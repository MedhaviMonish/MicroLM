# %%
import torch
import torch.nn as nn
import numpy as np
import math
import time

# Load frozen embedding table
embedding_table = np.load("tokenizer/token_embeddings.npy")
embedding_tensor = torch.tensor(embedding_table, dtype=torch.float32)

VOCAB_SIZE    = embedding_tensor.shape[0]   # 4096
MINILM_DIM    = embedding_tensor.shape[1]   # 384
print(f"Vocab size : {VOCAB_SIZE}")
print(f"MiniLM dim : {MINILM_DIM}")
# Out:
# Vocab size : 16384
# MiniLM dim : 384

# %%
import torch.nn.functional as F 

N_HEADS  = 16
N_LAYERS = 4
FFN_DIM  = 512
HEAD_DIM = MINILM_DIM // N_HEADS 

def sinusoidal_encoding(seq_len, dim, device):
    pe       = torch.zeros(seq_len, dim, device=device)
    position = torch.arange(seq_len, device=device).unsqueeze(1)
    div_term = torch.exp(torch.arange(0, dim, 2, device=device) * (-math.log(10000.0) / dim))
    pe[:, 0::2] = torch.sin(position * div_term)
    pe[:, 1::2] = torch.cos(position * div_term)
    return pe  # (seq_len, dim)

class LayerNorm(nn.Module):
    """
    y = ((x - mean) / sqrt(var + eps)) * gamma + beta
    gamma, beta are learned per-feature scalars — shape (dim,)
    """
    def __init__(self, dim, eps=1e-5):
        super().__init__()
        self.eps   = eps
        self.gamma = nn.Parameter(torch.ones(dim))   # scale
        self.beta  = nn.Parameter(torch.zeros(dim))  # shift

    def forward(self, x):
        mean = x.mean(dim=-1, keepdim=True)           # (B, T, 1)
        var  = x.var(dim=-1, keepdim=True, unbiased=False)  # (B, T, 1)
        x_norm = (x - mean) / torch.sqrt(var + self.eps)    # (B, T, D)
        return self.gamma * x_norm + self.beta               # (B, T, D)

class MultiHeadCausalAttention(nn.Module):
    """
    Projects input into Q, K, V — splits into H heads — computes scaled
    dot-product attention with a causal mask — concatenates heads — projects out.

    Q = x W_q      shape: (B, T, D)
    K = x W_k      shape: (B, T, D)
    V = x W_v      shape: (B, T, D)

    Reshape to (B, H, T, head_dim), then:
        scores = Q @ Kᵀ / sqrt(head_dim)    (B, H, T, T)
        scores = scores + causal_mask        (upper triangle = -inf)
        weights = softmax(scores, dim=-1)    (B, H, T, T)
        out = weights @ V                    (B, H, T, head_dim)

    Concat heads → (B, T, D), project out via W_o
    """
    def __init__(self, dim, n_heads, dropout=0.0):
        super().__init__()
        assert dim % n_heads == 0, "dim must be divisible by n_heads"
        self.n_heads  = n_heads
        self.head_dim = dim // n_heads       # 48
        self.scale    = self.head_dim ** -0.5

        self.W_q = nn.Linear(dim, dim, bias=False)
        self.W_k = nn.Linear(dim, dim, bias=False)
        self.W_v = nn.Linear(dim, dim, bias=False)
        self.W_o = nn.Linear(dim, dim, bias=False)

        self.attn_drop = nn.Dropout(dropout)

    def forward(self, x):
        B, T, D = x.shape

        # --- Project & split into heads ---
        Q = self.W_q(x)  # (B, T, D)
        K = self.W_k(x)  # (B, T, D)
        V = self.W_v(x)  # (B, T, D)

        # Reshape: (B, T, D) → (B, H, T, head_dim)
        Q = Q.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)
        K = K.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)
        V = V.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)

        # --- Scaled dot-product attention ---
        # (B, H, T, head_dim) @ (B, H, head_dim, T) → (B, H, T, T)
        scores = (Q @ K.transpose(-2, -1)) * self.scale

        # Causal mask: positions can only attend to themselves and earlier tokens
        # Upper triangle (future tokens) set to -inf → softmax drives them to 0
        causal_mask = torch.triu(
            torch.ones(T, T, device=x.device, dtype=torch.bool), diagonal=1
        )
        scores = scores.masked_fill(causal_mask, float('-inf'))

        weights = torch.softmax(scores, dim=-1)  # (B, H, T, T)
        weights = self.attn_drop(weights)

        # (B, H, T, T) @ (B, H, T, head_dim) → (B, H, T, head_dim)
        out = weights @ V

        # --- Concat heads & project ---
        # (B, H, T, head_dim) → (B, T, H*head_dim) = (B, T, D)
        out = out.transpose(1, 2).contiguous().view(B, T, D)
        return self.W_o(out)  # (B, T, D)

class FeedForward(nn.Module):
    """
    Two-layer MLP with GELU activation.
    FFN(x) = GELU(x W_1 + b_1) W_2 + b_2

    Expands dim → ffn_dim (wider representation),
    then projects back down ffn_dim → dim.
    """
    def __init__(self, dim, ffn_dim, dropout=0.0):
        super().__init__()
        self.W_1 = nn.Linear(dim, ffn_dim)       # expand
        # self.W_2 = nn.Linear(ffn_dim, ffn_dim)       # maintain
        self.W_2 = nn.Linear(ffn_dim, dim)       # contract
        # self.drop = nn.Dropout(dropout)

    def forward(self, x):
        x = F.gelu(self.W_1(x))   # (B, T, ffn_dim)
        # x = self.drop(x)
        # x = F.gelu(self.W_2(x))   
        # x = self.drop(x)
        x = self.W_2(x)           # (B, T, dim)
        return x

class TransformerBlock(nn.Module):
    """
    Pre-norm residual block (norm_first=True, same as your original config).

    x = x + Attention(LayerNorm(x))   ← self-attention sub-layer
    x = x + FFN(LayerNorm(x))         ← feed-forward sub-layer

    Pre-norm (LN before the sub-layer) stabilises training at depth
    vs post-norm (LN after the residual add).
    """
    def __init__(self, dim, n_heads, ffn_dim, dropout=0.0):
        super().__init__()
        self.norm_1 = LayerNorm(dim)
        self.attn   = MultiHeadCausalAttention(dim, n_heads, dropout)
        self.norm_2 = LayerNorm(dim)
        self.ffn    = FeedForward(dim, ffn_dim, dropout)
        self.drop   = nn.Dropout(dropout)

    def forward(self, x):
        x = x + self.drop(self.attn(self.norm_1(x)))  # (B, T, D)
        x = x + self.drop(self.ffn(self.norm_2(x)))   # (B, T, D)
        return x

class MicroLM(nn.Module):
    """
    Full architecture:
      1. Frozen MiniLM embedding lookup         → (B, T, 384)
      2. Sinusoidal positional encoding added   → (B, T, 384)
      3. N_LAYERS x TransformerBlock            → (B, T, 384)
      4. Final LayerNorm                        → (B, T, 384)
      5. Linear output head → logits            → (B, T, VOCAB_SIZE)
    """
    def __init__(self):
        super().__init__()
        self.register_buffer("embedding_table", embedding_tensor)


        self.blocks = nn.ModuleList([
            TransformerBlock(MINILM_DIM, N_HEADS, FFN_DIM, dropout=0.0)
            for _ in range(N_LAYERS)
        ])

        self.norm        = LayerNorm(MINILM_DIM)

    def forward(self, token_ids):
        B, T = token_ids.shape

        x = self.embedding_table[token_ids]                    # (B, T, 384)
        x = x + sinusoidal_encoding(T, MINILM_DIM, token_ids.device) # (B, T, 384)

        for block in self.blocks:
            x = block(x)   # (B, T, 384)

        x = self.norm(x)
        return x @ self.embedding_table.T

# %%
model     = MicroLM()
total     = sum(p.numel() for p in model.parameters())
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
frozen    = total - trainable

print(f"Trainable params : {trainable:,}")
print(f"Frozen params    : {frozen:,}  (embedding table)")
print(f"Total params     : {total:,}")

# print(f"\nParam breakdown:")
# for name, p in model.named_parameters():
#     if p.requires_grad:
#         print(f"  {name:55s} {p.numel():>10,}")

# Forward pass
x      = torch.randint(0, VOCAB_SIZE, (2, 32))
logits = model(x)
print(f"\nInput  : {x.shape}")
print(f"Output : {logits.shape}")
# Out:
# Trainable params : 3,942,656
# Frozen params    : 0  (embedding table)
# Total params     : 3,942,656
#
# Input  : torch.Size([2, 32])
# Output : torch.Size([2, 32, 16384])

# %%
model
# Out:
# MicroLM(
#   (blocks): ModuleList(
#     (0-3): 4 x TransformerBlock(
#       (norm_1): LayerNorm()
#       (attn): MultiHeadCausalAttention(
#         (W_q): Linear(in_features=384, out_features=384, bias=False)
#         (W_k): Linear(in_features=384, out_features=384, bias=False)
#         (W_v): Linear(in_features=384, out_features=384, bias=False)
#         (W_o): Linear(in_features=384, out_features=384, bias=False)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#       )
#       (norm_2): LayerNorm()
#       (ffn): FeedForward(
#         (W_1): Linear(in_features=384, out_features=512, bias=True)
#         (W_2): Linear(in_features=512, out_features=384, bias=True)
#       )
#       (drop): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (norm): LayerNorm()
# )

# %%
# ── Training Config ───────────────────────────────────────────────────────────
import gc
import json
import random
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from pathlib import Path

SHARD_DIR  = Path("dataset_shards")
SEQ_LEN    = 512
STRIDE  = 256    # step size → 64-token overlap
BATCH_SIZE = 16
N_EPOCHS   = 100
LOG_EVERY  = 200
CKPT_DIR   = Path("checkpoints_v1")
CKPT_DIR.mkdir(parents=True, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device      : {device}")
print(f"Model params: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# Device      : cuda
# Model params: 3,942,656

# %%
from torch.utils.data import Dataset


class ShardDataset(Dataset):
    def __init__(self, shard_path, seq_len=SEQ_LEN, stride=STRIDE):
        flat = torch.load(shard_path, weights_only=True)

        self.flat    = flat.to(torch.int16)
        print(len(self.flat))
        self.flat    = self.flat[:1_000_000]
        print(len(self.flat))
        self.seq_len = seq_len
        self.stride  = stride

        # number of full windows we can extract
        # +1 because we need seq_len+1 tokens (x + y target)
        n_tokens = len(self.flat)
        self.num_samples = max(0, (n_tokens - seq_len - 1) // stride + 1)

    def __len__(self):
        return self.num_samples

    def __getitem__(self, idx):
        start  = idx * self.stride
        tokens = self.flat[start : start + self.seq_len + 1].to(torch.long)  # ← cast here
        
        if len(tokens) < self.seq_len + 1:
            pad    = torch.full((self.seq_len + 1 - len(tokens),), PAD_ID, dtype=torch.long)
            tokens = torch.cat([tokens, pad])

        x = tokens[:-1]
        y = tokens[1:]
        return x, y


BOS_ID       = 2
EOS_ID       = 3

def collate_fn(batch):
    xs, ys = zip(*batch)
    # all samples are now fixed-length (seq_len), so no padding needed here
    x_pad = torch.stack(xs)          # [B, seq_len]
    y_pad = torch.stack(ys).clone()  # [B, seq_len]
    return x_pad, y_pad

# %%
# run once after sharding
meta = {
    "total_samples": sum(len(ShardDataset(p)) for p in sorted(SHARD_DIR.glob("shard_*.pt"))[:1]),
    "seq_len": SEQ_LEN,
    "stride": STRIDE,
}
with open(SHARD_DIR / "meta.json", "w") as f:
    json.dump(meta, f, indent=2)
    
# ── Optimizer & Scheduler ─────────────────────────────────────────────────────

with open(SHARD_DIR / "meta.json") as f:
    meta = json.load(f)

total_steps = (meta['total_samples'] // BATCH_SIZE) * N_EPOCHS

optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5)
scaler    = torch.cuda.amp.GradScaler()

print(f"Total samples: {meta['total_samples']:,}")
print(f"Total steps  : {total_steps:,}")
# Out:
# 268436159
# 1000000
# Total samples: 3,905
# Total steps  : 24,400
# /tmp/ipykernel_317002/4277151627.py:18: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler    = torch.cuda.amp.GradScaler()

# %%
sorted(SHARD_DIR.glob("shard_*.pt"))[:1]
# Out:
# [PosixPath('dataset_shards/shard_0000.pt')]

# %%
model.to(device)
# Out:
# MicroLM(
#   (blocks): ModuleList(
#     (0-3): 4 x TransformerBlock(
#       (norm_1): LayerNorm()
#       (attn): MultiHeadCausalAttention(
#         (W_q): Linear(in_features=384, out_features=384, bias=False)
#         (W_k): Linear(in_features=384, out_features=384, bias=False)
#         (W_v): Linear(in_features=384, out_features=384, bias=False)
#         (W_o): Linear(in_features=384, out_features=384, bias=False)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#       )
#       (norm_2): LayerNorm()
#       (ffn): FeedForward(
#         (W_1): Linear(in_features=384, out_features=512, bias=True)
#         (W_2): Linear(in_features=512, out_features=384, bias=True)
#       )
#       (drop): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (norm): LayerNorm()
# )

# %%
shard_files  = sorted(SHARD_DIR.glob("shard_*.pt"))[:1]
# shard_files.extend(sorted(SHARD_DIR.glob("ins*.pt"))[:1])
# shard_files.extend(sorted(SHARD_DIR.glob("shard_*.pt"))[1:2])
shard_files
# Out:
# [PosixPath('dataset_shards/shard_0000.pt')]

# %%
# ── Training Loop with Resume ─────────────────────────────────────────────────
import math
loss_history = []
start_epoch  = 0
start_shard  = 0

# ── Resume from latest checkpoint ────────────────────────────────────────────
# Check mid-epoch checkpoints first, then epoch checkpoints
all_ckpts = sorted(CKPT_DIR.glob("epoch_*.pt"))
epoch_ckpts = [c for c in all_ckpts if "shard" not in c.name]
print(epoch_ckpts)
if epoch_ckpts:
    latest = epoch_ckpts[-2]
    print(f"Resuming from epoch checkpoint {latest}...")
    ckpt = torch.load(latest, map_location=device)
    model.load_state_dict(ckpt["model"])
    optimizer.load_state_dict(ckpt["optimizer"])
    loss_history = ckpt.get("loss_history", [])
    start_epoch  = ckpt["epoch"]            # full epoch completed
    start_shard  = 0                        # start from beginning of next epoch
    print(f"Resumed — starting from epoch {start_epoch+1}")

else:
    print("No checkpoint found — training from scratch")

optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3)
model.to(device)
model.train()

for epoch in range(start_epoch, N_EPOCHS):
    epoch_loss  = 0.0
    epoch_steps = 0

    # no shuffle — sequential shard order
    shard_order = list(range(len(shard_files)))

    # if resuming mid-epoch, skip already completed shards
    if epoch == start_epoch and start_shard > 0:
        shard_order = shard_order[start_shard:]
        print(f"Skipping shards 0-{start_shard-1}, resuming from shard {start_shard}")

    print(f"\n{'='*60}")
    print(f"Epoch {epoch+1}/{N_EPOCHS}")
    print(f"{'='*60}")

    for shard_num, shard_idx in enumerate(shard_order):
        # just before the step loop:
        shard_start = time.time()
        interval_start = time.time()
        
        # actual shard number in epoch (accounts for skipped shards on resume)
        actual_shard_num = shard_idx  

        shard_path = shard_files[shard_idx]
        print(f"\n[Epoch {epoch+1}] Shard {actual_shard_num+1}/{len(shard_files)} — {shard_path.name}")

        ds     = ShardDataset(shard_path)
        loader = DataLoader(
            ds,
            batch_size=BATCH_SIZE,
            shuffle=True,
            collate_fn=collate_fn,
            num_workers=0,
            pin_memory=True,
        )

        shard_loss  = 0.0
        shard_steps = 0

        for step, (x, y) in enumerate(loader):
            x = x.to(device)
            y = y.to(device)

            optimizer.zero_grad()

            with torch.autocast(device_type="cuda", dtype=torch.bfloat16):
                logits = model(x)
                loss   = F.cross_entropy(
                    logits.view(-1, logits.size(-1)),
                    y.view(-1),
                    ignore_index=-100,
                )
                del logits  # free 268MB immediately before backward


            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()

            if not math.isnan(loss.item()):
                shard_loss  += loss.item()
                shard_steps += 1
                epoch_loss  += loss.item()
                epoch_steps += 1

            if step % LOG_EVERY == 0:
                avg = shard_loss / max(shard_steps, 1)
                ppl = math.exp(min(avg, 20))
                elapsed_total = time.time() - shard_start
                interval_time = time.time() - interval_start
                print(f"  step {step:>5} | loss {loss.item():.4f} | avg {avg:.4f} | ppl {ppl:.2f} | last {LOG_EVERY} steps: {interval_time:.1f}s | total: {elapsed_total:.0f}s")
                interval_start = time.time()  # reset for next interval

            del loss, x, y
        shard_avg = shard_loss / max(shard_steps, 1)
        shard_ppl = math.exp(min(shard_avg, 20))
        loss_history.append({
            "epoch":      epoch + 1,
            "shard":      actual_shard_num,
            "avg_loss":   shard_avg,
            "perplexity": shard_ppl,
        })
        print(f"  Shard done — avg loss: {shard_avg:.4f} | ppl {shard_ppl:.2f}")

        del ds, loader
        gc.collect()
        torch.cuda.empty_cache()

        # mid-epoch checkpoint every 5 shards
        # if (actual_shard_num + 1) % 2 == 0:
        #     ckpt_path = CKPT_DIR / f"epoch_{epoch+1}_shard_{actual_shard_num}.pt"
        #     torch.save({
        #         "epoch":        epoch + 1,
        #         "shard":        actual_shard_num,
        #         "model":        model.state_dict(),
        #         "optimizer":    optimizer.state_dict(),
        #         "scheduler":    scheduler.state_dict(),
        #         "loss_history": loss_history,
        #     }, ckpt_path)
        #     print(f"Mid-epoch checkpoint saved → {ckpt_path}")

    # reset start_shard after first resumed epoch
    start_shard = 0

    epoch_avg = epoch_loss / max(epoch_steps, 1)
    epoch_ppl = math.exp(min(epoch_avg, 20))
    print(f"\nEpoch {epoch+1} complete — avg loss: {epoch_avg:.4f} | ppl {epoch_ppl:.2f}")

    ckpt_path = CKPT_DIR / f"epoch_{epoch+1}.pt"
    torch.save({
        "epoch":        epoch + 1,
        "shard":        -1,
        "model":        model.state_dict(),
        "optimizer":    optimizer.state_dict(),
        "loss_history": loss_history,
    }, ckpt_path)
    print(f"Epoch checkpoint saved → {ckpt_path}")

    with open(CKPT_DIR / "loss_history.json", "w") as f:
        json.dump(loss_history, f, indent=2)

print("\nTraining complete.")
# Out:
# []
# No checkpoint found — training from scratch
#
# ============================================================
# Epoch 1/100
# ============================================================
#
# [Epoch 1] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 9.8792 | avg 9.8792 | ppl 19519.50 | last 200 steps: 3.2s | total: 3s
#   step   200 | loss 8.2496 | avg 8.4244 | ppl 4556.68 | last 200 steps: 16.7s | total: 20s
#   Shard done — avg loss: 8.3996 | ppl 4445.31
#
# Epoch 1 complete — avg loss: 8.3996 | ppl 4445.31
# Epoch checkpoint saved → checkpoints_v1/epoch_1.pt
#
# ============================================================
# Epoch 2/100
# ============================================================
#
# [Epoch 2] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 8.2470 | avg 8.2470 | ppl 3816.20 | last 200 steps: 2.3s | total: 2s
#   step   200 | loss 8.1062 | avg 8.1396 | ppl 3427.51 | last 200 steps: 17.0s | total: 19s
#   Shard done — avg loss: 8.1244 | ppl 3375.78
#
# Epoch 2 complete — avg loss: 8.1244 | ppl 3375.78
# Epoch checkpoint saved → checkpoints_v1/epoch_2.pt
#
# ============================================================
# Epoch 3/100
# ============================================================
#
# [Epoch 3] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 8.0520 | avg 8.0520 | ppl 3140.19 | last 200 steps: 2.3s | total: 2s
#   step   200 | loss 8.0373 | avg 7.9877 | ppl 2944.55 | last 200 steps: 17.1s | total: 19s
#   Shard done — avg loss: 7.9784 | ppl 2917.20
#
# Epoch 3 complete — avg loss: 7.9784 | ppl 2917.20
# Epoch checkpoint saved → checkpoints_v1/epoch_3.pt
#
# ============================================================
# Epoch 4/100
# ============================================================
#
# [Epoch 4] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 7.9217 | avg 7.9217 | ppl 2756.53 | last 200 steps: 2.1s | total: 2s
#   step   200 | loss 7.7146 | avg 7.8701 | ppl 2617.78 | last 200 steps: 17.3s | total: 19s
#   Shard done — avg loss: 7.8558 | ppl 2580.73
#
# Epoch 4 complete — avg loss: 7.8558 | ppl 2580.73
# Epoch checkpoint saved → checkpoints_v1/epoch_4.pt
#
# ============================================================
# Epoch 5/100
# ============================================================
#
# [Epoch 5] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 7.8119 | avg 7.8119 | ppl 2469.84 | last 200 steps: 2.0s | total: 2s
#   step   200 | loss 7.8481 | avg 7.7756 | ppl 2381.77 | last 200 steps: 17.2s | total: 19s
#   Shard done — avg loss: 7.7648 | ppl 2356.30
#
# Epoch 5 complete — avg loss: 7.7648 | ppl 2356.30
# Epoch checkpoint saved → checkpoints_v1/epoch_5.pt
#
# ============================================================
# Epoch 6/100
# ============================================================
#
# [Epoch 6] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 7.6385 | avg 7.6385 | ppl 2076.53 | last 200 steps: 2.2s | total: 2s
#   step   200 | loss 7.7488 | avg 7.6859 | ppl 2177.45 | last 200 steps: 17.1s | total: 19s
#   Shard done — avg loss: 7.6788 | ppl 2162.05
#
# Epoch 6 complete — avg loss: 7.6788 | ppl 2162.05
# Epoch checkpoint saved → checkpoints_v1/epoch_6.pt
#
# ============================================================
# Epoch 7/100
# ============================================================
#
# [Epoch 7] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 7.6030 | avg 7.6030 | ppl 2004.27 | last 200 steps: 2.5s | total: 3s
#   step   200 | loss 7.6850 | avg 7.5866 | ppl 1971.52 | last 200 steps: 17.2s | total: 20s
#   Shard done — avg loss: 7.5743 | ppl 1947.41
#
# Epoch 7 complete — avg loss: 7.5743 | ppl 1947.41
# Epoch checkpoint saved → checkpoints_v1/epoch_7.pt
#
# ============================================================
# Epoch 8/100
# ============================================================
#
# [Epoch 8] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 7.5162 | avg 7.5162 | ppl 1837.61 | last 200 steps: 1.9s | total: 2s
#   step   200 | loss 7.4040 | avg 7.4778 | ppl 1768.39 | last 200 steps: 17.2s | total: 19s
#   Shard done — avg loss: 7.4640 | ppl 1744.16
#
# Epoch 8 complete — avg loss: 7.4640 | ppl 1744.16
# Epoch checkpoint saved → checkpoints_v1/epoch_8.pt
#
# ============================================================
# Epoch 9/100
# ============================================================
#
# [Epoch 9] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 7.5094 | avg 7.5094 | ppl 1825.09 | last 200 steps: 2.1s | total: 2s
#   step   200 | loss 7.3811 | avg 7.3542 | ppl 1562.69 | last 200 steps: 17.3s | total: 19s
#   Shard done — avg loss: 7.3470 | ppl 1551.60
#
# Epoch 9 complete — avg loss: 7.3470 | ppl 1551.60
# Epoch checkpoint saved → checkpoints_v1/epoch_9.pt
#
# ============================================================
# Epoch 10/100
# ============================================================
#
# [Epoch 10] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 7.2524 | avg 7.2524 | ppl 1411.55 | last 200 steps: 1.8s | total: 2s
#   step   200 | loss 7.2061 | avg 7.2443 | ppl 1400.06 | last 200 steps: 17.2s | total: 19s
#   Shard done — avg loss: 7.2373 | ppl 1390.35
#
# Epoch 10 complete — avg loss: 7.2373 | ppl 1390.35
# Epoch checkpoint saved → checkpoints_v1/epoch_10.pt
#
# ============================================================
# Epoch 11/100
# ============================================================
#
# [Epoch 11] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 7.1497 | avg 7.1497 | ppl 1273.72 | last 200 steps: 2.2s | total: 2s
#   step   200 | loss 7.0746 | avg 7.1327 | ppl 1252.28 | last 200 steps: 17.4s | total: 20s
#   Shard done — avg loss: 7.1246 | ppl 1242.09
#
# Epoch 11 complete — avg loss: 7.1246 | ppl 1242.09
# Epoch checkpoint saved → checkpoints_v1/epoch_11.pt
#
# ============================================================
# Epoch 12/100
# ============================================================
#
# [Epoch 12] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 7.0198 | avg 7.0198 | ppl 1118.53 | last 200 steps: 1.5s | total: 2s
#   step   200 | loss 6.8090 | avg 7.0200 | ppl 1118.83 | last 200 steps: 17.3s | total: 19s
#   Shard done — avg loss: 7.0215 | ppl 1120.51
#
# Epoch 12 complete — avg loss: 7.0215 | ppl 1120.51
# Epoch checkpoint saved → checkpoints_v1/epoch_12.pt
#
# ============================================================
# Epoch 13/100
# ============================================================
#
# [Epoch 13] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 7.1650 | avg 7.1650 | ppl 1293.36 | last 200 steps: 1.6s | total: 2s
#   step   200 | loss 6.6281 | avg 6.9238 | ppl 1016.15 | last 200 steps: 17.2s | total: 19s
#   Shard done — avg loss: 6.9176 | ppl 1009.86
#
# Epoch 13 complete — avg loss: 6.9176 | ppl 1009.86
# Epoch checkpoint saved → checkpoints_v1/epoch_13.pt
#
# ============================================================
# Epoch 14/100
# ============================================================
#
# [Epoch 14] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 6.6886 | avg 6.6886 | ppl 803.18 | last 200 steps: 1.6s | total: 2s
#   step   200 | loss 6.7540 | avg 6.8289 | ppl 924.15 | last 200 steps: 17.2s | total: 19s
#   Shard done — avg loss: 6.8231 | ppl 918.82
#
# Epoch 14 complete — avg loss: 6.8231 | ppl 918.82
# Epoch checkpoint saved → checkpoints_v1/epoch_14.pt
#
# ============================================================
# Epoch 15/100
# ============================================================
#
# [Epoch 15] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 6.5766 | avg 6.5766 | ppl 718.09 | last 200 steps: 1.7s | total: 2s
#   step   200 | loss 6.4576 | avg 6.7316 | ppl 838.48 | last 200 steps: 17.3s | total: 19s
#   Shard done — avg loss: 6.7269 | ppl 834.59
#
# Epoch 15 complete — avg loss: 6.7269 | ppl 834.59
# Epoch checkpoint saved → checkpoints_v1/epoch_15.pt
#
# ============================================================
# Epoch 16/100
# ============================================================
#
# [Epoch 16] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 6.6599 | avg 6.6599 | ppl 780.47 | last 200 steps: 2.2s | total: 2s
#   step   200 | loss 6.7076 | avg 6.6494 | ppl 772.33 | last 200 steps: 17.4s | total: 20s
#   Shard done — avg loss: 6.6363 | ppl 762.28
#
# Epoch 16 complete — avg loss: 6.6363 | ppl 762.28
# Epoch checkpoint saved → checkpoints_v1/epoch_16.pt
#
# ============================================================
# Epoch 17/100
# ============================================================
#
# [Epoch 17] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 6.6229 | avg 6.6229 | ppl 752.09 | last 200 steps: 2.3s | total: 2s
#   step   200 | loss 6.5371 | avg 6.5601 | ppl 706.32 | last 200 steps: 17.5s | total: 20s
#   Shard done — avg loss: 6.5565 | ppl 703.79
#
# Epoch 17 complete — avg loss: 6.5565 | ppl 703.79
# Epoch checkpoint saved → checkpoints_v1/epoch_17.pt
#
# ============================================================
# Epoch 18/100
# ============================================================
#
# [Epoch 18] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 6.5584 | avg 6.5584 | ppl 705.15 | last 200 steps: 2.2s | total: 2s
#   step   200 | loss 6.5940 | avg 6.4628 | ppl 640.88 | last 200 steps: 17.3s | total: 20s
#   Shard done — avg loss: 6.4664 | ppl 643.18
#
# Epoch 18 complete — avg loss: 6.4664 | ppl 643.18
# Epoch checkpoint saved → checkpoints_v1/epoch_18.pt
#
# ============================================================
# Epoch 19/100
# ============================================================
#
# [Epoch 19] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 6.6636 | avg 6.6636 | ppl 783.36 | last 200 steps: 2.0s | total: 2s
#   step   200 | loss 6.4543 | avg 6.3875 | ppl 594.35 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 6.3862 | ppl 593.59
#
# Epoch 19 complete — avg loss: 6.3862 | ppl 593.59
# Epoch checkpoint saved → checkpoints_v1/epoch_19.pt
#
# ============================================================
# Epoch 20/100
# ============================================================
#
# [Epoch 20] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 6.1388 | avg 6.1388 | ppl 463.49 | last 200 steps: 2.4s | total: 2s
#   step   200 | loss 6.3435 | avg 6.2981 | ppl 543.54 | last 200 steps: 17.3s | total: 20s
#   Shard done — avg loss: 6.3038 | ppl 546.63
#
# Epoch 20 complete — avg loss: 6.3038 | ppl 546.63
# Epoch checkpoint saved → checkpoints_v1/epoch_20.pt
#
# ============================================================
# Epoch 21/100
# ============================================================
#
# [Epoch 21] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 6.1521 | avg 6.1521 | ppl 469.70 | last 200 steps: 1.7s | total: 2s
#   step   200 | loss 6.1073 | avg 6.2187 | ppl 502.05 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 6.2261 | ppl 505.77
#
# Epoch 21 complete — avg loss: 6.2261 | ppl 505.77
# Epoch checkpoint saved → checkpoints_v1/epoch_21.pt
#
# ============================================================
# Epoch 22/100
# ============================================================
#
# [Epoch 22] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 6.2790 | avg 6.2790 | ppl 533.28 | last 200 steps: 1.8s | total: 2s
#   step   200 | loss 6.0736 | avg 6.1244 | ppl 456.89 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 6.1384 | ppl 463.30
#
# Epoch 22 complete — avg loss: 6.1384 | ppl 463.30
# Epoch checkpoint saved → checkpoints_v1/epoch_22.pt
#
# ============================================================
# Epoch 23/100
# ============================================================
#
# [Epoch 23] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 6.1650 | avg 6.1650 | ppl 475.79 | last 200 steps: 2.3s | total: 2s
#   step   200 | loss 5.9805 | avg 6.0595 | ppl 428.14 | last 200 steps: 17.4s | total: 20s
#   Shard done — avg loss: 6.0660 | ppl 430.94
#
# Epoch 23 complete — avg loss: 6.0660 | ppl 430.94
# Epoch checkpoint saved → checkpoints_v1/epoch_23.pt
#
# ============================================================
# Epoch 24/100
# ============================================================
#
# [Epoch 24] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.9184 | avg 5.9184 | ppl 371.82 | last 200 steps: 2.2s | total: 2s
#   step   200 | loss 6.1578 | avg 6.0061 | ppl 405.88 | last 200 steps: 17.3s | total: 19s
#   Shard done — avg loss: 6.0104 | ppl 407.63
#
# Epoch 24 complete — avg loss: 6.0104 | ppl 407.63
# Epoch checkpoint saved → checkpoints_v1/epoch_24.pt
#
# ============================================================
# Epoch 25/100
# ============================================================
#
# [Epoch 25] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.8675 | avg 5.8675 | ppl 353.36 | last 200 steps: 2.2s | total: 2s
#   step   200 | loss 6.1111 | avg 5.9247 | ppl 374.15 | last 200 steps: 17.5s | total: 20s
#   Shard done — avg loss: 5.9287 | ppl 375.65
#
# Epoch 25 complete — avg loss: 5.9287 | ppl 375.65
# Epoch checkpoint saved → checkpoints_v1/epoch_25.pt
#
# ============================================================
# Epoch 26/100
# ============================================================
#
# [Epoch 26] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.8106 | avg 5.8106 | ppl 333.83 | last 200 steps: 1.6s | total: 2s
#   step   200 | loss 5.7609 | avg 5.8630 | ppl 351.77 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 5.8725 | ppl 355.13
#
# Epoch 26 complete — avg loss: 5.8725 | ppl 355.13
# Epoch checkpoint saved → checkpoints_v1/epoch_26.pt
#
# ============================================================
# Epoch 27/100
# ============================================================
#
# [Epoch 27] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.8766 | avg 5.8766 | ppl 356.60 | last 200 steps: 1.7s | total: 2s
#   step   200 | loss 6.0180 | avg 5.7944 | ppl 328.44 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 5.8047 | ppl 331.87
#
# Epoch 27 complete — avg loss: 5.8047 | ppl 331.87
# Epoch checkpoint saved → checkpoints_v1/epoch_27.pt
#
# ============================================================
# Epoch 28/100
# ============================================================
#
# [Epoch 28] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.7570 | avg 5.7570 | ppl 316.39 | last 200 steps: 1.8s | total: 2s
#   step   200 | loss 5.8315 | avg 5.7150 | ppl 303.38 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 5.7158 | ppl 303.64
#
# Epoch 28 complete — avg loss: 5.7158 | ppl 303.64
# Epoch checkpoint saved → checkpoints_v1/epoch_28.pt
#
# ============================================================
# Epoch 29/100
# ============================================================
#
# [Epoch 29] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.7534 | avg 5.7534 | ppl 315.26 | last 200 steps: 2.8s | total: 3s
#   step   200 | loss 5.7129 | avg 5.6472 | ppl 283.51 | last 200 steps: 17.5s | total: 20s
#   Shard done — avg loss: 5.6604 | ppl 287.25
#
# Epoch 29 complete — avg loss: 5.6604 | ppl 287.25
# Epoch checkpoint saved → checkpoints_v1/epoch_29.pt
#
# ============================================================
# Epoch 30/100
# ============================================================
#
# [Epoch 30] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.3658 | avg 5.3658 | ppl 213.96 | last 200 steps: 2.5s | total: 3s
#   step   200 | loss 5.5339 | avg 5.6048 | ppl 271.74 | last 200 steps: 17.3s | total: 20s
#   Shard done — avg loss: 5.6268 | ppl 277.77
#
# Epoch 30 complete — avg loss: 5.6268 | ppl 277.77
# Epoch checkpoint saved → checkpoints_v1/epoch_30.pt
#
# ============================================================
# Epoch 31/100
# ============================================================
#
# [Epoch 31] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.5807 | avg 5.5807 | ppl 265.25 | last 200 steps: 1.7s | total: 2s
#   step   200 | loss 5.1105 | avg 5.5332 | ppl 252.95 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 5.5507 | ppl 257.42
#
# Epoch 31 complete — avg loss: 5.5507 | ppl 257.42
# Epoch checkpoint saved → checkpoints_v1/epoch_31.pt
#
# ============================================================
# Epoch 32/100
# ============================================================
#
# [Epoch 32] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.4262 | avg 5.4262 | ppl 227.29 | last 200 steps: 1.9s | total: 2s
#   step   200 | loss 5.5622 | avg 5.4750 | ppl 238.65 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 5.4837 | ppl 240.74
#
# Epoch 32 complete — avg loss: 5.4837 | ppl 240.74
# Epoch checkpoint saved → checkpoints_v1/epoch_32.pt
#
# ============================================================
# Epoch 33/100
# ============================================================
#
# [Epoch 33] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.2318 | avg 5.2318 | ppl 187.14 | last 200 steps: 2.3s | total: 2s
#   step   200 | loss 5.6547 | avg 5.4496 | ppl 232.66 | last 200 steps: 17.4s | total: 20s
#   Shard done — avg loss: 5.4528 | ppl 233.41
#
# Epoch 33 complete — avg loss: 5.4528 | ppl 233.41
# Epoch checkpoint saved → checkpoints_v1/epoch_33.pt
#
# ============================================================
# Epoch 34/100
# ============================================================
#
# [Epoch 34] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.4075 | avg 5.4075 | ppl 223.08 | last 200 steps: 1.9s | total: 2s
#   step   200 | loss 5.2831 | avg 5.3754 | ppl 216.03 | last 200 steps: 17.3s | total: 19s
#   Shard done — avg loss: 5.3968 | ppl 220.71
#
# Epoch 34 complete — avg loss: 5.3968 | ppl 220.71
# Epoch checkpoint saved → checkpoints_v1/epoch_34.pt
#
# ============================================================
# Epoch 35/100
# ============================================================
#
# [Epoch 35] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.1809 | avg 5.1809 | ppl 177.84 | last 200 steps: 2.6s | total: 3s
#   step   200 | loss 5.4123 | avg 5.3315 | ppl 206.75 | last 200 steps: 17.4s | total: 20s
#   Shard done — avg loss: 5.3478 | ppl 210.15
#
# Epoch 35 complete — avg loss: 5.3478 | ppl 210.15
# Epoch checkpoint saved → checkpoints_v1/epoch_35.pt
#
# ============================================================
# Epoch 36/100
# ============================================================
#
# [Epoch 36] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.2695 | avg 5.2695 | ppl 194.31 | last 200 steps: 1.7s | total: 2s
#   step   200 | loss 5.3659 | avg 5.2791 | ppl 196.18 | last 200 steps: 17.3s | total: 19s
#   Shard done — avg loss: 5.2943 | ppl 199.20
#
# Epoch 36 complete — avg loss: 5.2943 | ppl 199.20
# Epoch checkpoint saved → checkpoints_v1/epoch_36.pt
#
# ============================================================
# Epoch 37/100
# ============================================================
#
# [Epoch 37] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.2056 | avg 5.2056 | ppl 182.28 | last 200 steps: 1.6s | total: 2s
#   step   200 | loss 5.4067 | avg 5.2327 | ppl 187.29 | last 200 steps: 17.5s | total: 19s
#   Shard done — avg loss: 5.2515 | ppl 190.85
#
# Epoch 37 complete — avg loss: 5.2515 | ppl 190.85
# Epoch checkpoint saved → checkpoints_v1/epoch_37.pt
#
# ============================================================
# Epoch 38/100
# ============================================================
#
# [Epoch 38] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.0466 | avg 5.0466 | ppl 155.49 | last 200 steps: 1.8s | total: 2s
#   step   200 | loss 5.4251 | avg 5.1672 | ppl 175.43 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 5.1969 | ppl 180.71
#
# Epoch 38 complete — avg loss: 5.1969 | ppl 180.71
# Epoch checkpoint saved → checkpoints_v1/epoch_38.pt
#
# ============================================================
# Epoch 39/100
# ============================================================
#
# [Epoch 39] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.1028 | avg 5.1028 | ppl 164.49 | last 200 steps: 1.7s | total: 2s
#   step   200 | loss 5.3352 | avg 5.1562 | ppl 173.50 | last 200 steps: 17.3s | total: 19s
#   Shard done — avg loss: 5.1687 | ppl 175.68
#
# Epoch 39 complete — avg loss: 5.1687 | ppl 175.68
# Epoch checkpoint saved → checkpoints_v1/epoch_39.pt
#
# ============================================================
# Epoch 40/100
# ============================================================
#
# [Epoch 40] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.2820 | avg 5.2820 | ppl 196.77 | last 200 steps: 2.5s | total: 3s
#   step   200 | loss 5.2477 | avg 5.0801 | ppl 160.78 | last 200 steps: 17.4s | total: 20s
#   Shard done — avg loss: 5.0934 | ppl 162.95
#
# Epoch 40 complete — avg loss: 5.0934 | ppl 162.95
# Epoch checkpoint saved → checkpoints_v1/epoch_40.pt
#
# ============================================================
# Epoch 41/100
# ============================================================
#
# [Epoch 41] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.1179 | avg 5.1179 | ppl 166.99 | last 200 steps: 2.1s | total: 2s
#   step   200 | loss 5.2265 | avg 5.0827 | ppl 161.22 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 5.0895 | ppl 162.31
#
# Epoch 41 complete — avg loss: 5.0895 | ppl 162.31
# Epoch checkpoint saved → checkpoints_v1/epoch_41.pt
#
# ============================================================
# Epoch 42/100
# ============================================================
#
# [Epoch 42] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 5.0800 | avg 5.0800 | ppl 160.78 | last 200 steps: 1.9s | total: 2s
#   step   200 | loss 5.1076 | avg 5.0279 | ppl 152.62 | last 200 steps: 17.5s | total: 19s
#   Shard done — avg loss: 5.0374 | ppl 154.08
#
# Epoch 42 complete — avg loss: 5.0374 | ppl 154.08
# Epoch checkpoint saved → checkpoints_v1/epoch_42.pt
#
# ============================================================
# Epoch 43/100
# ============================================================
#
# [Epoch 43] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.9472 | avg 4.9472 | ppl 140.78 | last 200 steps: 2.0s | total: 2s
#   step   200 | loss 5.2250 | avg 4.9387 | ppl 139.58 | last 200 steps: 17.5s | total: 19s
#   Shard done — avg loss: 4.9474 | ppl 140.81
#
# Epoch 43 complete — avg loss: 4.9474 | ppl 140.81
# Epoch checkpoint saved → checkpoints_v1/epoch_43.pt
#
# ============================================================
# Epoch 44/100
# ============================================================
#
# [Epoch 44] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.4548 | avg 4.4548 | ppl 86.04 | last 200 steps: 2.6s | total: 3s
#   step   200 | loss 4.9845 | avg 4.9280 | ppl 138.10 | last 200 steps: 17.3s | total: 20s
#   Shard done — avg loss: 4.9379 | ppl 139.48
#
# Epoch 44 complete — avg loss: 4.9379 | ppl 139.48
# Epoch checkpoint saved → checkpoints_v1/epoch_44.pt
#
# ============================================================
# Epoch 45/100
# ============================================================
#
# [Epoch 45] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.9857 | avg 4.9857 | ppl 146.31 | last 200 steps: 2.0s | total: 2s
#   step   200 | loss 4.9123 | avg 4.8881 | ppl 132.70 | last 200 steps: 17.5s | total: 19s
#   Shard done — avg loss: 4.9085 | ppl 135.44
#
# Epoch 45 complete — avg loss: 4.9085 | ppl 135.44
# Epoch checkpoint saved → checkpoints_v1/epoch_45.pt
#
# ============================================================
# Epoch 46/100
# ============================================================
#
# [Epoch 46] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.8835 | avg 4.8835 | ppl 132.09 | last 200 steps: 2.1s | total: 2s
#   step   200 | loss 5.0556 | avg 4.8721 | ppl 130.59 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 4.9048 | ppl 134.94
#
# Epoch 46 complete — avg loss: 4.9048 | ppl 134.94
# Epoch checkpoint saved → checkpoints_v1/epoch_46.pt
#
# ============================================================
# Epoch 47/100
# ============================================================
#
# [Epoch 47] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.8634 | avg 4.8634 | ppl 129.47 | last 200 steps: 2.0s | total: 2s
#   step   200 | loss 4.8638 | avg 4.8415 | ppl 126.66 | last 200 steps: 17.6s | total: 20s
#   Shard done — avg loss: 4.8388 | ppl 126.32
#
# Epoch 47 complete — avg loss: 4.8388 | ppl 126.32
# Epoch checkpoint saved → checkpoints_v1/epoch_47.pt
#
# ============================================================
# Epoch 48/100
# ============================================================
#
# [Epoch 48] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.6677 | avg 4.6677 | ppl 106.45 | last 200 steps: 2.0s | total: 2s
#   step   200 | loss 4.8455 | avg 4.8112 | ppl 122.88 | last 200 steps: 17.3s | total: 19s
#   Shard done — avg loss: 4.8297 | ppl 125.17
#
# Epoch 48 complete — avg loss: 4.8297 | ppl 125.17
# Epoch checkpoint saved → checkpoints_v1/epoch_48.pt
#
# ============================================================
# Epoch 49/100
# ============================================================
#
# [Epoch 49] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.6213 | avg 4.6213 | ppl 101.62 | last 200 steps: 2.2s | total: 2s
#   step   200 | loss 4.6637 | avg 4.7676 | ppl 117.63 | last 200 steps: 17.4s | total: 20s
#   Shard done — avg loss: 4.7753 | ppl 118.54
#
# Epoch 49 complete — avg loss: 4.7753 | ppl 118.54
# Epoch checkpoint saved → checkpoints_v1/epoch_49.pt
#
# ============================================================
# Epoch 50/100
# ============================================================
#
# [Epoch 50] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.7261 | avg 4.7261 | ppl 112.85 | last 200 steps: 2.4s | total: 2s
#   step   200 | loss 4.7700 | avg 4.7479 | ppl 115.34 | last 200 steps: 17.3s | total: 20s
#   Shard done — avg loss: 4.7728 | ppl 118.25
#
# Epoch 50 complete — avg loss: 4.7728 | ppl 118.25
# Epoch checkpoint saved → checkpoints_v1/epoch_50.pt
#
# ============================================================
# Epoch 51/100
# ============================================================
#
# [Epoch 51] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.8914 | avg 4.8914 | ppl 133.14 | last 200 steps: 1.6s | total: 2s
#   step   200 | loss 4.8280 | avg 4.6759 | ppl 107.33 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 4.7025 | ppl 110.22
#
# Epoch 51 complete — avg loss: 4.7025 | ppl 110.22
# Epoch checkpoint saved → checkpoints_v1/epoch_51.pt
#
# ============================================================
# Epoch 52/100
# ============================================================
#
# [Epoch 52] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.5007 | avg 4.5007 | ppl 90.08 | last 200 steps: 2.2s | total: 2s
#   step   200 | loss 4.6881 | avg 4.6270 | ppl 102.21 | last 200 steps: 17.3s | total: 20s
#   Shard done — avg loss: 4.6515 | ppl 104.75
#
# Epoch 52 complete — avg loss: 4.6515 | ppl 104.75
# Epoch checkpoint saved → checkpoints_v1/epoch_52.pt
#
# ============================================================
# Epoch 53/100
# ============================================================
#
# [Epoch 53] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.6521 | avg 4.6521 | ppl 104.81 | last 200 steps: 2.0s | total: 2s
#   step   200 | loss 4.6200 | avg 4.6231 | ppl 101.80 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 4.6343 | ppl 102.95
#
# Epoch 53 complete — avg loss: 4.6343 | ppl 102.95
# Epoch checkpoint saved → checkpoints_v1/epoch_53.pt
#
# ============================================================
# Epoch 54/100
# ============================================================
#
# [Epoch 54] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.3957 | avg 4.3957 | ppl 81.10 | last 200 steps: 2.3s | total: 2s
#   step   200 | loss 4.5045 | avg 4.6454 | ppl 104.11 | last 200 steps: 17.3s | total: 20s
#   Shard done — avg loss: 4.6645 | ppl 106.12
#
# Epoch 54 complete — avg loss: 4.6645 | ppl 106.12
# Epoch checkpoint saved → checkpoints_v1/epoch_54.pt
#
# ============================================================
# Epoch 55/100
# ============================================================
#
# [Epoch 55] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.6516 | avg 4.6516 | ppl 104.75 | last 200 steps: 2.3s | total: 2s
#   step   200 | loss 4.2909 | avg 4.5777 | ppl 97.29 | last 200 steps: 17.4s | total: 20s
#   Shard done — avg loss: 4.5921 | ppl 98.70
#
# Epoch 55 complete — avg loss: 4.5921 | ppl 98.70
# Epoch checkpoint saved → checkpoints_v1/epoch_55.pt
#
# ============================================================
# Epoch 56/100
# ============================================================
#
# [Epoch 56] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.9237 | avg 4.9237 | ppl 137.51 | last 200 steps: 2.0s | total: 2s
#   step   200 | loss 4.9402 | avg 4.5826 | ppl 97.77 | last 200 steps: 17.5s | total: 20s
#   Shard done — avg loss: 4.6120 | ppl 100.69
#
# Epoch 56 complete — avg loss: 4.6120 | ppl 100.69
# Epoch checkpoint saved → checkpoints_v1/epoch_56.pt
#
# ============================================================
# Epoch 57/100
# ============================================================
#
# [Epoch 57] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.6376 | avg 4.6376 | ppl 103.30 | last 200 steps: 2.3s | total: 2s
#   step   200 | loss 4.7649 | avg 4.5100 | ppl 90.92 | last 200 steps: 17.4s | total: 20s
#   Shard done — avg loss: 4.5527 | ppl 94.89
#
# Epoch 57 complete — avg loss: 4.5527 | ppl 94.89
# Epoch checkpoint saved → checkpoints_v1/epoch_57.pt
#
# ============================================================
# Epoch 58/100
# ============================================================
#
# [Epoch 58] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.5961 | avg 4.5961 | ppl 99.09 | last 200 steps: 2.4s | total: 2s
#   step   200 | loss 4.5046 | avg 4.5412 | ppl 93.81 | last 200 steps: 17.5s | total: 20s
#   Shard done — avg loss: 4.5544 | ppl 95.05
#
# Epoch 58 complete — avg loss: 4.5544 | ppl 95.05
# Epoch checkpoint saved → checkpoints_v1/epoch_58.pt
#
# ============================================================
# Epoch 59/100
# ============================================================
#
# [Epoch 59] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.6814 | avg 4.6814 | ppl 107.92 | last 200 steps: 1.9s | total: 2s
#   step   200 | loss 4.5999 | avg 4.4122 | ppl 82.45 | last 200 steps: 17.3s | total: 19s
#   Shard done — avg loss: 4.4523 | ppl 85.82
#
# Epoch 59 complete — avg loss: 4.4523 | ppl 85.82
# Epoch checkpoint saved → checkpoints_v1/epoch_59.pt
#
# ============================================================
# Epoch 60/100
# ============================================================
#
# [Epoch 60] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.5152 | avg 4.5152 | ppl 91.39 | last 200 steps: 1.6s | total: 2s
#   step   200 | loss 4.6318 | avg 4.4327 | ppl 84.16 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 4.4664 | ppl 87.05
#
# Epoch 60 complete — avg loss: 4.4664 | ppl 87.05
# Epoch checkpoint saved → checkpoints_v1/epoch_60.pt
#
# ============================================================
# Epoch 61/100
# ============================================================
#
# [Epoch 61] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.5950 | avg 4.5950 | ppl 98.99 | last 200 steps: 1.7s | total: 2s
#   step   200 | loss 4.4362 | avg 4.4263 | ppl 83.62 | last 200 steps: 17.5s | total: 19s
#   Shard done — avg loss: 4.4411 | ppl 84.87
#
# Epoch 61 complete — avg loss: 4.4411 | ppl 84.87
# Epoch checkpoint saved → checkpoints_v1/epoch_61.pt
#
# ============================================================
# Epoch 62/100
# ============================================================
#
# [Epoch 62] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.3522 | avg 4.3522 | ppl 77.65 | last 200 steps: 1.5s | total: 2s
#   step   200 | loss 4.4770 | avg 4.4621 | ppl 86.67 | last 200 steps: 17.5s | total: 19s
#   Shard done — avg loss: 4.4595 | ppl 86.45
#
# Epoch 62 complete — avg loss: 4.4595 | ppl 86.45
# Epoch checkpoint saved → checkpoints_v1/epoch_62.pt
#
# ============================================================
# Epoch 63/100
# ============================================================
#
# [Epoch 63] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.2600 | avg 4.2600 | ppl 70.81 | last 200 steps: 1.6s | total: 2s
#   step   200 | loss 4.3064 | avg 4.4091 | ppl 82.19 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 4.4158 | ppl 82.75
#
# Epoch 63 complete — avg loss: 4.4158 | ppl 82.75
# Epoch checkpoint saved → checkpoints_v1/epoch_63.pt
#
# ============================================================
# Epoch 64/100
# ============================================================
#
# [Epoch 64] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.2429 | avg 4.2429 | ppl 69.61 | last 200 steps: 2.5s | total: 3s
#   step   200 | loss 4.5933 | avg 4.3286 | ppl 75.84 | last 200 steps: 17.4s | total: 20s
#   Shard done — avg loss: 4.3520 | ppl 77.63
#
# Epoch 64 complete — avg loss: 4.3520 | ppl 77.63
# Epoch checkpoint saved → checkpoints_v1/epoch_64.pt
#
# ============================================================
# Epoch 65/100
# ============================================================
#
# [Epoch 65] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.5130 | avg 4.5130 | ppl 91.20 | last 200 steps: 2.0s | total: 2s
#   step   200 | loss 4.4498 | avg 4.3523 | ppl 77.66 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 4.3812 | ppl 79.93
#
# Epoch 65 complete — avg loss: 4.3812 | ppl 79.93
# Epoch checkpoint saved → checkpoints_v1/epoch_65.pt
#
# ============================================================
# Epoch 66/100
# ============================================================
#
# [Epoch 66] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.2985 | avg 4.2985 | ppl 73.59 | last 200 steps: 2.2s | total: 2s
#   step   200 | loss 4.2792 | avg 4.3363 | ppl 76.43 | last 200 steps: 17.3s | total: 20s
#   Shard done — avg loss: 4.3507 | ppl 77.54
#
# Epoch 66 complete — avg loss: 4.3507 | ppl 77.54
# Epoch checkpoint saved → checkpoints_v1/epoch_66.pt
#
# ============================================================
# Epoch 67/100
# ============================================================
#
# [Epoch 67] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.1286 | avg 4.1286 | ppl 62.09 | last 200 steps: 2.1s | total: 2s
#   step   200 | loss 4.2198 | avg 4.2947 | ppl 73.31 | last 200 steps: 17.5s | total: 20s
#   Shard done — avg loss: 4.3255 | ppl 75.61
#
# Epoch 67 complete — avg loss: 4.3255 | ppl 75.61
# Epoch checkpoint saved → checkpoints_v1/epoch_67.pt
#
# ============================================================
# Epoch 68/100
# ============================================================
#
# [Epoch 68] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.2816 | avg 4.2816 | ppl 72.35 | last 200 steps: 2.1s | total: 2s
#   step   200 | loss 4.6244 | avg 4.3212 | ppl 75.28 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 4.3508 | ppl 77.54
#
# Epoch 68 complete — avg loss: 4.3508 | ppl 77.54
# Epoch checkpoint saved → checkpoints_v1/epoch_68.pt
#
# ============================================================
# Epoch 69/100
# ============================================================
#
# [Epoch 69] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.0906 | avg 4.0906 | ppl 59.78 | last 200 steps: 2.6s | total: 3s
#   step   200 | loss 4.1485 | avg 4.2385 | ppl 69.30 | last 200 steps: 17.4s | total: 20s
#   Shard done — avg loss: 4.2671 | ppl 71.31
#
# Epoch 69 complete — avg loss: 4.2671 | ppl 71.31
# Epoch checkpoint saved → checkpoints_v1/epoch_69.pt
#
# ============================================================
# Epoch 70/100
# ============================================================
#
# [Epoch 70] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.8616 | avg 3.8616 | ppl 47.54 | last 200 steps: 2.0s | total: 2s
#   step   200 | loss 4.4624 | avg 4.2235 | ppl 68.27 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 4.2472 | ppl 69.91
#
# Epoch 70 complete — avg loss: 4.2472 | ppl 69.91
# Epoch checkpoint saved → checkpoints_v1/epoch_70.pt
#
# ============================================================
# Epoch 71/100
# ============================================================
#
# [Epoch 71] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.5355 | avg 4.5355 | ppl 93.27 | last 200 steps: 1.7s | total: 2s
#   step   200 | loss 4.4802 | avg 4.1828 | ppl 65.55 | last 200 steps: 17.6s | total: 19s
#   Shard done — avg loss: 4.2046 | ppl 67.00
#
# Epoch 71 complete — avg loss: 4.2046 | ppl 67.00
# Epoch checkpoint saved → checkpoints_v1/epoch_71.pt
#
# ============================================================
# Epoch 72/100
# ============================================================
#
# [Epoch 72] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.1002 | avg 4.1002 | ppl 60.35 | last 200 steps: 1.8s | total: 2s
#   step   200 | loss 4.1178 | avg 4.1486 | ppl 63.35 | last 200 steps: 17.5s | total: 19s
#   Shard done — avg loss: 4.1545 | ppl 63.72
#
# Epoch 72 complete — avg loss: 4.1545 | ppl 63.72
# Epoch checkpoint saved → checkpoints_v1/epoch_72.pt
#
# ============================================================
# Epoch 73/100
# ============================================================
#
# [Epoch 73] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.8374 | avg 3.8374 | ppl 46.41 | last 200 steps: 1.6s | total: 2s
#   step   200 | loss 4.0308 | avg 4.1801 | ppl 65.37 | last 200 steps: 17.3s | total: 19s
#   Shard done — avg loss: 4.2013 | ppl 66.77
#
# Epoch 73 complete — avg loss: 4.2013 | ppl 66.77
# Epoch checkpoint saved → checkpoints_v1/epoch_73.pt
#
# ============================================================
# Epoch 74/100
# ============================================================
#
# [Epoch 74] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.9147 | avg 3.9147 | ppl 50.13 | last 200 steps: 2.2s | total: 2s
#   step   200 | loss 4.1351 | avg 4.1751 | ppl 65.05 | last 200 steps: 17.4s | total: 20s
#   Shard done — avg loss: 4.1805 | ppl 65.40
#
# Epoch 74 complete — avg loss: 4.1805 | ppl 65.40
# Epoch checkpoint saved → checkpoints_v1/epoch_74.pt
#
# ============================================================
# Epoch 75/100
# ============================================================
#
# [Epoch 75] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.0145 | avg 4.0145 | ppl 55.40 | last 200 steps: 2.6s | total: 3s
#   step   200 | loss 4.1067 | avg 4.1871 | ppl 65.83 | last 200 steps: 17.4s | total: 20s
#   Shard done — avg loss: 4.2007 | ppl 66.73
#
# Epoch 75 complete — avg loss: 4.2007 | ppl 66.73
# Epoch checkpoint saved → checkpoints_v1/epoch_75.pt
#
# ============================================================
# Epoch 76/100
# ============================================================
#
# [Epoch 76] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.2316 | avg 4.2316 | ppl 68.83 | last 200 steps: 2.2s | total: 2s
#   step   200 | loss 4.4170 | avg 4.1336 | ppl 62.40 | last 200 steps: 17.5s | total: 20s
#   Shard done — avg loss: 4.1625 | ppl 64.23
#
# Epoch 76 complete — avg loss: 4.1625 | ppl 64.23
# Epoch checkpoint saved → checkpoints_v1/epoch_76.pt
#
# ============================================================
# Epoch 77/100
# ============================================================
#
# [Epoch 77] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.1841 | avg 4.1841 | ppl 65.64 | last 200 steps: 2.1s | total: 2s
#   step   200 | loss 4.4919 | avg 4.1575 | ppl 63.91 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 4.1658 | ppl 64.44
#
# Epoch 77 complete — avg loss: 4.1658 | ppl 64.44
# Epoch checkpoint saved → checkpoints_v1/epoch_77.pt
#
# ============================================================
# Epoch 78/100
# ============================================================
#
# [Epoch 78] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.0639 | avg 4.0639 | ppl 58.20 | last 200 steps: 1.6s | total: 2s
#   step   200 | loss 4.1367 | avg 4.0867 | ppl 59.55 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 4.0921 | ppl 59.87
#
# Epoch 78 complete — avg loss: 4.0921 | ppl 59.87
# Epoch checkpoint saved → checkpoints_v1/epoch_78.pt
#
# ============================================================
# Epoch 79/100
# ============================================================
#
# [Epoch 79] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.9893 | avg 3.9893 | ppl 54.02 | last 200 steps: 1.6s | total: 2s
#   step   200 | loss 4.5361 | avg 4.1303 | ppl 62.20 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 4.1579 | ppl 63.94
#
# Epoch 79 complete — avg loss: 4.1579 | ppl 63.94
# Epoch checkpoint saved → checkpoints_v1/epoch_79.pt
#
# ============================================================
# Epoch 80/100
# ============================================================
#
# [Epoch 80] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.1763 | avg 4.1763 | ppl 65.12 | last 200 steps: 1.7s | total: 2s
#   step   200 | loss 4.2543 | avg 4.1282 | ppl 62.07 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 4.1342 | ppl 62.44
#
# Epoch 80 complete — avg loss: 4.1342 | ppl 62.44
# Epoch checkpoint saved → checkpoints_v1/epoch_80.pt
#
# ============================================================
# Epoch 81/100
# ============================================================
#
# [Epoch 81] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.0882 | avg 4.0882 | ppl 59.63 | last 200 steps: 1.6s | total: 2s
#   step   200 | loss 4.0349 | avg 3.9828 | ppl 53.66 | last 200 steps: 17.5s | total: 19s
#   Shard done — avg loss: 3.9984 | ppl 54.51
#
# Epoch 81 complete — avg loss: 3.9984 | ppl 54.51
# Epoch checkpoint saved → checkpoints_v1/epoch_81.pt
#
# ============================================================
# Epoch 82/100
# ============================================================
#
# [Epoch 82] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.8429 | avg 3.8429 | ppl 46.66 | last 200 steps: 1.6s | total: 2s
#   step   200 | loss 4.1125 | avg 4.0150 | ppl 55.43 | last 200 steps: 17.5s | total: 19s
#   Shard done — avg loss: 4.0405 | ppl 56.85
#
# Epoch 82 complete — avg loss: 4.0405 | ppl 56.85
# Epoch checkpoint saved → checkpoints_v1/epoch_82.pt
#
# ============================================================
# Epoch 83/100
# ============================================================
#
# [Epoch 83] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.9563 | avg 3.9563 | ppl 52.26 | last 200 steps: 2.3s | total: 2s
#   step   200 | loss 4.1770 | avg 4.0399 | ppl 56.82 | last 200 steps: 17.3s | total: 20s
#   Shard done — avg loss: 4.0759 | ppl 58.91
#
# Epoch 83 complete — avg loss: 4.0759 | ppl 58.91
# Epoch checkpoint saved → checkpoints_v1/epoch_83.pt
#
# ============================================================
# Epoch 84/100
# ============================================================
#
# [Epoch 84] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.1718 | avg 4.1718 | ppl 64.83 | last 200 steps: 2.2s | total: 2s
#   step   200 | loss 3.9787 | avg 3.9898 | ppl 54.04 | last 200 steps: 17.5s | total: 20s
#   Shard done — avg loss: 4.0056 | ppl 54.90
#
# Epoch 84 complete — avg loss: 4.0056 | ppl 54.90
# Epoch checkpoint saved → checkpoints_v1/epoch_84.pt
#
# ============================================================
# Epoch 85/100
# ============================================================
#
# [Epoch 85] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 4.0839 | avg 4.0839 | ppl 59.37 | last 200 steps: 2.0s | total: 2s
#   step   200 | loss 3.9896 | avg 3.8836 | ppl 48.60 | last 200 steps: 17.5s | total: 19s
#   Shard done — avg loss: 3.9065 | ppl 49.72
#
# Epoch 85 complete — avg loss: 3.9065 | ppl 49.72
# Epoch checkpoint saved → checkpoints_v1/epoch_85.pt
#
# ============================================================
# Epoch 86/100
# ============================================================
#
# [Epoch 86] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.7919 | avg 3.7919 | ppl 44.34 | last 200 steps: 1.9s | total: 2s
#   step   200 | loss 4.1049 | avg 3.9927 | ppl 54.20 | last 200 steps: 17.3s | total: 19s
#   Shard done — avg loss: 4.0251 | ppl 55.99
#
# Epoch 86 complete — avg loss: 4.0251 | ppl 55.99
# Epoch checkpoint saved → checkpoints_v1/epoch_86.pt
#
# ============================================================
# Epoch 87/100
# ============================================================
#
# [Epoch 87] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.9023 | avg 3.9023 | ppl 49.52 | last 200 steps: 1.6s | total: 2s
#   step   200 | loss 3.9819 | avg 3.9889 | ppl 53.99 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 3.9935 | ppl 54.24
#
# Epoch 87 complete — avg loss: 3.9935 | ppl 54.24
# Epoch checkpoint saved → checkpoints_v1/epoch_87.pt
#
# ============================================================
# Epoch 88/100
# ============================================================
#
# [Epoch 88] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.8780 | avg 3.8780 | ppl 48.33 | last 200 steps: 2.5s | total: 2s
#   step   200 | loss 3.9551 | avg 3.9558 | ppl 52.24 | last 200 steps: 17.4s | total: 20s
#   Shard done — avg loss: 3.9666 | ppl 52.80
#
# Epoch 88 complete — avg loss: 3.9666 | ppl 52.80
# Epoch checkpoint saved → checkpoints_v1/epoch_88.pt
#
# ============================================================
# Epoch 89/100
# ============================================================
#
# [Epoch 89] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.5867 | avg 3.5867 | ppl 36.11 | last 200 steps: 1.6s | total: 2s
#   step   200 | loss 3.8668 | avg 3.8766 | ppl 48.26 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 3.8823 | ppl 48.53
#
# Epoch 89 complete — avg loss: 3.8823 | ppl 48.53
# Epoch checkpoint saved → checkpoints_v1/epoch_89.pt
#
# ============================================================
# Epoch 90/100
# ============================================================
#
# [Epoch 90] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.8753 | avg 3.8753 | ppl 48.20 | last 200 steps: 2.5s | total: 2s
#   step   200 | loss 4.0146 | avg 3.9451 | ppl 51.68 | last 200 steps: 17.5s | total: 20s
#   Shard done — avg loss: 3.9473 | ppl 51.79
#
# Epoch 90 complete — avg loss: 3.9473 | ppl 51.79
# Epoch checkpoint saved → checkpoints_v1/epoch_90.pt
#
# ============================================================
# Epoch 91/100
# ============================================================
#
# [Epoch 91] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.4808 | avg 3.4808 | ppl 32.48 | last 200 steps: 1.9s | total: 2s
#   step   200 | loss 3.8574 | avg 3.9017 | ppl 49.49 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 3.9118 | ppl 49.99
#
# Epoch 91 complete — avg loss: 3.9118 | ppl 49.99
# Epoch checkpoint saved → checkpoints_v1/epoch_91.pt
#
# ============================================================
# Epoch 92/100
# ============================================================
#
# [Epoch 92] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.6924 | avg 3.6924 | ppl 40.14 | last 200 steps: 1.7s | total: 2s
#   step   200 | loss 4.0244 | avg 3.9725 | ppl 53.12 | last 200 steps: 17.3s | total: 19s
#   Shard done — avg loss: 3.9663 | ppl 52.79
#
# Epoch 92 complete — avg loss: 3.9663 | ppl 52.79
# Epoch checkpoint saved → checkpoints_v1/epoch_92.pt
#
# ============================================================
# Epoch 93/100
# ============================================================
#
# [Epoch 93] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.5754 | avg 3.5754 | ppl 35.71 | last 200 steps: 2.2s | total: 2s
#   step   200 | loss 4.2521 | avg 3.8472 | ppl 46.86 | last 200 steps: 17.5s | total: 20s
#   Shard done — avg loss: 3.8716 | ppl 48.02
#
# Epoch 93 complete — avg loss: 3.8716 | ppl 48.02
# Epoch checkpoint saved → checkpoints_v1/epoch_93.pt
#
# ============================================================
# Epoch 94/100
# ============================================================
#
# [Epoch 94] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.7568 | avg 3.7568 | ppl 42.81 | last 200 steps: 2.1s | total: 2s
#   step   200 | loss 4.0440 | avg 3.9309 | ppl 50.95 | last 200 steps: 17.4s | total: 20s
#   Shard done — avg loss: 3.9307 | ppl 50.94
#
# Epoch 94 complete — avg loss: 3.9307 | ppl 50.94
# Epoch checkpoint saved → checkpoints_v1/epoch_94.pt
#
# ============================================================
# Epoch 95/100
# ============================================================
#
# [Epoch 95] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.7080 | avg 3.7080 | ppl 40.77 | last 200 steps: 2.3s | total: 2s
#   step   200 | loss 3.9152 | avg 3.8504 | ppl 47.01 | last 200 steps: 17.4s | total: 20s
#   Shard done — avg loss: 3.8656 | ppl 47.73
#
# Epoch 95 complete — avg loss: 3.8656 | ppl 47.73
# Epoch checkpoint saved → checkpoints_v1/epoch_95.pt
#
# ============================================================
# Epoch 96/100
# ============================================================
#
# [Epoch 96] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.7732 | avg 3.7732 | ppl 43.52 | last 200 steps: 2.0s | total: 2s
#   step   200 | loss 3.9444 | avg 3.8938 | ppl 49.10 | last 200 steps: 17.3s | total: 19s
#   Shard done — avg loss: 3.9023 | ppl 49.52
#
# Epoch 96 complete — avg loss: 3.9023 | ppl 49.52
# Epoch checkpoint saved → checkpoints_v1/epoch_96.pt
#
# ============================================================
# Epoch 97/100
# ============================================================
#
# [Epoch 97] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.8396 | avg 3.8396 | ppl 46.51 | last 200 steps: 2.1s | total: 2s
#   step   200 | loss 4.2000 | avg 3.8577 | ppl 47.36 | last 200 steps: 17.6s | total: 20s
#   Shard done — avg loss: 3.8888 | ppl 48.85
#
# Epoch 97 complete — avg loss: 3.8888 | ppl 48.85
# Epoch checkpoint saved → checkpoints_v1/epoch_97.pt
#
# ============================================================
# Epoch 98/100
# ============================================================
#
# [Epoch 98] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.9421 | avg 3.9421 | ppl 51.53 | last 200 steps: 2.1s | total: 2s
#   step   200 | loss 3.7204 | avg 3.8015 | ppl 44.77 | last 200 steps: 17.5s | total: 20s
#   Shard done — avg loss: 3.8301 | ppl 46.07
#
# Epoch 98 complete — avg loss: 3.8301 | ppl 46.07
# Epoch checkpoint saved → checkpoints_v1/epoch_98.pt
#
# ============================================================
# Epoch 99/100
# ============================================================
#
# [Epoch 99] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.8370 | avg 3.8370 | ppl 46.39 | last 200 steps: 1.7s | total: 2s
#   step   200 | loss 4.0076 | avg 3.8834 | ppl 48.59 | last 200 steps: 17.5s | total: 19s
#   Shard done — avg loss: 3.9019 | ppl 49.50
#
# Epoch 99 complete — avg loss: 3.9019 | ppl 49.50
# Epoch checkpoint saved → checkpoints_v1/epoch_99.pt
#
# ============================================================
# Epoch 100/100
# ============================================================
#
# [Epoch 100] Shard 1/1 — shard_0000.pt
# 268436159
# 1000000
#   step     0 | loss 3.7487 | avg 3.7487 | ppl 42.46 | last 200 steps: 1.6s | total: 2s
#   step   200 | loss 3.9869 | avg 3.8135 | ppl 45.31 | last 200 steps: 17.4s | total: 19s
#   Shard done — avg loss: 3.8314 | ppl 46.13
#
# Epoch 100 complete — avg loss: 3.8314 | ppl 46.13
# Epoch checkpoint saved → checkpoints_v1/epoch_100.pt
#
# Training complete.

# %%
latest = "checkpoints_v1/epoch_50.pt"
print(f"Resuming from epoch checkpoint {latest}...")
ckpt = torch.load(latest, map_location=device)
model.load_state_dict(ckpt["model"])
model.to("cuda")
# Out:
# Resuming from epoch checkpoint checkpoints_v1/epoch_50.pt...
# MicroLM(
#   (blocks): ModuleList(
#     (0-3): 4 x TransformerBlock(
#       (norm_1): LayerNorm()
#       (attn): MultiHeadCausalAttention(
#         (W_q): Linear(in_features=384, out_features=384, bias=False)
#         (W_k): Linear(in_features=384, out_features=384, bias=False)
#         (W_v): Linear(in_features=384, out_features=384, bias=False)
#         (W_o): Linear(in_features=384, out_features=384, bias=False)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#       )
#       (norm_2): LayerNorm()
#       (ffn): FeedForward(
#         (W_1): Linear(in_features=384, out_features=512, bias=True)
#         (W_2): Linear(in_features=512, out_features=384, bias=True)
#       )
#       (drop): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (norm): LayerNorm()
# )

# %%
# ── Inference ─────────────────────────────────────────────────────────────────
from tokenizers import Tokenizer

tok = Tokenizer.from_file("tokenizer/tokenizer.json")

# Special token IDs
BOS_ID       = 2
EOS_ID       = 3
USER_ID      = 5
ASSISTANT_ID = 6

SPECIAL_IDS = set()  # 0-49, all special tokens
MAX_SEQ = 2048
def generate(prompt, max_new_tokens=200, temperature=0.8, top_k=1, mode="text"):
    ids = tok.encode(prompt).ids

    if mode == "text":
        ids = [BOS_ID] + ids
    elif mode == "chat":
        ids = [BOS_ID, USER_ID] + ids + [ASSISTANT_ID]

    x = torch.tensor([ids], dtype=torch.long).to(device)

    with torch.no_grad():
        for _ in range(max_new_tokens):
            logits = model(x[:, -MAX_SEQ:])
            logits = logits[:, -1, :] / temperature
            top_vals, top_idx = torch.topk(logits, top_k)
            probs   = torch.softmax(top_vals, dim=-1)
            next_id = top_idx[0][torch.multinomial(probs, 1)]
            x = torch.cat([x, next_id.view(1, 1)], dim=1)
            if next_id.item() == EOS_ID:
                break

    # manually filter special token IDs before decoding
    clean_ids = [t for t in x[0].tolist() if t not in SPECIAL_IDS]
    return tok.decode(clean_ids)

# ── Text generation prompts ───────────────────────────────────────────────────

text_prompts = [
    "Tori's Health Step by Step coming soon"
    # "The quick brown fox",
    # "Once upon a time",
    # "What should i do ? i love her.",
    # "Tell me about a girl named lola and her pet elephant"
]

print("=" * 60)
print("TEXT GENERATION MODE")
print("=" * 60)
for prompt in text_prompts:
    print(f"\nPrompt : {prompt}")
    print(f"Output : {generate(prompt, mode='chat')}")
# Out:
# ============================================================
# TEXT GENERATION MODE
# ============================================================
#
# Prompt : Tori's Health Step by Step coming soon
# Output : Tori's Health Step by Step coming sooneals, theFirst .
#  theFirstthing goes That The way , the Film doesn't actually Be comfortable , even In Any positive hit positive.the hitsens Oklahoma ,THE musical- W att turned The hitting putting anyone's film and The same scene were".
# THE " explose " behavior," Hence The song's finished Point, Of Course Because, this wasn't The build, really were " reallywas gone. and of Course,the scene realized.Butthe sameing tale ofthe playsof this. thecaseofTHEoneOpen storyHereis " close." theone Can causing That. it won'tinesout there ,Butit won't go Out that,but it wasn'tthething ThatitWould bringin The second simultaneously In(THE classificationthatThey won'tHave been focused;as extremely harder,which The sameuisance we really just say." ultimately, otherwise The same reminds meets,"I thinks is H Oick In front." Because even,the whole

# %%
import torch
import torch.nn as nn
import numpy as np
import math
import time

# Load frozen embedding table
embedding_table = np.load("tokenizer_v3/token_embeddings.npy")
embedding_tensor = torch.tensor(embedding_table, dtype=torch.float32)

VOCAB_SIZE    = embedding_tensor.shape[0]   # 4096
MINILM_DIM    = embedding_tensor.shape[1]   # 384
print(f"Vocab size : {VOCAB_SIZE}")
print(f"MiniLM dim : {MINILM_DIM}")
# Out:
# Vocab size : 16384
# MiniLM dim : 384

# %%
import torch.nn.functional as F 

DIM      = 384
EXPANDED_DIM = 512
N_HEADS  = 4
N_LAYERS = 4
FFN_DIM  = 768
HEAD_DIM = DIM // N_HEADS 

def sinusoidal_encoding(seq_len, dim, device):
    pe       = torch.zeros(seq_len, dim, device=device)
    position = torch.arange(seq_len, device=device).unsqueeze(1)
    div_term = torch.exp(torch.arange(0, dim, 2, device=device) * (-math.log(10000.0) / dim))
    pe[:, 0::2] = torch.sin(position * div_term)
    pe[:, 1::2] = torch.cos(position * div_term)
    return pe  # (seq_len, dim)

class LayerNorm(nn.Module):
    """
    y = ((x - mean) / sqrt(var + eps)) * gamma + beta
    gamma, beta are learned per-feature scalars — shape (dim,)
    """
    def __init__(self, dim, eps=1e-5):
        super().__init__()
        self.eps   = eps
        self.gamma = nn.Parameter(torch.ones(dim))   # scale
        self.beta  = nn.Parameter(torch.zeros(dim))  # shift

    def forward(self, x):
        mean = x.mean(dim=-1, keepdim=True)           # (B, T, 1)
        var  = x.var(dim=-1, keepdim=True, unbiased=False)  # (B, T, 1)
        x_norm = (x - mean) / torch.sqrt(var + self.eps)    # (B, T, D)
        return self.gamma * x_norm + self.beta               # (B, T, D)

class MultiHeadCausalAttention(nn.Module):
    """
    Projects input into Q, K, V — splits into H heads — computes scaled
    dot-product attention with a causal mask — concatenates heads — projects out.

    Q = x W_q      shape: (B, T, D)
    K = x W_k      shape: (B, T, D)
    V = x W_v      shape: (B, T, D)

    Reshape to (B, H, T, head_dim), then:
        scores = Q @ Kᵀ / sqrt(head_dim)    (B, H, T, T)
        scores = scores + causal_mask        (upper triangle = -inf)
        weights = softmax(scores, dim=-1)    (B, H, T, T)
        out = weights @ V                    (B, H, T, head_dim)

    Concat heads → (B, T, D), project out via W_o
    """
    def __init__(self, dim, n_heads, dropout=0.1):
        super().__init__()
        assert dim % n_heads == 0, "dim must be divisible by n_heads"
        self.n_heads  = n_heads
        self.head_dim = dim // n_heads       # 48
        self.scale    = self.head_dim ** -0.5

        self.W_q = nn.Linear(dim, dim, bias=False)
        self.W_k = nn.Linear(dim, dim, bias=False)
        self.W_v = nn.Linear(dim, dim, bias=False)
        self.W_o = nn.Linear(dim, dim, bias=False)

        self.attn_drop = nn.Dropout(dropout)

    def forward(self, x):
        B, T, D = x.shape

        # --- Project & split into heads ---
        Q = self.W_q(x)  # (B, T, D)
        K = self.W_k(x)  # (B, T, D)
        V = self.W_v(x)  # (B, T, D)

        # Reshape: (B, T, D) → (B, H, T, head_dim)
        Q = Q.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)
        K = K.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)
        V = V.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)

        # --- Scaled dot-product attention ---
        # (B, H, T, head_dim) @ (B, H, head_dim, T) → (B, H, T, T)
        scores = (Q @ K.transpose(-2, -1)) * self.scale

        # Causal mask: positions can only attend to themselves and earlier tokens
        # Upper triangle (future tokens) set to -inf → softmax drives them to 0
        causal_mask = torch.triu(
            torch.ones(T, T, device=x.device, dtype=torch.bool), diagonal=1
        )
        scores = scores.masked_fill(causal_mask, float('-inf'))

        weights = torch.softmax(scores, dim=-1)  # (B, H, T, T)
        weights = self.attn_drop(weights)

        # (B, H, T, T) @ (B, H, T, head_dim) → (B, H, T, head_dim)
        out = weights @ V

        # --- Concat heads & project ---
        # (B, H, T, head_dim) → (B, T, H*head_dim) = (B, T, D)
        out = out.transpose(1, 2).contiguous().view(B, T, D)
        return self.W_o(out)  # (B, T, D)

class FeedForward(nn.Module):
    """
    Two-layer MLP with GELU activation.
    FFN(x) = GELU(x W_1 + b_1) W_2 + b_2

    Expands dim → ffn_dim (wider representation),
    then projects back down ffn_dim → dim.
    """
    def __init__(self, dim, ffn_dim, dropout=0.1):
        super().__init__()
        self.W_1 = nn.Linear(dim, ffn_dim)       # expand
        self.W_2 = nn.Linear(ffn_dim, dim)       # contract
        self.drop = nn.Dropout(dropout)

    def forward(self, x):
        x = F.gelu(self.W_1(x))   # (B, T, ffn_dim)
        x = self.drop(x)
        x = self.W_2(x)           # (B, T, dim)
        return x

class TransformerBlock(nn.Module):
    """
    Pre-norm residual block (norm_first=True, same as your original config).

    x = x + Attention(LayerNorm(x))   ← self-attention sub-layer
    x = x + FFN(LayerNorm(x))         ← feed-forward sub-layer

    Pre-norm (LN before the sub-layer) stabilises training at depth
    vs post-norm (LN after the residual add).
    """
    def __init__(self, dim, n_heads, ffn_dim, dropout=0.1):
        super().__init__()
        self.norm_1 = LayerNorm(dim)
        self.attn   = MultiHeadCausalAttention(dim, n_heads, dropout)
        self.norm_2 = LayerNorm(dim)
        self.ffn    = FeedForward(dim, ffn_dim, dropout)
        self.drop   = nn.Dropout(dropout)

    def forward(self, x):
        x = x + self.drop(self.attn(self.norm_1(x)))  # (B, T, D)
        x = x + self.drop(self.ffn(self.norm_2(x)))   # (B, T, D)
        return x

class MicroLM(nn.Module):
    """
    Full architecture:
      1. Frozen MiniLM embedding lookup         → (B, T, 384)
      2. Sinusoidal positional encoding added   → (B, T, 384)
      3. N_LAYERS x TransformerBlock            → (B, T, 384)
      4. Final LayerNorm                        → (B, T, 384)
      5. Linear output head → logits            → (B, T, VOCAB_SIZE)
    """
    def __init__(self):
        super().__init__()
        self.register_buffer("embedding_table", embedding_tensor)

        # Expander 384 → 512 (trainable)
        self.expander = nn.Sequential(
            nn.Linear(MINILM_DIM, EXPANDED_DIM),
            nn.LayerNorm(EXPANDED_DIM),
        )
        
        self.blocks = nn.ModuleList([
            TransformerBlock(EXPANDED_DIM, N_HEADS, FFN_DIM, dropout=0.1)
            for _ in range(N_LAYERS)
        ])

        self.norm        = LayerNorm(EXPANDED_DIM)
        self.output_head = nn.Linear(EXPANDED_DIM, VOCAB_SIZE, bias=False)

    def forward(self, token_ids):
        B, T = token_ids.shape

        x = self.embedding_table[token_ids]                    # (B, T, 512)
        x = self.expander(x)
        x = x + sinusoidal_encoding(T, EXPANDED_DIM, token_ids.device) # (B, T, 512)

        for block in self.blocks:
            x = block(x)   # (B, T, 512)

        x = self.norm(x)
        return self.output_head(x)  # (B, T, VOCAB_SIZE)

# %%
model     = MicroLM()
total     = sum(p.numel() for p in model.parameters())
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
frozen    = total - trainable

print(f"Trainable params : {trainable:,}")
print(f"Frozen params    : {frozen:,}  (embedding table)")
print(f"Total params     : {total:,}")

# print(f"\nParam breakdown:")
# for name, p in model.named_parameters():
#     if p.requires_grad:
#         print(f"  {name:55s} {p.numel():>10,}")

# Forward pass
x      = torch.randint(0, VOCAB_SIZE, (2, 32))
logits = model(x)
print(f"\nInput  : {x.shape}")
print(f"Output : {logits.shape}")
# Out:
# Trainable params : 15,941,120
# Frozen params    : 0  (embedding table)
# Total params     : 15,941,120
#
# Input  : torch.Size([2, 32])
# Output : torch.Size([2, 32, 16384])

# %%
# ── Training Config ───────────────────────────────────────────────────────────
import gc
import json
import random
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from pathlib import Path

SHARD_DIR  = Path("dataset_shards_v2")
SEQ_LEN    = 512
BATCH_SIZE = 32
N_EPOCHS   = 3
LOG_EVERY  = 200
CKPT_DIR   = Path("checkpoints_v5")
CKPT_DIR.mkdir(parents=True, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device      : {device}")
print(f"Model params: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# Device      : cuda
# Model params: 15,941,120

# %%
from torch.utils.data import Dataset

SEQ_LEN = 512    # window size
STRIDE  = 448    # step size → 64-token overlap

class ShardDataset(Dataset):
    def __init__(self, shard_path, seq_len=SEQ_LEN, stride=STRIDE):
        flat = torch.load(shard_path, weights_only=True)

        self.flat    = flat.to(torch.int16)
        self.seq_len = seq_len
        self.stride  = stride

        # number of full windows we can extract
        # +1 because we need seq_len+1 tokens (x + y target)
        n_tokens = len(self.flat)
        self.num_samples = max(0, (n_tokens - seq_len - 1) // stride + 1)

    def __len__(self):
        return self.num_samples

    def __getitem__(self, idx):
        start  = idx * self.stride
        tokens = self.flat[start : start + self.seq_len + 1].to(torch.long)  # ← cast here
        
        if len(tokens) < self.seq_len + 1:
            pad    = torch.full((self.seq_len + 1 - len(tokens),), PAD_ID, dtype=torch.long)
            tokens = torch.cat([tokens, pad])

        x = tokens[:-1]
        y = tokens[1:]
        return x, y


BOS_ID       = 2
EOS_ID       = 3

def collate_fn(batch):
    xs, ys = zip(*batch)
    # all samples are now fixed-length (seq_len), so no padding needed here
    x_pad = torch.stack(xs)          # [B, seq_len]
    y_pad = torch.stack(ys).clone()  # [B, seq_len]

    # mask out targets after the first EOS in each sequence
    for i, y in enumerate(y_pad):
        eos_positions = (y == EOS_ID).nonzero(as_tuple=True)[0]
        if len(eos_positions) > 0:
            eos_pos = eos_positions[0].item()
            if eos_pos + 1 < y.size(0):
                y_pad[i, eos_pos + 1:] = -100

    return x_pad, y_pad

# %% [markdown]
# from tokenizers import Tokenizer
# TOKENIZER_PATH   = "tokenizer/tokenizer.json"
# tokenizer = Tokenizer.from_file(TOKENIZER_PATH)
# dataset = ShardDataset("dataset_shards/shard_0000.pt")
# for i in range(10,11):
#     x, y = dataset[i]
#     print(f"\nSample {i}")
#     print(f"  x: {x.tolist()}")
#     print(f"  y: {tokenizer.decode(x.tolist(), skip_special_tokens=False)}")
#     # print(f"  y: {y.tolist()}")
# for idx  in x.tolist():
#     tok = tokenizer.decode([idx], skip_special_tokens=False)
#     print(f"{idx} === '{tok}' ")

# %%
# run once after sharding
# meta = {
#     "total_samples": sum(len(ShardDataset(p)) for p in sorted(SHARD_DIR.glob("shard_*.pt"))),
#     "seq_len": SEQ_LEN,
#     "stride": STRIDE,
# }
# with open(SHARD_DIR / "meta.json", "w") as f:
#     json.dump(meta, f, indent=2)
    
# ── Optimizer & Scheduler ─────────────────────────────────────────────────────

with open(SHARD_DIR / "meta.json") as f:
    meta = json.load(f)

total_steps = (meta['total_samples'] // BATCH_SIZE) * N_EPOCHS

optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4, weight_decay=0.1)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=total_steps, eta_min=1e-5
)
scaler    = torch.cuda.amp.GradScaler()

print(f"Total samples: {meta['total_samples']:,}")
print(f"Total steps  : {total_steps:,}")
# Out:
# Total samples: 3,601,677
# Total steps  : 337,656
# /tmp/ipykernel_29612/892036717.py:21: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler    = torch.cuda.amp.GradScaler()

# %%
model.to(device)
# Out:
# MicroLM(
#   (expander): Sequential(
#     (0): Linear(in_features=384, out_features=512, bias=True)
#     (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (blocks): ModuleList(
#     (0-3): 4 x TransformerBlock(
#       (norm_1): LayerNorm()
#       (attn): MultiHeadCausalAttention(
#         (W_q): Linear(in_features=512, out_features=512, bias=False)
#         (W_k): Linear(in_features=512, out_features=512, bias=False)
#         (W_v): Linear(in_features=512, out_features=512, bias=False)
#         (W_o): Linear(in_features=512, out_features=512, bias=False)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#       )
#       (norm_2): LayerNorm()
#       (ffn): FeedForward(
#         (W_1): Linear(in_features=512, out_features=768, bias=True)
#         (W_2): Linear(in_features=768, out_features=512, bias=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#       (drop): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (norm): LayerNorm()
#   (output_head): Linear(in_features=512, out_features=16384, bias=False)
# )

# %%
shard_files  = sorted(SHARD_DIR.glob("shard_*.pt"))[:2]
shard_files
# Out:
# [PosixPath('dataset_shards_v2/shard_0000.pt'),
#  PosixPath('dataset_shards_v2/shard_0001.pt')]

# %%
# ── Training Loop with Resume ─────────────────────────────────────────────────
import math
shard_files  = sorted(SHARD_DIR.glob("shard_*.pt"))[:2]
shard_files
loss_history = []
start_epoch  = 0
start_shard  = 0

# ── Resume from latest checkpoint ────────────────────────────────────────────
# Check mid-epoch checkpoints first, then epoch checkpoints
all_ckpts = sorted(CKPT_DIR.glob("epoch_*.pt"))
mid_ckpts  = [c for c in all_ckpts if "shard" in c.name]
epoch_ckpts = [c for c in all_ckpts if "shard" not in c.name]

if mid_ckpts:
    latest = mid_ckpts[-1]
    print(f"Resuming from mid-epoch checkpoint {latest}...")
    ckpt = torch.load(latest, map_location=device)
    model.load_state_dict(ckpt["model"])
    optimizer.load_state_dict(ckpt["optimizer"])
    scheduler.load_state_dict(ckpt["scheduler"])
    loss_history = ckpt.get("loss_history", [])
    start_epoch  = ckpt["epoch"] - 1        # epoch is 1-indexed, range is 0-indexed
    start_shard  = ckpt["shard"] + 1        # resume from next shard
    print(f"Resumed — epoch {start_epoch+1}, starting from shard {start_shard+1}")

elif epoch_ckpts:
    latest = epoch_ckpts[-1]
    print(f"Resuming from epoch checkpoint {latest}...")
    ckpt = torch.load(latest, map_location=device)
    model.load_state_dict(ckpt["model"])
    optimizer.load_state_dict(ckpt["optimizer"])
    scheduler.load_state_dict(ckpt["scheduler"])
    loss_history = ckpt.get("loss_history", [])
    start_epoch  = ckpt["epoch"]            # full epoch completed
    start_shard  = 0                        # start from beginning of next epoch
    print(f"Resumed — starting from epoch {start_epoch+1}")

else:
    print("No checkpoint found — training from scratch")

model.to(device)
model.train()

for epoch in range(start_epoch, N_EPOCHS):
    epoch_loss  = 0.0
    epoch_steps = 0

    # no shuffle — sequential shard order
    shard_order = list(range(len(shard_files)))

    # if resuming mid-epoch, skip already completed shards
    if epoch == start_epoch and start_shard > 0:
        shard_order = shard_order[start_shard:]
        print(f"Skipping shards 0-{start_shard-1}, resuming from shard {start_shard}")

    print(f"\n{'='*60}")
    print(f"Epoch {epoch+1}/{N_EPOCHS}")
    print(f"{'='*60}")

    for shard_num, shard_idx in enumerate(shard_order):
        # just before the step loop:
        shard_start = time.time()
        interval_start = time.time()
        
        # actual shard number in epoch (accounts for skipped shards on resume)
        actual_shard_num = shard_idx  

        shard_path = shard_files[shard_idx]
        print(f"\n[Epoch {epoch+1}] Shard {actual_shard_num+1}/{len(shard_files)} — {shard_path.name}")

        ds     = ShardDataset(shard_path)
        loader = DataLoader(
            ds,
            batch_size=BATCH_SIZE,
            shuffle=True,
            collate_fn=collate_fn,
            num_workers=0,
            pin_memory=True,
        )

        shard_loss  = 0.0
        shard_steps = 0

        for step, (x, y) in enumerate(loader):
            x = x.to(device)
            y = y.to(device)

            optimizer.zero_grad()

            with torch.autocast(device_type="cuda", dtype=torch.bfloat16):
                logits = model(x)
                loss   = F.cross_entropy(
                    logits.view(-1, logits.size(-1)),
                    y.view(-1),
                    ignore_index=-100,
                )
                del logits  # free 268MB immediately before backward


            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()

            if not math.isnan(loss.item()):
                shard_loss  += loss.item()
                shard_steps += 1
                epoch_loss  += loss.item()
                epoch_steps += 1

            if step % LOG_EVERY == 0:
                avg = shard_loss / max(shard_steps, 1)
                ppl = math.exp(min(avg, 20))
                lr  = scheduler.get_last_lr()[0]
                elapsed_total = time.time() - shard_start
                interval_time = time.time() - interval_start
                print(f"  step {step:>5} | loss {loss.item():.4f} | avg {avg:.4f} | ppl {ppl:.2f} | lr {lr:.2e} | last {LOG_EVERY} steps: {interval_time:.1f}s | total: {elapsed_total:.0f}s")
                interval_start = time.time()  # reset for next interval

            del loss, x, y
        shard_avg = shard_loss / max(shard_steps, 1)
        shard_ppl = math.exp(min(shard_avg, 20))
        loss_history.append({
            "epoch":      epoch + 1,
            "shard":      actual_shard_num,
            "avg_loss":   shard_avg,
            "perplexity": shard_ppl,
        })
        print(f"  Shard done — avg loss: {shard_avg:.4f} | ppl {shard_ppl:.2f}")

        del ds, loader
        gc.collect()
        torch.cuda.empty_cache()

        # mid-epoch checkpoint every 5 shards
        if (actual_shard_num + 1) % 2 == 0:
            ckpt_path = CKPT_DIR / f"epoch_{epoch+1}_shard_{actual_shard_num}.pt"
            torch.save({
                "epoch":        epoch + 1,
                "shard":        actual_shard_num,
                "model":        model.state_dict(),
                "optimizer":    optimizer.state_dict(),
                "scheduler":    scheduler.state_dict(),
                "loss_history": loss_history,
            }, ckpt_path)
            print(f"Mid-epoch checkpoint saved → {ckpt_path}")

    # reset start_shard after first resumed epoch
    start_shard = 0

    epoch_avg = epoch_loss / max(epoch_steps, 1)
    epoch_ppl = math.exp(min(epoch_avg, 20))
    print(f"\nEpoch {epoch+1} complete — avg loss: {epoch_avg:.4f} | ppl {epoch_ppl:.2f}")

    ckpt_path = CKPT_DIR / f"epoch_{epoch+1}.pt"
    torch.save({
        "epoch":        epoch + 1,
        "shard":        -1,
        "model":        model.state_dict(),
        "optimizer":    optimizer.state_dict(),
        "scheduler":    scheduler.state_dict(),
        "loss_history": loss_history,
    }, ckpt_path)
    print(f"Epoch checkpoint saved → {ckpt_path}")

    with open(CKPT_DIR / "loss_history.json", "w") as f:
        json.dump(loss_history, f, indent=2)

print("\nTraining complete.")
# Out:
# No checkpoint found — training from scratch
#
# ============================================================
# Epoch 1/3
# ============================================================
#
# [Epoch 1] Shard 1/2 — shard_0000.pt
#   step     0 | loss 10.0068 | avg 10.0068 | ppl 22176.33 | lr 3.00e-04 | last 200 steps: 2.7s | total: 3s
#   step   200 | loss 3.9317 | avg 4.7240 | ppl 112.62 | lr 3.00e-04 | last 200 steps: 24.8s | total: 28s
#   step   400 | loss 3.4049 | avg 4.1982 | ppl 66.57 | lr 3.00e-04 | last 200 steps: 25.3s | total: 53s
#   step   600 | loss 3.1216 | avg 3.9202 | ppl 50.41 | lr 3.00e-04 | last 200 steps: 25.6s | total: 78s
#   step   800 | loss 3.0723 | avg 3.7336 | ppl 41.83 | lr 3.00e-04 | last 200 steps: 25.8s | total: 104s
#   step  1000 | loss 3.0626 | avg 3.5946 | ppl 36.40 | lr 3.00e-04 | last 200 steps: 25.9s | total: 130s
#   step  1200 | loss 2.8798 | avg 3.4816 | ppl 32.51 | lr 3.00e-04 | last 200 steps: 25.9s | total: 156s
#   step  1400 | loss 2.8468 | avg 3.3909 | ppl 29.69 | lr 3.00e-04 | last 200 steps: 26.0s | total: 182s
#   step  1600 | loss 2.7144 | avg 3.3139 | ppl 27.49 | lr 3.00e-04 | last 200 steps: 25.9s | total: 208s
#   step  1800 | loss 2.6689 | avg 3.2476 | ppl 25.73 | lr 3.00e-04 | last 200 steps: 25.9s | total: 234s
#   step  2000 | loss 2.7411 | avg 3.1906 | ppl 24.30 | lr 3.00e-04 | last 200 steps: 25.9s | total: 260s
#   step  2200 | loss 2.6014 | avg 3.1392 | ppl 23.09 | lr 3.00e-04 | last 200 steps: 25.9s | total: 286s
#   step  2400 | loss 2.6889 | avg 3.0937 | ppl 22.06 | lr 3.00e-04 | last 200 steps: 25.9s | total: 312s
#   step  2600 | loss 2.5878 | avg 3.0516 | ppl 21.15 | lr 3.00e-04 | last 200 steps: 25.9s | total: 337s
#   step  2800 | loss 2.4813 | avg 3.0134 | ppl 20.36 | lr 3.00e-04 | last 200 steps: 25.9s | total: 363s
#   step  3000 | loss 2.5463 | avg 2.9787 | ppl 19.66 | lr 3.00e-04 | last 200 steps: 25.9s | total: 389s
#   step  3200 | loss 2.4338 | avg 2.9467 | ppl 19.04 | lr 3.00e-04 | last 200 steps: 25.9s | total: 415s
#   step  3400 | loss 2.4806 | avg 2.9176 | ppl 18.50 | lr 3.00e-04 | last 200 steps: 25.9s | total: 441s
#   step  3600 | loss 2.4138 | avg 2.8903 | ppl 18.00 | lr 3.00e-04 | last 200 steps: 26.0s | total: 467s
#   step  3800 | loss 2.4355 | avg 2.8652 | ppl 17.55 | lr 3.00e-04 | last 200 steps: 26.0s | total: 493s
#   step  4000 | loss 2.3160 | avg 2.8416 | ppl 17.14 | lr 3.00e-04 | last 200 steps: 26.0s | total: 519s
#   step  4200 | loss 2.2724 | avg 2.8193 | ppl 16.76 | lr 3.00e-04 | last 200 steps: 26.0s | total: 545s
#   step  4400 | loss 2.1680 | avg 2.7985 | ppl 16.42 | lr 3.00e-04 | last 200 steps: 26.0s | total: 571s
#   step  4600 | loss 2.2651 | avg 2.7790 | ppl 16.10 | lr 3.00e-04 | last 200 steps: 26.0s | total: 597s
#   step  4800 | loss 2.3121 | avg 2.7601 | ppl 15.80 | lr 3.00e-04 | last 200 steps: 26.0s | total: 623s
#   step  5000 | loss 2.2828 | avg 2.7425 | ppl 15.53 | lr 3.00e-04 | last 200 steps: 26.0s | total: 649s
#   step  5200 | loss 2.2368 | avg 2.7260 | ppl 15.27 | lr 3.00e-04 | last 200 steps: 26.0s | total: 675s
#   step  5400 | loss 2.3166 | avg 2.7097 | ppl 15.02 | lr 3.00e-04 | last 200 steps: 26.0s | total: 701s
#   step  5600 | loss 2.3858 | avg 2.6946 | ppl 14.80 | lr 3.00e-04 | last 200 steps: 26.0s | total: 727s
#   step  5800 | loss 2.1128 | avg 2.6800 | ppl 14.58 | lr 3.00e-04 | last 200 steps: 26.1s | total: 753s
#   step  6000 | loss 2.2360 | avg 2.6664 | ppl 14.39 | lr 3.00e-04 | last 200 steps: 26.0s | total: 779s
#   step  6200 | loss 2.1758 | avg 2.6532 | ppl 14.20 | lr 3.00e-04 | last 200 steps: 26.0s | total: 805s
#   step  6400 | loss 2.1238 | avg 2.6405 | ppl 14.02 | lr 3.00e-04 | last 200 steps: 26.0s | total: 831s
#   step  6600 | loss 2.1430 | avg 2.6285 | ppl 13.85 | lr 3.00e-04 | last 200 steps: 26.0s | total: 857s
#   step  6800 | loss 2.2297 | avg 2.6171 | ppl 13.70 | lr 3.00e-04 | last 200 steps: 26.0s | total: 883s
#   step  7000 | loss 2.2392 | avg 2.6060 | ppl 13.55 | lr 3.00e-04 | last 200 steps: 26.0s | total: 909s
#   step  7200 | loss 2.2808 | avg 2.5954 | ppl 13.40 | lr 3.00e-04 | last 200 steps: 26.0s | total: 935s
#   step  7400 | loss 2.0779 | avg 2.5851 | ppl 13.27 | lr 3.00e-04 | last 200 steps: 26.0s | total: 961s
#   step  7600 | loss 2.2186 | avg 2.5752 | ppl 13.13 | lr 3.00e-04 | last 200 steps: 26.1s | total: 987s
#   step  7800 | loss 2.1560 | avg 2.5658 | ppl 13.01 | lr 3.00e-04 | last 200 steps: 26.0s | total: 1013s
#   step  8000 | loss 2.1069 | avg 2.5566 | ppl 12.89 | lr 3.00e-04 | last 200 steps: 26.1s | total: 1039s
#   step  8200 | loss 2.2322 | avg 2.5475 | ppl 12.77 | lr 3.00e-04 | last 200 steps: 26.2s | total: 1066s
#   step  8400 | loss 2.2280 | avg 2.5388 | ppl 12.66 | lr 3.00e-04 | last 200 steps: 26.1s | total: 1092s
#   step  8600 | loss 2.0677 | avg 2.5302 | ppl 12.56 | lr 3.00e-04 | last 200 steps: 26.4s | total: 1118s
#   step  8800 | loss 2.1329 | avg 2.5220 | ppl 12.45 | lr 3.00e-04 | last 200 steps: 26.1s | total: 1144s
#   step  9000 | loss 2.1641 | avg 2.5139 | ppl 12.35 | lr 2.99e-04 | last 200 steps: 26.1s | total: 1170s
#   step  9200 | loss 2.1386 | avg 2.5063 | ppl 12.26 | lr 2.99e-04 | last 200 steps: 26.5s | total: 1197s
#   step  9400 | loss 2.1676 | avg 2.4988 | ppl 12.17 | lr 2.99e-04 | last 200 steps: 26.0s | total: 1223s
#   step  9600 | loss 2.3574 | avg 2.4915 | ppl 12.08 | lr 2.99e-04 | last 200 steps: 26.4s | total: 1249s
#   step  9800 | loss 2.0411 | avg 2.4845 | ppl 12.00 | lr 2.99e-04 | last 200 steps: 26.2s | total: 1276s
#   step 10000 | loss 2.1767 | avg 2.4777 | ppl 11.91 | lr 2.99e-04 | last 200 steps: 26.3s | total: 1302s
#   step 10200 | loss 2.0651 | avg 2.4713 | ppl 11.84 | lr 2.99e-04 | last 200 steps: 26.3s | total: 1328s
#   step 10400 | loss 2.1631 | avg 2.4648 | ppl 11.76 | lr 2.99e-04 | last 200 steps: 26.3s | total: 1354s
#   step 10600 | loss 2.1337 | avg 2.4584 | ppl 11.69 | lr 2.99e-04 | last 200 steps: 26.4s | total: 1381s
#   step 10800 | loss 2.1612 | avg 2.4523 | ppl 11.61 | lr 2.99e-04 | last 200 steps: 26.1s | total: 1407s
#   step 11000 | loss 2.1652 | avg 2.4462 | ppl 11.54 | lr 2.99e-04 | last 200 steps: 26.3s | total: 1433s
#   step 11200 | loss 2.1901 | avg 2.4403 | ppl 11.48 | lr 2.99e-04 | last 200 steps: 26.3s | total: 1460s
#   step 11400 | loss 2.2490 | avg 2.4347 | ppl 11.41 | lr 2.99e-04 | last 200 steps: 26.3s | total: 1486s
#   step 11600 | loss 2.0367 | avg 2.4293 | ppl 11.35 | lr 2.99e-04 | last 200 steps: 26.4s | total: 1512s
#   step 11800 | loss 1.8986 | avg 2.4236 | ppl 11.29 | lr 2.99e-04 | last 200 steps: 26.4s | total: 1539s
#   step 12000 | loss 2.1032 | avg 2.4182 | ppl 11.23 | lr 2.99e-04 | last 200 steps: 26.3s | total: 1565s
#   step 12200 | loss 2.2464 | avg 2.4130 | ppl 11.17 | lr 2.99e-04 | last 200 steps: 26.2s | total: 1591s
#   step 12400 | loss 2.1000 | avg 2.4081 | ppl 11.11 | lr 2.99e-04 | last 200 steps: 26.3s | total: 1617s
#   step 12600 | loss 2.0629 | avg 2.4031 | ppl 11.06 | lr 2.99e-04 | last 200 steps: 26.4s | total: 1644s
#   step 12800 | loss 1.9849 | avg 2.3982 | ppl 11.00 | lr 2.99e-04 | last 200 steps: 26.3s | total: 1670s
#   step 13000 | loss 1.9383 | avg 2.3935 | ppl 10.95 | lr 2.99e-04 | last 200 steps: 26.4s | total: 1696s
#   step 13200 | loss 2.0405 | avg 2.3889 | ppl 10.90 | lr 2.99e-04 | last 200 steps: 26.3s | total: 1723s
#   step 13400 | loss 2.1155 | avg 2.3843 | ppl 10.85 | lr 2.99e-04 | last 200 steps: 26.3s | total: 1749s
#   step 13600 | loss 2.2126 | avg 2.3798 | ppl 10.80 | lr 2.99e-04 | last 200 steps: 26.3s | total: 1775s
#   step 13800 | loss 2.1483 | avg 2.3756 | ppl 10.76 | lr 2.99e-04 | last 200 steps: 26.4s | total: 1802s
#   step 14000 | loss 2.0093 | avg 2.3712 | ppl 10.71 | lr 2.99e-04 | last 200 steps: 26.2s | total: 1828s
#   step 14200 | loss 2.0760 | avg 2.3670 | ppl 10.67 | lr 2.99e-04 | last 200 steps: 26.1s | total: 1854s
#   step 14400 | loss 2.0856 | avg 2.3628 | ppl 10.62 | lr 2.99e-04 | last 200 steps: 26.2s | total: 1880s
#   step 14600 | loss 2.2252 | avg 2.3589 | ppl 10.58 | lr 2.99e-04 | last 200 steps: 26.3s | total: 1907s
#   step 14800 | loss 1.9223 | avg 2.3549 | ppl 10.54 | lr 2.99e-04 | last 200 steps: 26.3s | total: 1933s
#   step 15000 | loss 1.9845 | avg 2.3511 | ppl 10.50 | lr 2.99e-04 | last 200 steps: 26.0s | total: 1959s
#   step 15200 | loss 2.1263 | avg 2.3473 | ppl 10.46 | lr 2.99e-04 | last 200 steps: 26.3s | total: 1985s
#   step 15400 | loss 2.1184 | avg 2.3436 | ppl 10.42 | lr 2.99e-04 | last 200 steps: 26.3s | total: 2012s
#   step 15600 | loss 2.0297 | avg 2.3400 | ppl 10.38 | lr 2.98e-04 | last 200 steps: 26.3s | total: 2038s
#   step 15800 | loss 2.1961 | avg 2.3365 | ppl 10.35 | lr 2.98e-04 | last 200 steps: 26.3s | total: 2064s
#   step 16000 | loss 2.3123 | avg 2.3331 | ppl 10.31 | lr 2.98e-04 | last 200 steps: 26.2s | total: 2090s
#   step 16200 | loss 2.0986 | avg 2.3296 | ppl 10.27 | lr 2.98e-04 | last 200 steps: 26.3s | total: 2117s
#   step 16400 | loss 2.0957 | avg 2.3262 | ppl 10.24 | lr 2.98e-04 | last 200 steps: 26.2s | total: 2143s
#   step 16600 | loss 2.0154 | avg 2.3228 | ppl 10.20 | lr 2.98e-04 | last 200 steps: 26.4s | total: 2169s
#   step 16800 | loss 2.0057 | avg 2.3195 | ppl 10.17 | lr 2.98e-04 | last 200 steps: 26.2s | total: 2195s
#   step 17000 | loss 2.1441 | avg 2.3162 | ppl 10.14 | lr 2.98e-04 | last 200 steps: 26.7s | total: 2222s
#   step 17200 | loss 1.9935 | avg 2.3131 | ppl 10.11 | lr 2.98e-04 | last 200 steps: 26.1s | total: 2248s
#   step 17400 | loss 2.0025 | avg 2.3100 | ppl 10.07 | lr 2.98e-04 | last 200 steps: 26.4s | total: 2275s
#   step 17600 | loss 1.9126 | avg 2.3069 | ppl 10.04 | lr 2.98e-04 | last 200 steps: 26.2s | total: 2301s
#   step 17800 | loss 2.0683 | avg 2.3038 | ppl 10.01 | lr 2.98e-04 | last 200 steps: 26.4s | total: 2327s
#   step 18000 | loss 1.9657 | avg 2.3007 | ppl 9.98 | lr 2.98e-04 | last 200 steps: 26.3s | total: 2353s
#   step 18200 | loss 2.1346 | avg 2.2979 | ppl 9.95 | lr 2.98e-04 | last 200 steps: 26.3s | total: 2380s
#   step 18400 | loss 1.9959 | avg 2.2950 | ppl 9.92 | lr 2.98e-04 | last 200 steps: 26.3s | total: 2406s
#   step 18600 | loss 2.1139 | avg 2.2922 | ppl 9.90 | lr 2.98e-04 | last 200 steps: 26.3s | total: 2432s
#   Shard done — avg loss: 2.2904 | ppl 9.88
#
# [Epoch 1] Shard 2/2 — shard_0001.pt
#   step     0 | loss 2.2183 | avg 2.2183 | ppl 9.19 | lr 2.98e-04 | last 200 steps: 1.9s | total: 2s
#   step   200 | loss 1.8588 | avg 2.0286 | ppl 7.60 | lr 2.98e-04 | last 200 steps: 26.2s | total: 28s
#   step   400 | loss 2.1030 | avg 2.0329 | ppl 7.64 | lr 2.98e-04 | last 200 steps: 26.3s | total: 54s
#   step   600 | loss 1.9878 | avg 2.0282 | ppl 7.60 | lr 2.98e-04 | last 200 steps: 26.4s | total: 81s
#   step   800 | loss 1.9589 | avg 2.0272 | ppl 7.59 | lr 2.98e-04 | last 200 steps: 26.2s | total: 107s
#   step  1000 | loss 2.0168 | avg 2.0268 | ppl 7.59 | lr 2.98e-04 | last 200 steps: 26.4s | total: 133s
#   step  1200 | loss 1.9911 | avg 2.0252 | ppl 7.58 | lr 2.98e-04 | last 200 steps: 26.3s | total: 160s
#   step  1400 | loss 2.0352 | avg 2.0254 | ppl 7.58 | lr 2.97e-04 | last 200 steps: 26.4s | total: 186s
#   step  1600 | loss 2.0018 | avg 2.0250 | ppl 7.58 | lr 2.97e-04 | last 200 steps: 26.3s | total: 212s
#   step  1800 | loss 2.0197 | avg 2.0243 | ppl 7.57 | lr 2.97e-04 | last 200 steps: 26.3s | total: 239s
#   step  2000 | loss 1.8378 | avg 2.0223 | ppl 7.56 | lr 2.97e-04 | last 200 steps: 26.3s | total: 265s
#   step  2200 | loss 1.9471 | avg 2.0213 | ppl 7.55 | lr 2.97e-04 | last 200 steps: 26.4s | total: 291s
#   step  2400 | loss 1.7915 | avg 2.0211 | ppl 7.55 | lr 2.97e-04 | last 200 steps: 26.3s | total: 318s
#   step  2600 | loss 1.9522 | avg 2.0205 | ppl 7.54 | lr 2.97e-04 | last 200 steps: 26.3s | total: 344s
#   step  2800 | loss 2.0156 | avg 2.0194 | ppl 7.53 | lr 2.97e-04 | last 200 steps: 26.4s | total: 370s
#   step  3000 | loss 2.0335 | avg 2.0190 | ppl 7.53 | lr 2.97e-04 | last 200 steps: 26.3s | total: 397s
#   step  3200 | loss 2.0518 | avg 2.0186 | ppl 7.53 | lr 2.97e-04 | last 200 steps: 26.3s | total: 423s
#   step  3400 | loss 2.0639 | avg 2.0174 | ppl 7.52 | lr 2.97e-04 | last 200 steps: 26.2s | total: 449s
#   step  3600 | loss 1.9499 | avg 2.0171 | ppl 7.52 | lr 2.97e-04 | last 200 steps: 26.4s | total: 476s
#   step  3800 | loss 1.8309 | avg 2.0167 | ppl 7.51 | lr 2.97e-04 | last 200 steps: 26.4s | total: 502s
#   step  4000 | loss 2.0467 | avg 2.0160 | ppl 7.51 | lr 2.97e-04 | last 200 steps: 26.3s | total: 528s
#   step  4200 | loss 2.0152 | avg 2.0151 | ppl 7.50 | lr 2.97e-04 | last 200 steps: 26.4s | total: 555s
#   step  4400 | loss 1.8893 | avg 2.0142 | ppl 7.49 | lr 2.97e-04 | last 200 steps: 26.3s | total: 581s
#   step  4600 | loss 1.9545 | avg 2.0137 | ppl 7.49 | lr 2.97e-04 | last 200 steps: 26.6s | total: 608s
#   step  4800 | loss 2.0880 | avg 2.0131 | ppl 7.49 | lr 2.97e-04 | last 200 steps: 26.2s | total: 634s
#   step  5000 | loss 2.1098 | avg 2.0123 | ppl 7.48 | lr 2.96e-04 | last 200 steps: 26.3s | total: 660s
#   step  5200 | loss 1.9539 | avg 2.0115 | ppl 7.47 | lr 2.96e-04 | last 200 steps: 26.5s | total: 687s
#   step  5400 | loss 1.8968 | avg 2.0105 | ppl 7.47 | lr 2.96e-04 | last 200 steps: 26.5s | total: 713s
#   step  5600 | loss 2.0182 | avg 2.0093 | ppl 7.46 | lr 2.96e-04 | last 200 steps: 26.4s | total: 739s
#   step  5800 | loss 1.9388 | avg 2.0086 | ppl 7.45 | lr 2.96e-04 | last 200 steps: 26.6s | total: 766s
#   step  6000 | loss 1.9321 | avg 2.0081 | ppl 7.45 | lr 2.96e-04 | last 200 steps: 26.5s | total: 792s
#   step  6200 | loss 2.0246 | avg 2.0074 | ppl 7.44 | lr 2.96e-04 | last 200 steps: 26.6s | total: 819s
#   step  6400 | loss 2.0601 | avg 2.0069 | ppl 7.44 | lr 2.96e-04 | last 200 steps: 26.4s | total: 846s
#   step  6600 | loss 2.0222 | avg 2.0062 | ppl 7.43 | lr 2.96e-04 | last 200 steps: 26.5s | total: 872s
#   step  6800 | loss 2.0524 | avg 2.0058 | ppl 7.43 | lr 2.96e-04 | last 200 steps: 26.8s | total: 899s
#   step  7000 | loss 1.9546 | avg 2.0051 | ppl 7.43 | lr 2.96e-04 | last 200 steps: 26.8s | total: 926s
#   step  7200 | loss 1.9322 | avg 2.0043 | ppl 7.42 | lr 2.96e-04 | last 200 steps: 27.2s | total: 953s
#   step  7400 | loss 1.9546 | avg 2.0037 | ppl 7.42 | lr 2.96e-04 | last 200 steps: 27.6s | total: 980s
#   step  7600 | loss 2.1143 | avg 2.0030 | ppl 7.41 | lr 2.96e-04 | last 200 steps: 27.5s | total: 1008s
#   step  7800 | loss 2.0376 | avg 2.0023 | ppl 7.41 | lr 2.96e-04 | last 200 steps: 28.0s | total: 1036s
#   step  8000 | loss 1.9816 | avg 2.0015 | ppl 7.40 | lr 2.96e-04 | last 200 steps: 27.7s | total: 1064s
#   step  8200 | loss 2.0225 | avg 2.0009 | ppl 7.40 | lr 2.95e-04 | last 200 steps: 27.8s | total: 1091s
#   step  8400 | loss 2.0949 | avg 2.0004 | ppl 7.39 | lr 2.95e-04 | last 200 steps: 28.2s | total: 1120s
#   step  8600 | loss 1.9749 | avg 1.9999 | ppl 7.39 | lr 2.95e-04 | last 200 steps: 28.5s | total: 1148s
#   step  8800 | loss 2.0279 | avg 1.9994 | ppl 7.38 | lr 2.95e-04 | last 200 steps: 28.1s | total: 1176s
#   step  9000 | loss 2.1145 | avg 1.9990 | ppl 7.38 | lr 2.95e-04 | last 200 steps: 28.9s | total: 1205s
#   step  9200 | loss 1.7960 | avg 1.9986 | ppl 7.38 | lr 2.95e-04 | last 200 steps: 28.7s | total: 1234s
#   step  9400 | loss 1.8903 | avg 1.9981 | ppl 7.38 | lr 2.95e-04 | last 200 steps: 28.9s | total: 1263s
#   step  9600 | loss 2.1200 | avg 1.9975 | ppl 7.37 | lr 2.95e-04 | last 200 steps: 28.4s | total: 1291s
#   step  9800 | loss 1.9180 | avg 1.9969 | ppl 7.37 | lr 2.95e-04 | last 200 steps: 28.0s | total: 1319s
#   step 10000 | loss 1.8995 | avg 1.9965 | ppl 7.36 | lr 2.95e-04 | last 200 steps: 28.4s | total: 1347s
#   step 10200 | loss 1.9887 | avg 1.9960 | ppl 7.36 | lr 2.95e-04 | last 200 steps: 28.0s | total: 1375s
#   step 10400 | loss 2.0423 | avg 1.9955 | ppl 7.36 | lr 2.95e-04 | last 200 steps: 28.1s | total: 1403s
#   step 10600 | loss 1.8946 | avg 1.9949 | ppl 7.35 | lr 2.95e-04 | last 200 steps: 28.3s | total: 1432s
#   step 10800 | loss 1.8966 | avg 1.9943 | ppl 7.35 | lr 2.95e-04 | last 200 steps: 27.8s | total: 1460s
#   step 15600 | loss 1.9515 | avg 1.9826 | ppl 7.26 | lr 2.93e-04 | last 200 steps: 35.9s | total: 2189s
#   step 15800 | loss 1.9770 | avg 1.9820 | ppl 7.26 | lr 2.93e-04 | last 200 steps: 35.9s | total: 2225s
#   step 16000 | loss 1.9895 | avg 1.9814 | ppl 7.25 | lr 2.92e-04 | last 200 steps: 35.9s | total: 2261s
#   step 16200 | loss 1.9987 | avg 1.9809 | ppl 7.25 | lr 2.92e-04 | last 200 steps: 35.9s | total: 2297s
#   step 16400 | loss 1.7933 | avg 1.9807 | ppl 7.25 | lr 2.92e-04 | last 200 steps: 35.9s | total: 2333s
#   step 16600 | loss 2.1101 | avg 1.9802 | ppl 7.24 | lr 2.92e-04 | last 200 steps: 35.9s | total: 2368s
#   step 16800 | loss 1.9725 | avg 1.9797 | ppl 7.24 | lr 2.92e-04 | last 200 steps: 35.9s | total: 2404s
#   step 17000 | loss 1.9132 | avg 1.9793 | ppl 7.24 | lr 2.92e-04 | last 200 steps: 36.0s | total: 2440s
#   step 17200 | loss 1.8665 | avg 1.9787 | ppl 7.23 | lr 2.92e-04 | last 200 steps: 36.0s | total: 2476s
#   step 17400 | loss 1.9135 | avg 1.9783 | ppl 7.23 | lr 2.92e-04 | last 200 steps: 36.0s | total: 2512s
#   step 17600 | loss 2.0446 | avg 1.9779 | ppl 7.23 | lr 2.92e-04 | last 200 steps: 36.0s | total: 2548s
#   step 17800 | loss 1.8178 | avg 1.9774 | ppl 7.22 | lr 2.92e-04 | last 200 steps: 36.0s | total: 2584s
#   step 18000 | loss 1.8968 | avg 1.9770 | ppl 7.22 | lr 2.92e-04 | last 200 steps: 36.1s | total: 2621s
#   step 18200 | loss 1.8092 | avg 1.9766 | ppl 7.22 | lr 2.92e-04 | last 200 steps: 36.1s | total: 2657s
#   step 18400 | loss 1.9327 | avg 1.9762 | ppl 7.22 | lr 2.91e-04 | last 200 steps: 36.1s | total: 2693s
#   step 18600 | loss 1.8539 | avg 1.9759 | ppl 7.21 | lr 2.91e-04 | last 200 steps: 36.2s | total: 2729s
#   Shard done — avg loss: 1.9756 | ppl 7.21
# Mid-epoch checkpoint saved → checkpoints_v5/epoch_1_shard_1.pt
#
# Epoch 1 complete — avg loss: 2.1330 | ppl 8.44
# Epoch checkpoint saved → checkpoints_v5/epoch_1.pt
#
# ============================================================
# Epoch 2/3
# ============================================================
#
# [Epoch 2] Shard 1/2 — shard_0000.pt
#   step     0 | loss 1.9914 | avg 1.9914 | ppl 7.33 | lr 2.91e-04 | last 200 steps: 2.5s | total: 3s
#   step   200 | loss 1.8580 | avg 1.9199 | ppl 6.82 | lr 2.91e-04 | last 200 steps: 36.2s | total: 39s
#   step   400 | loss 1.9890 | avg 1.9268 | ppl 6.87 | lr 2.91e-04 | last 200 steps: 36.1s | total: 75s
#   step   600 | loss 1.8294 | avg 1.9332 | ppl 6.91 | lr 2.91e-04 | last 200 steps: 36.2s | total: 111s
#   step   800 | loss 2.0267 | avg 1.9359 | ppl 6.93 | lr 2.91e-04 | last 200 steps: 36.4s | total: 147s
#   step 15000 | loss 1.8050 | avg 1.8852 | ppl 6.59 | lr 2.69e-04 | last 200 steps: 26.1s | total: 1961s
#   step 15200 | loss 1.8790 | avg 1.8851 | ppl 6.59 | lr 2.69e-04 | last 200 steps: 26.1s | total: 1987s
#   step 15400 | loss 2.1010 | avg 1.8850 | ppl 6.59 | lr 2.69e-04 | last 200 steps: 26.1s | total: 2013s
#   step 15600 | loss 1.9625 | avg 1.8848 | ppl 6.59 | lr 2.69e-04 | last 200 steps: 26.1s | total: 2039s
#   step 15800 | loss 1.9230 | avg 1.8847 | ppl 6.58 | lr 2.69e-04 | last 200 steps: 26.1s | total: 2065s
#   step 16000 | loss 1.8470 | avg 1.8846 | ppl 6.58 | lr 2.69e-04 | last 200 steps: 26.1s | total: 2092s
#   step 16200 | loss 1.9563 | avg 1.8846 | ppl 6.58 | lr 2.68e-04 | last 200 steps: 26.1s | total: 2118s
#   step 16400 | loss 1.9354 | avg 1.8844 | ppl 6.58 | lr 2.68e-04 | last 200 steps: 26.1s | total: 2144s
#   step 16600 | loss 1.8835 | avg 1.8843 | ppl 6.58 | lr 2.68e-04 | last 200 steps: 26.1s | total: 2170s
#   step 16800 | loss 1.8677 | avg 1.8842 | ppl 6.58 | lr 2.68e-04 | last 200 steps: 26.1s | total: 2196s
#   step 17000 | loss 1.9797 | avg 1.8841 | ppl 6.58 | lr 2.68e-04 | last 200 steps: 26.1s | total: 2222s
#   step 17200 | loss 1.8707 | avg 1.8839 | ppl 6.58 | lr 2.68e-04 | last 200 steps: 26.1s | total: 2248s
#   step 17400 | loss 1.8126 | avg 1.8838 | ppl 6.58 | lr 2.67e-04 | last 200 steps: 26.1s | total: 2274s
#   step 17600 | loss 1.7764 | avg 1.8837 | ppl 6.58 | lr 2.67e-04 | last 200 steps: 26.1s | total: 2300s
#   step 17800 | loss 1.8014 | avg 1.8835 | ppl 6.58 | lr 2.67e-04 | last 200 steps: 26.1s | total: 2327s
#   step 18000 | loss 1.9626 | avg 1.8834 | ppl 6.58 | lr 2.67e-04 | last 200 steps: 26.1s | total: 2353s
#   step 18200 | loss 1.8548 | avg 1.8833 | ppl 6.57 | lr 2.67e-04 | last 200 steps: 26.1s | total: 2379s
#   step 18400 | loss 1.8096 | avg 1.8832 | ppl 6.57 | lr 2.66e-04 | last 200 steps: 26.1s | total: 2405s
#   step 18600 | loss 1.9088 | avg 1.8830 | ppl 6.57 | lr 2.66e-04 | last 200 steps: 26.1s | total: 2431s
#   Shard done — avg loss: 1.8830 | ppl 6.57
# Mid-epoch checkpoint saved → checkpoints_v5/epoch_2_shard_1.pt
#
# Epoch 2 complete — avg loss: 1.8991 | ppl 6.68
# Epoch checkpoint saved → checkpoints_v5/epoch_2.pt
#
# ============================================================
# Epoch 3/3
# ============================================================
#
# [Epoch 3] Shard 1/2 — shard_0000.pt
#   step     0 | loss 1.8130 | avg 1.8130 | ppl 6.13 | lr 2.66e-04 | last 200 steps: 2.2s | total: 2s
#   step   200 | loss
#   step  5200 | loss 1.9377 | avg 1.8667 | ppl 6.47 | lr 2.62e-04 | last 200 steps: 26.2s | total: 681s
#   step  5400 | loss 1.7676 | avg 1.8669 | ppl 6.47 | lr 2.61e-04 | last 200 steps: 26.2s | total: 707s
#   step  5600 | loss 1.7697 | avg 1.8669 | ppl 6.47 | lr 2.61e-04 | last 200 steps: 26.2s | total: 733s
#   step  5800 | loss 1.8805 | avg 1.8668 | ppl 6.47 | lr 2.61e-04 | last 200 steps: 26.2s | total: 759s
#   step  6000 | loss 1.9457 | avg 1.8671 | ppl 6.47 | lr 2.61e-04 | last 200 steps: 26.2s | total: 786s
#   step  6200 | loss 2.0012 | avg 1.8670 | ppl 6.47 | lr 2.61e-04 | last 200 steps: 26.2s | total: 812s
#   step  6400 | loss 1.7786 | avg 1.8668 | ppl 6.47 | lr 2.60e-04 | last 200 steps: 26.2s | total: 838s
#   step  6600 | loss 1.9227 | avg 1.8667 | ppl 6.47 | lr 2.60e-04 | last 200 steps: 26.2s | total: 864s
#   step  6800 | loss 1.8707 | avg 1.8669 | ppl 6.47 | lr 2.60e-04 | last 200 steps: 26.2s | total: 890s
#   step  7000 | loss 1.8555 | avg 1.8666 | ppl 6.47 | lr 2.60e-04 | last 200 steps: 26.2s | total: 916s
#   step  7200 | loss 1.8703 | avg 1.8665 | ppl 6.47 | lr 2.60e-04 | last 200 steps: 26.2s | total: 943s
#   step  7400 | loss 2.0910 | avg 1.8663 | ppl 6.46 | lr 2.60e-04 | last 200 steps: 26.2s | total: 969s
#   step  7600 | loss 1.8690 | avg 1.8662 | ppl 6.46 | lr 2.59e-04 | last 200 steps: 26.2s | total: 995s
#   step  7800 | loss 1.8727 | avg 1.8662 | ppl 6.46 | lr 2.59e-04 | last 200 steps: 26.2s | total: 1021s
#   step  8000 | loss 1.8389 | avg 1.8659 | ppl 6.46 | lr 2.59e-04 | last 200 steps: 26.2s | total: 1047s
#   step  8200 | loss 1.9029 | avg 1.8659 | ppl 6.46 | lr 2.59e-04 | last 200 steps: 26.2s | total: 1074s
#   step  8400 | loss 1.9567 | avg 1.8656 | ppl 6.46 | lr 2.59e-04 | last 200 steps: 26.2s | total: 1100s
#   step  8600 | loss 2.0886 | avg 1.8654 | ppl 6.46 | lr 2.58e-04 | last 200 steps: 26.2s | total: 1126s
#   step  8800 | loss 2.0219 | avg 1.8652 | ppl 6.46 | lr 2.58e-04 | last 200 steps: 26.2s | total: 1152s
#   step  9000 | loss 1.7947 | avg 1.8651 | ppl 6.46 | lr 2.58e-04 | last 200 steps: 26.2s | total: 1178s
#   step  9200 | loss 1.9039 | avg 1.8652 | ppl 6.46 | lr 2.58e-04 | last 200 steps: 26.1s | total: 1204s
#   step  9400 | loss 1.7654 | avg 1.8653 | ppl 6.46 | lr 2.58e-04 | last 200 steps: 26.1s | total: 1231s
#   step  9600 | loss 1.8965 | avg 1.8652 | ppl 6.46 | lr 2.57e-04 | last 200 steps: 26.1s | total: 1257s
#   step  9800 | loss 2.0131 | avg 1.8653 | ppl 6.46 | lr 2.57e-04 | last 200 steps: 26.1s | total: 1283s
#   step 10000 | loss 1.8064 | avg 1.8651 | ppl 6.46 | lr 2.57e-04 | last 200 steps: 26.1s | total: 1309s
#   step 10200 | loss 1.8743 | avg 1.8652 | ppl 6.46 | lr 2.57e-04 | last 200 steps: 26.1s | total: 1335s
#   step 10400 | loss 1.8121 | avg 1.8650 | ppl 6.46 | lr 2.57e-04 | last 200 steps: 26.1s | total: 1361s
#   step 10600 | loss 1.7566 | avg 1.8649 | ppl 6.46 | lr 2.56e-04 | last 200 steps: 26.2s | total: 1387s
#   step 10800 | loss 1.8176 | avg 1.8649 | ppl 6.46 | lr 2.56e-04 | last 200 steps: 26.1s | total: 1413s
#   step 11000 | loss 1.9786 | avg 1.8649 | ppl 6.46 | lr 2.56e-04 | last 200 steps: 26.2s | total: 1439s
#   step 11200 | loss 1.8004 | avg 1.8649 | ppl 6.46 | lr 2.56e-04 | last 200 steps: 26.2s | total: 1466s
#   step 11400 | loss 1.7986 | avg 1.8648 | ppl 6.45 | lr 2.56e-04 | last 200 steps: 26.2s | total: 1492s
#   step 11600 | loss 1.9360 | avg 1.8648 | ppl 6.45 | lr 2.56e-04 | last 200 steps: 26.2s | total: 1518s
#   step 11800 | loss 2.0594 | avg 1.8647 | ppl 6.45 | lr 2.55e-04 | last 200 steps: 26.2s | total: 1544s
#   step 12000 | loss 1.8456 | avg 1.8647 | ppl 6.45 | lr 2.55e-04 | last 200 steps: 26.2s | total: 1570s
#   step 12200 | loss 1.7551 | avg 1.8648 | ppl 6.45 | lr 2.55e-04 | last 200 steps: 26.2s | total: 1596s
#   step 12400 | loss 1.8302 | avg 1.8646 | ppl 6.45 | lr 2.55e-04 | last 200 steps: 26.2s | total: 1623s
#   step 12600 | loss 1.7427 | avg 1.8645 | ppl 6.45 | lr 2.55e-04 | last 200 steps: 26.2s | total: 1649s
#   step 12800 | loss 1.8678 | avg 1.8644 | ppl 6.45 | lr 2.54e-04 | last 200 steps: 26.2s | total: 1675s
#   step 13000 | loss 1.8283 | avg 1.8643 | ppl 6.45 | lr 2.54e-04 | last 200 steps: 26.1s | total: 1701s
#   step 13200 | loss 1.8923 | avg 1.8641 | ppl 6.45 | lr 2.54e-04 | last 200 steps: 26.2s | total: 1727s
#   step 13400 | loss 1.8752 | avg 1.8639 | ppl 6.45 | lr 2.54e-04 | last 200 steps: 26.1s | total: 1753s
#   step 13600 | loss 1.6724 | avg 1.8638 | ppl 6.45 | lr 2.54e-04 | last 200 steps: 26.2s | total: 1780s
#   step 13800 | loss 1.8980 | avg 1.8635 | ppl 6.45 | lr 2.53e-04 | last 200 steps: 26.2s | total: 1806s
#   step 14000 | loss 1.8229 | avg 1.8634 | ppl 6.45 | lr 2.53e-04 | last 200 steps: 26.2s | total: 1832s
#   step 14200 | loss 2.0237 | avg 1.8633 | ppl 6.45 | lr 2.53e-04 | last 200 steps: 26.2s | total: 1858s
#   step 14400 | loss 1.8451 | avg 1.8633 | ppl 6.44 | lr 2.53e-04 | last 200 steps: 26.2s | total: 1884s
#   step 14600 | loss 1.8820 | avg 1.8632 | ppl 6.44 | lr 2.53e-04 | last 200 steps: 26.2s | total: 1910s
#   step 14800 | loss 1.8509 | avg 1.8631 | ppl 6.44 | lr 2.52e-04 | last 200 steps: 26.2s | total: 1937s
#   step 15000 | loss 1.7451 | avg 1.8630 | ppl 6.44 | lr 2.52e-04 | last 200 steps: 26.2s | total: 1963s
#   step 15200 | loss 1.8634 | avg 1.8629 | ppl 6.44 | lr 2.52e-04 | last 200 steps: 26.2s | total: 1989s
#   step 15400 | loss 1.8882 | avg 1.8628 | ppl 6.44 | lr 2.52e-04 | last 200 steps: 26.2s | total: 2015s
#   step 15600 | loss 1.7603 | avg 1.8626 | ppl 6.44 | lr 2.52e-04 | last 200 steps: 26.2s | total: 2041s
#   step 15800 | loss 1.9222 | avg 1.8623 | ppl 6.44 | lr 2.51e-04 | last 200 steps: 26.2s | total: 2067s
#   step 16000 | loss 1.8614 | avg 1.8623 | ppl 6.44 | lr 2.51e-04 | last 200 steps: 26.1s | total: 2094s
#   step 16200 | loss 1.8293 | avg 1.8621 | ppl 6.44 | lr 2.51e-04 | last 200 steps: 26.2s | total: 2120s
#   step 16400 | loss 1.7856 | avg 1.8620 | ppl 6.44 | lr 2.51e-04 | last 200 steps: 26.2s | total: 2146s
#   step 16600 | loss 1.8962 | avg 1.8619 | ppl 6.44 | lr 2.51e-04 | last 200 steps: 26.1s | total: 2172s
#   step 16800 | loss 1.9128 | avg 1.8616 | ppl 6.43 | lr 2.50e-04 | last 200 steps: 26.2s | total: 2198s
#   step 17000 | loss 1.9603 | avg 1.8616 | ppl 6.43 | lr 2.50e-04 | last 200 steps: 26.2s | total: 2224s
#   step 17200 | loss 1.8759 | avg 1.8615 | ppl 6.43 | lr 2.50e-04 | last 200 steps: 26.2s | total: 2251s
#   step 17400 | loss 1.7949 | avg 1.8614 | ppl 6.43 | lr 2.50e-04 | last 200 steps: 26.2s | total: 2277s
#   step 17600 | loss 1.8145 | avg 1.8614 | ppl 6.43 | lr 2.50e-04 | last 200 steps: 26.2s | total: 2303s
#   step 17800 | loss 1.6934 | avg 1.8612 | ppl 6.43 | lr 2.49e-04 | last 200 steps: 26.2s | total: 2329s
#   step 18000 | loss 1.7100 | avg 1.8611 | ppl 6.43 | lr 2.49e-04 | last 200 steps: 26.2s | total: 2355s
#   step 18200 | loss 1.7856 | avg 1.8609 | ppl 6.43 | lr 2.49e-04 | last 200 steps: 26.2s | total: 2381s
#   step 18400 | loss 1.9044 | avg 1.8609 | ppl 6.43 | lr 2.49e-04 | last 200 steps: 26.1s | total: 2408s
#   step 18600 | loss 1.8718 | avg 1.8608 | ppl 6.43 | lr 2.49e-04 | last 200 steps: 26.2s | total: 2434s
#   Shard done — avg loss: 1.8606 | ppl 6.43
#
# [Epoch 3] Shard 2/2 — shard_0001.pt
#   step     0 | loss 1.8861 | avg 1.8861 | ppl 6.59 | lr 2.48e-04 | last 200 steps: 2.1s | total: 2s
#   step   200 | loss
#   step 14600 | loss 1.6703 | avg 1.8438 | ppl 6.32 | lr 2.32e-04 | last 200 steps: 26.1s | total: 1963s
#   step 14800 | loss 1.7467 | avg 1.8438 | ppl 6.32 | lr 2.32e-04 | last 200 steps: 26.1s | total: 1989s
#   step 15000 | loss 1.7346 | avg 1.8438 | ppl 6.32 | lr 2.32e-04 | last 200 steps: 26.1s | total: 2016s
#   step 15200 | loss 1.9690 | avg 1.8437 | ppl 6.32 | lr 2.32e-04 | last 200 steps: 26.1s | total: 2042s
#   step 15400 | loss 2.0835 | avg 1.8435 | ppl 6.32 | lr 2.32e-04 | last 200 steps: 26.1s | total: 2068s
#   step 15600 | loss 1.9024 | avg 1.8435 | ppl 6.32 | lr 2.31e-04 | last 200 steps: 26.1s | total: 2094s
#   step 15800 | loss 1.9941 | avg 1.8434 | ppl 6.32 | lr 2.31e-04 | last 200 steps: 26.1s | total: 2120s
#   step 16000 | loss 1.7402 | avg 1.8432 | ppl 6.32 | lr 2.31e-04 | last 200 steps: 26.1s | total: 2146s
#   step 16200 | loss 1.9193 | avg 1.8432 | ppl 6.32 | lr 2.31e-04 | last 200 steps: 26.1s | total: 2172s
#   step 16400 | loss 1.8154 | avg 1.8432 | ppl 6.32 | lr 2.30e-04 | last 200 steps: 26.1s | total: 2198s
#   step 16600 | loss 1.9207 | avg 1.8431 | ppl 6.32 | lr 2.30e-04 | last 200 steps: 26.1s | total: 2224s
#   step 16800 | loss 1.8549 | avg 1.8431 | ppl 6.32 | lr 2.30e-04 | last 200 steps: 26.1s | total: 2251s
#   step 17000 | loss 1.9757 | avg 1.8430 | ppl 6.32 | lr 2.30e-04 | last 200 steps: 26.1s | total: 2277s
#   step 17200 | loss 1.9637 | avg 1.8429 | ppl 6.32 | lr 2.30e-04 | last 200 steps: 26.1s | total: 2303s
#   step 17400 | loss 1.8094 | avg 1.8428 | ppl 6.31 | lr 2.29e-04 | last 200 steps: 26.1s | total: 2329s
#   step 17600 | loss 1.7598 | avg 1.8427 | ppl 6.31 | lr 2.29e-04 | last 200 steps: 26.1s | total: 2355s
#   step 17800 | loss 1.5912 | avg 1.8426 | ppl 6.31 | lr 2.29e-04 | last 200 steps: 26.1s | total: 2381s
#   step 18000 | loss 1.8921 | avg 1.8424 | ppl 6.31 | lr 2.29e-04 | last 200 steps: 26.1s | total: 2407s
#   step 18200 | loss 1.8019 | avg 1.8424 | ppl 6.31 | lr 2.28e-04 | last 200 steps: 26.1s | total: 2433s
#   step 18400 | loss 1.8179 | avg 1.8424 | ppl 6.31 | lr 2.28e-04 | last 200 steps: 26.1s | total: 2459s
#   step 18600 | loss 1.8130 | avg 1.8422 | ppl 6.31 | lr 2.28e-04 | last 200 steps: 26.1s | total: 2486s
#   Shard done — avg loss: 1.8421 | ppl 6.31
# Mid-epoch checkpoint saved → checkpoints_v5/epoch_3_shard_1.pt
#
# Epoch 3 complete — avg loss: 1.8514 | ppl 6.37
# Epoch checkpoint saved → checkpoints_v5/epoch_3.pt
#
# Training complete.

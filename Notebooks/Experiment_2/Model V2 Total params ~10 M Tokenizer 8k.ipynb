# %%
import torch
import torch.nn as nn
import numpy as np
import math
import time

# Load frozen embedding table
embedding_table = np.load("tokenizer_v2/token_embeddings.npy")
embedding_tensor = torch.tensor(embedding_table, dtype=torch.float32)

VOCAB_SIZE    = embedding_tensor.shape[0]   # 4096
MINILM_DIM    = embedding_tensor.shape[1]   # 384
print(f"Vocab size : {VOCAB_SIZE}")
print(f"MiniLM dim : {MINILM_DIM}")
# Out:
# Vocab size : 8192
# MiniLM dim : 384

# %%
import torch.nn.functional as F 

DIM      = 384
N_HEADS  = 8
N_LAYERS = 8
FFN_DIM  = 768
HEAD_DIM = DIM // N_HEADS 

def sinusoidal_encoding(seq_len, dim, device):
    pe       = torch.zeros(seq_len, dim, device=device)
    position = torch.arange(seq_len, device=device).unsqueeze(1)
    div_term = torch.exp(torch.arange(0, dim, 2, device=device) * (-math.log(10000.0) / dim))
    pe[:, 0::2] = torch.sin(position * div_term)
    pe[:, 1::2] = torch.cos(position * div_term)
    return pe  # (seq_len, dim)

class LayerNorm(nn.Module):
    """
    y = ((x - mean) / sqrt(var + eps)) * gamma + beta
    gamma, beta are learned per-feature scalars — shape (dim,)
    """
    def __init__(self, dim, eps=1e-5):
        super().__init__()
        self.eps   = eps
        self.gamma = nn.Parameter(torch.ones(dim))   # scale
        self.beta  = nn.Parameter(torch.zeros(dim))  # shift

    def forward(self, x):
        mean = x.mean(dim=-1, keepdim=True)           # (B, T, 1)
        var  = x.var(dim=-1, keepdim=True, unbiased=False)  # (B, T, 1)
        x_norm = (x - mean) / torch.sqrt(var + self.eps)    # (B, T, D)
        return self.gamma * x_norm + self.beta               # (B, T, D)

class MultiHeadCausalAttention(nn.Module):
    """
    Projects input into Q, K, V — splits into H heads — computes scaled
    dot-product attention with a causal mask — concatenates heads — projects out.

    Q = x W_q      shape: (B, T, D)
    K = x W_k      shape: (B, T, D)
    V = x W_v      shape: (B, T, D)

    Reshape to (B, H, T, head_dim), then:
        scores = Q @ Kᵀ / sqrt(head_dim)    (B, H, T, T)
        scores = scores + causal_mask        (upper triangle = -inf)
        weights = softmax(scores, dim=-1)    (B, H, T, T)
        out = weights @ V                    (B, H, T, head_dim)

    Concat heads → (B, T, D), project out via W_o
    """
    def __init__(self, dim, n_heads, dropout=0.1):
        super().__init__()
        assert dim % n_heads == 0, "dim must be divisible by n_heads"
        self.n_heads  = n_heads
        self.head_dim = dim // n_heads       # 48
        self.scale    = self.head_dim ** -0.5

        self.W_q = nn.Linear(dim, dim, bias=False)
        self.W_k = nn.Linear(dim, dim, bias=False)
        self.W_v = nn.Linear(dim, dim, bias=False)
        self.W_o = nn.Linear(dim, dim, bias=False)

        self.attn_drop = nn.Dropout(dropout)

    def forward(self, x):
        B, T, D = x.shape

        # --- Project & split into heads ---
        Q = self.W_q(x)  # (B, T, D)
        K = self.W_k(x)  # (B, T, D)
        V = self.W_v(x)  # (B, T, D)

        # Reshape: (B, T, D) → (B, H, T, head_dim)
        Q = Q.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)
        K = K.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)
        V = V.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)

        # --- Scaled dot-product attention ---
        # (B, H, T, head_dim) @ (B, H, head_dim, T) → (B, H, T, T)
        scores = (Q @ K.transpose(-2, -1)) * self.scale

        # Causal mask: positions can only attend to themselves and earlier tokens
        # Upper triangle (future tokens) set to -inf → softmax drives them to 0
        causal_mask = torch.triu(
            torch.ones(T, T, device=x.device, dtype=torch.bool), diagonal=1
        )
        scores = scores.masked_fill(causal_mask, float('-inf'))

        weights = torch.softmax(scores, dim=-1)  # (B, H, T, T)
        weights = self.attn_drop(weights)

        # (B, H, T, T) @ (B, H, T, head_dim) → (B, H, T, head_dim)
        out = weights @ V

        # --- Concat heads & project ---
        # (B, H, T, head_dim) → (B, T, H*head_dim) = (B, T, D)
        out = out.transpose(1, 2).contiguous().view(B, T, D)
        return self.W_o(out)  # (B, T, D)

class FeedForward(nn.Module):
    """
    Two-layer MLP with GELU activation.
    FFN(x) = GELU(x W_1 + b_1) W_2 + b_2

    Expands dim → ffn_dim (wider representation),
    then projects back down ffn_dim → dim.
    """
    def __init__(self, dim, ffn_dim, dropout=0.1):
        super().__init__()
        self.W_1 = nn.Linear(dim, ffn_dim)       # expand
        self.W_2 = nn.Linear(ffn_dim, dim)       # contract
        self.drop = nn.Dropout(dropout)

    def forward(self, x):
        x = F.gelu(self.W_1(x))   # (B, T, ffn_dim)
        x = self.drop(x)
        x = self.W_2(x)           # (B, T, dim)
        return x

class TransformerBlock(nn.Module):
    """
    Pre-norm residual block (norm_first=True, same as your original config).

    x = x + Attention(LayerNorm(x))   ← self-attention sub-layer
    x = x + FFN(LayerNorm(x))         ← feed-forward sub-layer

    Pre-norm (LN before the sub-layer) stabilises training at depth
    vs post-norm (LN after the residual add).
    """
    def __init__(self, dim, n_heads, ffn_dim, dropout=0.1):
        super().__init__()
        self.norm_1 = LayerNorm(dim)
        self.attn   = MultiHeadCausalAttention(dim, n_heads, dropout)
        self.norm_2 = LayerNorm(dim)
        self.ffn    = FeedForward(dim, ffn_dim, dropout)
        self.drop   = nn.Dropout(dropout)

    def forward(self, x):
        x = x + self.drop(self.attn(self.norm_1(x)))  # (B, T, D)
        x = x + self.drop(self.ffn(self.norm_2(x)))   # (B, T, D)
        return x

class MicroLM(nn.Module):
    """
    Full architecture:
      1. Frozen MiniLM embedding lookup         → (B, T, 384)
      2. Sinusoidal positional encoding added   → (B, T, 384)
      3. N_LAYERS x TransformerBlock            → (B, T, 384)
      4. Final LayerNorm                        → (B, T, 384)
      5. Linear output head → logits            → (B, T, VOCAB_SIZE)
    """
    def __init__(self):
        super().__init__()
        self.register_buffer("embedding_table", embedding_tensor)

        self.blocks = nn.ModuleList([
            TransformerBlock(DIM, N_HEADS, FFN_DIM, dropout=0.1)
            for _ in range(N_LAYERS)
        ])

        self.norm        = LayerNorm(DIM)
        self.output_head = nn.Linear(DIM, VOCAB_SIZE, bias=False)

    def forward(self, token_ids):
        B, T = token_ids.shape

        x = self.embedding_table[token_ids]                    # (B, T, 384)
        x = x + sinusoidal_encoding(T, DIM, token_ids.device) # (B, T, 384)

        for block in self.blocks:
            x = block(x)   # (B, T, 384)

        x = self.norm(x)
        return self.output_head(x)  # (B, T, VOCAB_SIZE)

# %%
model     = MicroLM()
total     = sum(p.numel() for p in model.parameters())
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
frozen    = total - trainable

print(f"Trainable params : {trainable:,}")
print(f"Frozen params    : {frozen:,}  (embedding table)")
print(f"Total params     : {total:,}")

# print(f"\nParam breakdown:")
# for name, p in model.named_parameters():
#     if p.requires_grad:
#         print(f"  {name:55s} {p.numel():>10,}")

# Forward pass
x      = torch.randint(0, VOCAB_SIZE, (2, 32))
logits = model(x)
print(f"\nInput  : {x.shape}")
print(f"Output : {logits.shape}")
# Out:
# Trainable params : 12,605,184
# Frozen params    : 0  (embedding table)
# Total params     : 12,605,184
#
# Input  : torch.Size([2, 32])
# Output : torch.Size([2, 32, 8192])

# %%
# ── Training Config ───────────────────────────────────────────────────────────
import gc
import json
import random
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from pathlib import Path

SHARD_DIR  = Path("dataset_shards")
SEQ_LEN    = 512
BATCH_SIZE = 32
N_EPOCHS   = 3
LOG_EVERY  = 200
CKPT_DIR   = Path("checkpoints_v3")
CKPT_DIR.mkdir(parents=True, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device      : {device}")
print(f"Model params: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# Device      : cuda
# Model params: 12,605,184

# %%
from torch.utils.data import Dataset

SEQ_LEN = 512    # window size
STRIDE  = 448    # step size → 64-token overlap

class ShardDataset(Dataset):
    def __init__(self, shard_path, seq_len=SEQ_LEN, stride=STRIDE):
        flat = torch.load(shard_path, weights_only=True)

        self.flat    = flat.to(torch.int16)
        self.seq_len = seq_len
        self.stride  = stride

        # number of full windows we can extract
        # +1 because we need seq_len+1 tokens (x + y target)
        n_tokens = len(self.flat)
        self.num_samples = max(0, (n_tokens - seq_len - 1) // stride + 1)

    def __len__(self):
        return self.num_samples

    def __getitem__(self, idx):
        start  = idx * self.stride
        tokens = self.flat[start : start + self.seq_len + 1].to(torch.long)  # ← cast here
        
        if len(tokens) < self.seq_len + 1:
            pad    = torch.full((self.seq_len + 1 - len(tokens),), PAD_ID, dtype=torch.long)
            tokens = torch.cat([tokens, pad])

        x = tokens[:-1]
        y = tokens[1:]
        return x, y


BOS_ID       = 2
EOS_ID       = 3

def collate_fn(batch):
    xs, ys = zip(*batch)
    # all samples are now fixed-length (seq_len), so no padding needed here
    x_pad = torch.stack(xs)          # [B, seq_len]
    y_pad = torch.stack(ys).clone()  # [B, seq_len]

    # mask out targets after the first EOS in each sequence
    for i, y in enumerate(y_pad):
        eos_positions = (y == EOS_ID).nonzero(as_tuple=True)[0]
        if len(eos_positions) > 0:
            eos_pos = eos_positions[0].item()
            if eos_pos + 1 < y.size(0):
                y_pad[i, eos_pos + 1:] = -100

    return x_pad, y_pad

# %%
from tokenizers import Tokenizer
TOKENIZER_PATH   = "tokenizer/tokenizer.json"
tokenizer = Tokenizer.from_file(TOKENIZER_PATH)
dataset = ShardDataset("dataset_shards/shard_0000.pt")
for i in range(10,11):
    x, y = dataset[i]
    print(f"\nSample {i}")
    print(f"  x: {x.tolist()}")
    print(f"  y: {tokenizer.decode(x.tolist(), skip_special_tokens=False)}")
    # print(f"  y: {y.tolist()}")
for idx  in x.tolist():
    tok = tokenizer.decode([idx], skip_special_tokens=False)
    print(f"{idx} === '{tok}' ")
# Out:
# Sample 10
#   x: [20, 378, 455, 350, 539, 20, 181, 2690, 18, 220, 446, 742, 603, 894, 847, 236, 3012, 535, 20, 894, 380, 18, 324, 1320, 892, 1345, 222, 2651, 93, 511, 238, 287, 609, 468, 628, 238, 886, 908, 551, 300, 20, 378, 1278, 236, 1345, 222, 2651, 93, 511, 238, 392, 683, 20, 181, 924, 222, 909, 18, 628, 238, 886, 1296, 308, 3537, 296, 708, 20, 378, 1198, 849, 609, 238, 761, 252, 222, 868, 693, 397, 20, 3, 2, 3515, 238, 628, 455, 2916, 89, 20, 378, 949, 236, 392, 304, 1192, 238, 2285, 20, 735, 391, 587, 350, 584, 236, 542, 1487, 238, 3447, 304, 430, 347, 89, 20, 378, 908, 430, 347, 89, 455, 250, 884, 238, 1193, 20, 181, 520, 397, 18, 1487, 238, 3447, 427, 236, 506, 469, 294, 220, 1037, 20, 378, 1206, 927, 238, 628, 236, 287, 708, 238, 387, 611, 430, 347, 89, 20, 378, 380, 391, 568, 2047, 646, 220, 3012, 294, 535, 700, 391, 587, 20, 927, 238, 628, 3038, 18, 429, 391, 587, 350, 1217, 1970, 20, 181, 1271, 1847, 326, 1487, 238, 3447, 1633, 18, 927, 238, 628, 1068, 236, 457, 1096, 20, 378, 985, 469, 457, 1192, 238, 2285, 238, 860, 236, 392, 20, 378, 3003, 270, 551, 222, 430, 347, 89, 20, 378, 427, 632, 238, 744, 220, 900, 253, 2616, 20, 181, 1340, 587, 350, 2572, 222, 1801, 72, 438, 337, 245, 20, 378, 587, 350, 2572, 2238, 536, 931, 289, 222, 1801, 20, 378, 587, 350, 2572, 222, 1801, 1269, 20, 378, 587, 350, 674, 220, 503, 1136, 252, 20, 282, 503, 283, 350, 220, 485, 20, 365, 283, 220, 1549, 503, 20, 365, 610, 236, 911, 881, 403, 222, 975, 20, 181, 398, 503, 544, 927, 238, 628, 1015, 252, 457, 1096, 20, 365, 1055, 220, 1567, 2744, 20, 365, 427, 220, 446, 2569, 238, 220, 2470, 253, 218, 1809, 20, 365, 1727, 236, 457, 1096, 238, 380, 18, 324, 3224, 18, 797, 89, 20, 279, 401, 220, 3012, 294, 306, 20, 1788, 306, 461, 236, 674, 300, 748, 181, 3515, 238, 628, 822, 402, 238, 544, 222, 503, 20, 378, 587, 350, 714, 623, 20, 378, 913, 1187, 20, 378, 1209, 236, 977, 18, 429, 222, 503, 283, 3986, 20, 365, 581, 1804, 231, 535, 238, 839, 535, 252, 354, 2569, 20, 365, 1047, 222, 218, 1809, 236, 1108, 426, 222, 2569, 20, 365, 380, 18, 324, 1320, 345, 575, 3012, 20, 279, 453, 911, 306, 236, 575, 975, 238, 675, 306, 679, 294, 490, 20, 764, 453, 1150, 674, 475, 1192, 238, 2285, 745, 20, 764, 453, 804, 401, 547, 1576, 236, 1485, 32, 289, 260, 20, 357, 1043, 289, 260, 20, 1776, 397, 20, 1438, 387, 306, 584, 308, 748, 181, 3515, 238, 628, 3715, 238, 558, 223, 578, 20, 378, 587, 350, 584, 289, 260, 20, 378, 587, 350, 461, 236, 679, 294, 222, 1549, 503, 20, 378, 610, 457, 1487, 238, 3447, 20, 378, 610, 457, 1192, 238, 2285, 20, 378, 610, 236, 387, 457, 430, 347, 89, 20]
#   y: . They were not happy.
# Then, a big dog named Max came to surprise them. Max said, "You should share the sandwich and be friends." Tom and Sue thought about it. They decided to share the sandwich and play together.
# In the end, Tom and Sue learned that sharing is good. They became best friends and played in the park every day.<eos><bos>Sam and Tom were brothers. They liked to play with toys and books. But they did not like to help Mom and Dad with chores. They thought chores were dull and hard.
# One day, Mom and Dad had to go out for a while. They told Sam and Tom to be good and do some chores. They said they would bring back a surprise for them if they did. Sam and Tom nodded, but they did not really listen.
# As soon as Mom and Dad left, Sam and Tom ran to their room. They took out their toys and books and started to play. They forgot about the chores. They had fun and made a lot of noise.
# They did not hear the doorbell ring. They did not hear someone knock on the door. They did not hear the door open. They did not see a man come in. The man was not a friend. He was a bad man. He wanted to take things from the house.
# The man saw Sam and Tom playing in their room. He smiled a mean smile. He had a big bag and a roll of tape. He walked to their room and said, "Hello, boys. I have a surprise for you. Do you want to see it?"
# Sam and Tom looked up and saw the man. They did not know him. They felt scared. They tried to run, but the man was faster. He grabbed them and put them in his bag. He used the tape to wrap the bag. He said, "You are my surprise. I will take you to my house and make you work for me. You will never see your toys and books again. You will only have one thing to eat: onion. Raw onion. Every day. How do you like that?"
# Sam and Tom cried and screamed. They did not like onion. They did not want to work for the bad man. They wanted their Mom and Dad. They wanted their toys and books. They wanted to do their chores.
# 20 === '.'
# 378 === ' They'
# 455 === ' were'
# 350 === ' not'
# 539 === ' happy'
# 20 === '.'
# 181 === '
# '
# 2690 === 'Then'
# 18 === ','
# 220 === ' a'
# 446 === ' big'
# 742 === ' dog'
# 603 === ' named'
# 894 === ' Max'
# 847 === ' came'
# 236 === ' to'
# 3012 === ' surprise'
# 535 === ' them'
# 20 === '.'
# 894 === ' Max'
# 380 === ' said'
# 18 === ','
# 324 === ' "'
# 1320 === 'You'
# 892 === ' should'
# 1345 === ' share'
# 222 === ' the'
# 2651 === ' sand'
# 93 === 'w'
# 511 === 'ich'
# 238 === ' and'
# 287 === ' be'
# 609 === ' friends'
# 468 === '."'
# 628 === ' Tom'
# 238 === ' and'
# 886 === ' Sue'
# 908 === ' thought'
# 551 === ' about'
# 300 === ' it'
# 20 === '.'
# 378 === ' They'
# 1278 === ' decided'
# 236 === ' to'
# 1345 === ' share'
# 222 === ' the'
# 2651 === ' sand'
# 93 === 'w'
# 511 === 'ich'
# 238 === ' and'
# 392 === ' play'
# 683 === ' together'
# 20 === '.'
# 181 === '
# '
# 924 === 'In'
# 222 === ' the'
# 909 === ' end'
# 18 === ','
# 628 === ' Tom'
# 238 === ' and'
# 886 === ' Sue'
# 1296 === ' learned'
# 308 === ' that'
# 3537 === ' sharing'
# 296 === ' is'
# 708 === ' good'
# 20 === '.'
# 378 === ' They'
# 1198 === ' became'
# 849 === ' best'
# 609 === ' friends'
# 238 === ' and'
# 761 === ' played'
# 252 === ' in'
# 222 === ' the'
# 868 === ' park'
# 693 === ' every'
# 397 === ' day'
# 20 === '.'
# 3 === '<eos>'
# 2 === '<bos>'
# 3515 === 'Sam'
# 238 === ' and'
# 628 === ' Tom'
# 455 === ' were'
# 2916 === ' brother'
# 89 === 's'
# 20 === '.'
# 378 === ' They'
# 949 === ' liked'
# 236 === ' to'
# 392 === ' play'
# 304 === ' with'
# 1192 === ' toys'
# 238 === ' and'
# 2285 === ' books'
# 20 === '.'
# 735 === ' But'
# 391 === ' they'
# 587 === ' did'
# 350 === ' not'
# 584 === ' like'
# 236 === ' to'
# 542 === ' help'
# 1487 === ' Mom'
# 238 === ' and'
# 3447 === ' Dad'
# 304 === ' with'
# 430 === ' ch'
# 347 === 'ore'
# 89 === 's'
# 20 === '.'
# 378 === ' They'
# 908 === ' thought'
# 430 === ' ch'
# 347 === 'ore'
# 89 === 's'
# 455 === ' were'
# 250 === ' d'
# 884 === 'ull'
# 238 === ' and'
# 1193 === ' hard'
# 20 === '.'
# 181 === '
# '
# 520 === 'One'
# 397 === ' day'
# 18 === ','
# 1487 === ' Mom'
# 238 === ' and'
# 3447 === ' Dad'
# 427 === ' had'
# 236 === ' to'
# 506 === ' go'
# 469 === ' out'
# 294 === ' for'
# 220 === ' a'
# 1037 === ' while'
# 20 === '.'
# 378 === ' They'
# 1206 === ' told'
# 927 === ' Sam'
# 238 === ' and'
# 628 === ' Tom'
# 236 === ' to'
# 287 === ' be'
# 708 === ' good'
# 238 === ' and'
# 387 === ' do'
# 611 === ' some'
# 430 === ' ch'
# 347 === 'ore'
# 89 === 's'
# 20 === '.'
# 378 === ' They'
# 380 === ' said'
# 391 === ' they'
# 568 === ' would'
# 2047 === ' bring'
# 646 === ' back'
# 220 === ' a'
# 3012 === ' surprise'
# 294 === ' for'
# 535 === ' them'
# 700 === ' if'
# 391 === ' they'
# 587 === ' did'
# 20 === '.'
# 927 === ' Sam'
# 238 === ' and'
# 628 === ' Tom'
# 3038 === ' nodded'
# 18 === ','
# 429 === ' but'
# 391 === ' they'
# 587 === ' did'
# 350 === ' not'
# 1217 === ' really'
# 1970 === ' listen'
# 20 === '.'
# 181 === '
# '
# 1271 === 'As'
# 1847 === ' soon'
# 326 === ' as'
# 1487 === ' Mom'
# 238 === ' and'
# 3447 === ' Dad'
# 1633 === ' left'
# 18 === ','
# 927 === ' Sam'
# 238 === ' and'
# 628 === ' Tom'
# 1068 === ' ran'
# 236 === ' to'
# 457 === ' their'
# 1096 === ' room'
# 20 === '.'
# 378 === ' They'
# 985 === ' took'
# 469 === ' out'
# 457 === ' their'
# 1192 === ' toys'
# 238 === ' and'
# 2285 === ' books'
# 238 === ' and'
# 860 === ' started'
# 236 === ' to'
# 392 === ' play'
# 20 === '.'
# 378 === ' They'
# 3003 === ' forg'
# 270 === 'ot'
# 551 === ' about'
# 222 === ' the'
# 430 === ' ch'
# 347 === 'ore'
# 89 === 's'
# 20 === '.'
# 378 === ' They'
# 427 === ' had'
# 632 === ' fun'
# 238 === ' and'
# 744 === ' made'
# 220 === ' a'
# 900 === ' lot'
# 253 === ' of'
# 2616 === ' noise'
# 20 === '.'
# 181 === '
# '
# 1340 === 'They'
# 587 === ' did'
# 350 === ' not'
# 2572 === ' hear'
# 222 === ' the'
# 1801 === ' door'
# 72 === 'b'
# 438 === 'ell'
# 337 === ' r'
# 245 === 'ing'
# 20 === '.'
# 378 === ' They'
# 587 === ' did'
# 350 === ' not'
# 2572 === ' hear'
# 2238 === ' someone'
# 536 === ' kn'
# 931 === 'ock'
# 289 === ' on'
# 222 === ' the'
# 1801 === ' door'
# 20 === '.'
# 378 === ' They'
# 587 === ' did'
# 350 === ' not'
# 2572 === ' hear'
# 222 === ' the'
# 1801 === ' door'
# 1269 === ' open'
# 20 === '.'
# 378 === ' They'
# 587 === ' did'
# 350 === ' not'
# 674 === ' see'
# 220 === ' a'
# 503 === ' man'
# 1136 === ' come'
# 252 === ' in'
# 20 === '.'
# 282 === ' The'
# 503 === ' man'
# 283 === ' was'
# 350 === ' not'
# 220 === ' a'
# 485 === ' friend'
# 20 === '.'
# 365 === ' He'
# 283 === ' was'
# 220 === ' a'
# 1549 === ' bad'
# 503 === ' man'
# 20 === '.'
# 365 === ' He'
# 610 === ' wanted'
# 236 === ' to'
# 911 === ' take'
# 881 === ' things'
# 403 === ' from'
# 222 === ' the'
# 975 === ' house'
# 20 === '.'
# 181 === '
# '
# 398 === 'The'
# 503 === ' man'
# 544 === ' saw'
# 927 === ' Sam'
# 238 === ' and'
# 628 === ' Tom'
# 1015 === ' playing'
# 252 === ' in'
# 457 === ' their'
# 1096 === ' room'
# 20 === '.'
# 365 === ' He'
# 1055 === ' smiled'
# 220 === ' a'
# 1567 === ' mean'
# 2744 === ' smile'
# 20 === '.'
# 365 === ' He'
# 427 === ' had'
# 220 === ' a'
# 446 === ' big'
# 2569 === ' bag'
# 238 === ' and'
# 220 === ' a'
# 2470 === ' roll'
# 253 === ' of'
# 218 === ' t'
# 1809 === 'ape'
# 20 === '.'
# 365 === ' He'
# 1727 === ' walked'
# 236 === ' to'
# 457 === ' their'
# 1096 === ' room'
# 238 === ' and'
# 380 === ' said'
# 18 === ','
# 324 === ' "'
# 3224 === 'Hello'
# 18 === ','
# 797 === ' boy'
# 89 === 's'
# 20 === '.'
# 279 === ' I'
# 401 === ' have'
# 220 === ' a'
# 3012 === ' surprise'
# 294 === ' for'
# 306 === ' you'
# 20 === '.'
# 1788 === ' Do'
# 306 === ' you'
# 461 === ' want'
# 236 === ' to'
# 674 === ' see'
# 300 === ' it'
# 748 === '?"'
# 181 === '
# '
# 3515 === 'Sam'
# 238 === ' and'
# 628 === ' Tom'
# 822 === ' looked'
# 402 === ' up'
# 238 === ' and'
# 544 === ' saw'
# 222 === ' the'
# 503 === ' man'
# 20 === '.'
# 378 === ' They'
# 587 === ' did'
# 350 === ' not'
# 714 === ' know'
# 623 === ' him'
# 20 === '.'
# 378 === ' They'
# 913 === ' felt'
# 1187 === ' scared'
# 20 === '.'
# 378 === ' They'
# 1209 === ' tried'
# 236 === ' to'
# 977 === ' run'
# 18 === ','
# 429 === ' but'
# 222 === ' the'
# 503 === ' man'
# 283 === ' was'
# 3986 === ' faster'
# 20 === '.'
# 365 === ' He'
# 581 === ' gr'
# 1804 === 'abb'
# 231 === 'ed'
# 535 === ' them'
# 238 === ' and'
# 839 === ' put'
# 535 === ' them'
# 252 === ' in'
# 354 === ' his'
# 2569 === ' bag'
# 20 === '.'
# 365 === ' He'
# 1047 === ' used'
# 222 === ' the'
# 218 === ' t'
# 1809 === 'ape'
# 236 === ' to'
# 1108 === ' wr'
# 426 === 'ap'
# 222 === ' the'
# 2569 === ' bag'
# 20 === '.'
# 365 === ' He'
# 380 === ' said'
# 18 === ','
# 324 === ' "'
# 1320 === 'You'
# 345 === ' are'
# 575 === ' my'
# 3012 === ' surprise'
# 20 === '.'
# 279 === ' I'
# 453 === ' will'
# 911 === ' take'
# 306 === ' you'
# 236 === ' to'
# 575 === ' my'
# 975 === ' house'
# 238 === ' and'
# 675 === ' make'
# 306 === ' you'
# 679 === ' work'
# 294 === ' for'
# 490 === ' me'
# 20 === '.'
# 764 === ' You'
# 453 === ' will'
# 1150 === ' never'
# 674 === ' see'
# 475 === ' your'
# 1192 === ' toys'
# 238 === ' and'
# 2285 === ' books'
# 745 === ' again'
# 20 === '.'
# 764 === ' You'
# 453 === ' will'
# 804 === ' only'
# 401 === ' have'
# 547 === ' one'
# 1576 === ' thing'
# 236 === ' to'
# 1485 === ' eat'
# 32 === ':'
# 289 === ' on'
# 260 === 'ion'
# 20 === '.'
# 357 === ' R'
# 1043 === 'aw'
# 289 === ' on'
# 260 === 'ion'
# 20 === '.'
# 1776 === ' Every'
# 397 === ' day'
# 20 === '.'
# 1438 === ' How'
# 387 === ' do'
# 306 === ' you'
# 584 === ' like'
# 308 === ' that'
# 748 === '?"'
# 181 === '
# '
# 3515 === 'Sam'
# 238 === ' and'
# 628 === ' Tom'
# 3715 === ' cried'
# 238 === ' and'
# 558 === ' sc'
# 223 === 're'
# 578 === 'amed'
# 20 === '.'
# 378 === ' They'
# 587 === ' did'
# 350 === ' not'
# 584 === ' like'
# 289 === ' on'
# 260 === 'ion'
# 20 === '.'
# 378 === ' They'
# 587 === ' did'
# 350 === ' not'
# 461 === ' want'
# 236 === ' to'
# 679 === ' work'
# 294 === ' for'
# 222 === ' the'
# 1549 === ' bad'
# 503 === ' man'
# 20 === '.'
# 378 === ' They'
# 610 === ' wanted'
# 457 === ' their'
# 1487 === ' Mom'
# 238 === ' and'
# 3447 === ' Dad'
# 20 === '.'
# 378 === ' They'
# 610 === ' wanted'
# 457 === ' their'
# 1192 === ' toys'
# 238 === ' and'
# 2285 === ' books'
# 20 === '.'
# 378 === ' They'
# 610 === ' wanted'
# 236 === ' to'
# 387 === ' do'
# 457 === ' their'
# 430 === ' ch'
# 347 === 'ore'
# 89 === 's'
# 20 === '.'

# %%
# run once after sharding
# meta = {
#     "total_samples": sum(len(ShardDataset(p)) for p in sorted(SHARD_DIR.glob("shard_*.pt"))),
#     "seq_len": SEQ_LEN,
#     "stride": STRIDE,
# }
# with open(SHARD_DIR / "meta.json", "w") as f:
#     json.dump(meta, f, indent=2)
    
# ── Optimizer & Scheduler ─────────────────────────────────────────────────────

with open(SHARD_DIR / "meta.json") as f:
    meta = json.load(f)

total_steps = (meta['total_samples'] // BATCH_SIZE) * N_EPOCHS

optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4, weight_decay=0.1)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=total_steps, eta_min=1e-5
)
scaler    = torch.cuda.amp.GradScaler()

print(f"Total samples: {meta['total_samples']:,}")
print(f"Total steps  : {total_steps:,}")
# Out:
# Total samples: 5,751,488
# Total steps  : 539,202
# /tmp/ipykernel_287471/892036717.py:21: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler    = torch.cuda.amp.GradScaler()

# %%
model.to(device)
# Out:
# MicroLM(
#   (blocks): ModuleList(
#     (0-7): 8 x TransformerBlock(
#       (norm_1): LayerNorm()
#       (attn): MultiHeadCausalAttention(
#         (W_q): Linear(in_features=384, out_features=384, bias=False)
#         (W_k): Linear(in_features=384, out_features=384, bias=False)
#         (W_v): Linear(in_features=384, out_features=384, bias=False)
#         (W_o): Linear(in_features=384, out_features=384, bias=False)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#       )
#       (norm_2): LayerNorm()
#       (ffn): FeedForward(
#         (W_1): Linear(in_features=384, out_features=768, bias=True)
#         (W_2): Linear(in_features=768, out_features=384, bias=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#       (drop): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (norm): LayerNorm()
#   (output_head): Linear(in_features=384, out_features=8192, bias=False)
# )

# %%
shard_files  = sorted(SHARD_DIR.glob("shard_*.pt"))[:1]
shard_files
# Out:
# [PosixPath('dataset_shards/shard_0000.pt')]

# %%
# ── Training Loop with Resume ─────────────────────────────────────────────────
import math

shard_files  = sorted(SHARD_DIR.glob("shard_*.pt"))[:1]
loss_history = []
start_epoch  = 0
start_shard  = 0

# ── Resume from latest checkpoint ────────────────────────────────────────────
# Check mid-epoch checkpoints first, then epoch checkpoints
all_ckpts = sorted(CKPT_DIR.glob("epoch_*.pt"))
mid_ckpts  = [c for c in all_ckpts if "shard" in c.name]
epoch_ckpts = [c for c in all_ckpts if "shard" not in c.name]

if mid_ckpts:
    latest = mid_ckpts[-1]
    print(f"Resuming from mid-epoch checkpoint {latest}...")
    ckpt = torch.load(latest, map_location=device)
    model.load_state_dict(ckpt["model"])
    optimizer.load_state_dict(ckpt["optimizer"])
    scheduler.load_state_dict(ckpt["scheduler"])
    loss_history = ckpt.get("loss_history", [])
    start_epoch  = ckpt["epoch"] - 1        # epoch is 1-indexed, range is 0-indexed
    start_shard  = ckpt["shard"] + 1        # resume from next shard
    print(f"Resumed — epoch {start_epoch+1}, starting from shard {start_shard+1}")

elif epoch_ckpts:
    latest = epoch_ckpts[-1]
    print(f"Resuming from epoch checkpoint {latest}...")
    ckpt = torch.load(latest, map_location=device)
    model.load_state_dict(ckpt["model"])
    optimizer.load_state_dict(ckpt["optimizer"])
    scheduler.load_state_dict(ckpt["scheduler"])
    loss_history = ckpt.get("loss_history", [])
    start_epoch  = ckpt["epoch"]            # full epoch completed
    start_shard  = 0                        # start from beginning of next epoch
    print(f"Resumed — starting from epoch {start_epoch+1}")

else:
    print("No checkpoint found — training from scratch")

model.to(device)
model.train()

for epoch in range(start_epoch, N_EPOCHS):
    epoch_loss  = 0.0
    epoch_steps = 0

    # no shuffle — sequential shard order
    shard_order = list(range(len(shard_files)))

    # if resuming mid-epoch, skip already completed shards
    if epoch == start_epoch and start_shard > 0:
        shard_order = shard_order[start_shard:]
        print(f"Skipping shards 0-{start_shard-1}, resuming from shard {start_shard}")

    print(f"\n{'='*60}")
    print(f"Epoch {epoch+1}/{N_EPOCHS}")
    print(f"{'='*60}")

    for shard_num, shard_idx in enumerate(shard_order):
        # just before the step loop:
        shard_start = time.time()
        interval_start = time.time()
        
        # actual shard number in epoch (accounts for skipped shards on resume)
        actual_shard_num = shard_idx  

        shard_path = shard_files[shard_idx]
        print(f"\n[Epoch {epoch+1}] Shard {actual_shard_num+1}/{len(shard_files)} — {shard_path.name}")

        ds     = ShardDataset(shard_path)
        loader = DataLoader(
            ds,
            batch_size=BATCH_SIZE,
            shuffle=True,
            collate_fn=collate_fn,
            num_workers=0,
            pin_memory=True,
        )

        shard_loss  = 0.0
        shard_steps = 0

        for step, (x, y) in enumerate(loader):
            x = x.to(device)
            y = y.to(device)

            optimizer.zero_grad()

            with torch.autocast(device_type="cuda", dtype=torch.bfloat16):
                logits = model(x)
                loss   = F.cross_entropy(
                    logits.view(-1, logits.size(-1)),
                    y.view(-1),
                    ignore_index=-100,
                )
                del logits  # free 268MB immediately before backward


            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()

            if not math.isnan(loss.item()):
                shard_loss  += loss.item()
                shard_steps += 1
                epoch_loss  += loss.item()
                epoch_steps += 1

            if step % LOG_EVERY == 0:
                avg = shard_loss / max(shard_steps, 1)
                ppl = math.exp(min(avg, 20))
                lr  = scheduler.get_last_lr()[0]
                elapsed_total = time.time() - shard_start
                interval_time = time.time() - interval_start
                print(f"  step {step:>5} | loss {loss.item():.4f} | avg {avg:.4f} | ppl {ppl:.2f} | lr {lr:.2e} | last {LOG_EVERY} steps: {interval_time:.1f}s | total: {elapsed_total:.0f}s")
                interval_start = time.time()  # reset for next interval

            del loss, x, y
        shard_avg = shard_loss / max(shard_steps, 1)
        shard_ppl = math.exp(min(shard_avg, 20))
        loss_history.append({
            "epoch":      epoch + 1,
            "shard":      actual_shard_num,
            "avg_loss":   shard_avg,
            "perplexity": shard_ppl,
        })
        print(f"  Shard done — avg loss: {shard_avg:.4f} | ppl {shard_ppl:.2f}")

        del ds, loader
        gc.collect()
        torch.cuda.empty_cache()

        # mid-epoch checkpoint every 5 shards
        if (actual_shard_num + 1) % 2 == 0:
            ckpt_path = CKPT_DIR / f"epoch_{epoch+1}_shard_{actual_shard_num}.pt"
            torch.save({
                "epoch":        epoch + 1,
                "shard":        actual_shard_num,
                "model":        model.state_dict(),
                "optimizer":    optimizer.state_dict(),
                "scheduler":    scheduler.state_dict(),
                "loss_history": loss_history,
            }, ckpt_path)
            print(f"Mid-epoch checkpoint saved → {ckpt_path}")

    # reset start_shard after first resumed epoch
    start_shard = 0

    epoch_avg = epoch_loss / max(epoch_steps, 1)
    epoch_ppl = math.exp(min(epoch_avg, 20))
    print(f"\nEpoch {epoch+1} complete — avg loss: {epoch_avg:.4f} | ppl {epoch_ppl:.2f}")

    ckpt_path = CKPT_DIR / f"epoch_{epoch+1}.pt"
    torch.save({
        "epoch":        epoch + 1,
        "shard":        -1,
        "model":        model.state_dict(),
        "optimizer":    optimizer.state_dict(),
        "scheduler":    scheduler.state_dict(),
        "loss_history": loss_history,
    }, ckpt_path)
    print(f"Epoch checkpoint saved → {ckpt_path}")

    with open(CKPT_DIR / "loss_history.json", "w") as f:
        json.dump(loss_history, f, indent=2)

print("\nTraining complete.")
# Out:
# No checkpoint found — training from scratch
#
# ============================================================
# Epoch 1/3
# ============================================================
#
# [Epoch 1] Shard 1/1 — shard_0000.pt
#   step     0 | loss 9.1919 | avg 9.1919 | ppl 9817.43 | lr 3.00e-04 | last 200 steps: 3.3s | total: 3s
#   step   200 | loss 5.7633 | avg 6.0938 | ppl 443.11 | lr 3.00e-04 | last 200 steps: 43.5s | total: 47s
#   step   400 | loss 5.3597 | avg 5.8189 | ppl 336.60 | lr 3.00e-04 | last 200 steps: 43.1s | total: 90s
#   step   600 | loss 5.0846 | avg 5.6428 | ppl 282.24 | lr 3.00e-04 | last 200 steps: 43.1s | total: 133s
#   step   800 | loss 4.7542 | avg 5.4593 | ppl 234.94 | lr 3.00e-04 | last 200 steps: 43.1s | total: 176s
#   step  1000 | loss 4.5030 | avg 5.2866 | ppl 197.68 | lr 3.00e-04 | last 200 steps: 43.1s | total: 219s
#   step  1200 | loss 4.1322 | avg 5.1230 | ppl 167.85 | lr 3.00e-04 | last 200 steps: 43.1s | total: 262s
#   step  1400 | loss 4.1126 | avg 4.9739 | ppl 144.59 | lr 3.00e-04 | last 200 steps: 43.1s | total: 305s
#   step  1600 | loss 3.7768 | avg 4.8395 | ppl 126.41 | lr 3.00e-04 | last 200 steps: 43.2s | total: 349s
#   step  1800 | loss 3.6258 | avg 4.7189 | ppl 112.04 | lr 3.00e-04 | last 200 steps: 43.2s | total: 392s
#   step  2000 | loss 3.6950 | avg 4.6091 | ppl 100.40 | lr 3.00e-04 | last 200 steps: 43.3s | total: 435s
#   step  2200 | loss 3.5722 | avg 4.5080 | ppl 90.74 | lr 3.00e-04 | last 200 steps: 43.3s | total: 478s
#   step  2400 | loss 3.3657 | avg 4.4151 | ppl 82.69 | lr 3.00e-04 | last 200 steps: 43.3s | total: 522s
#   step  2600 | loss 3.1937 | avg 4.3290 | ppl 75.87 | lr 3.00e-04 | last 200 steps: 43.3s | total: 565s
#   step  2800 | loss 3.1598 | avg 4.2493 | ppl 70.06 | lr 3.00e-04 | last 200 steps: 43.3s | total: 608s
#   step  3000 | loss 3.2550 | avg 4.1762 | ppl 65.12 | lr 3.00e-04 | last 200 steps: 43.4s | total: 652s
#   step  3200 | loss 2.8980 | avg 4.1071 | ppl 60.77 | lr 3.00e-04 | last 200 steps: 43.4s | total: 695s
#   step  3400 | loss 2.9136 | avg 4.0430 | ppl 57.00 | lr 3.00e-04 | last 200 steps: 43.3s | total: 738s
#   step  3600 | loss 2.7860 | avg 3.9823 | ppl 53.64 | lr 3.00e-04 | last 200 steps: 43.2s | total: 781s
#   step  3800 | loss 2.8548 | avg 3.9248 | ppl 50.64 | lr 3.00e-04 | last 200 steps: 43.1s | total: 825s
#   step  4000 | loss 2.8964 | avg 3.8701 | ppl 47.95 | lr 3.00e-04 | last 200 steps: 43.2s | total: 868s
#   step  4200 | loss 2.7881 | avg 3.8181 | ppl 45.52 | lr 3.00e-04 | last 200 steps: 43.3s | total: 911s
#   step  4400 | loss 2.5902 | avg 3.7690 | ppl 43.34 | lr 3.00e-04 | last 200 steps: 43.2s | total: 954s
#   step  4600 | loss 2.7152 | avg 3.7227 | ppl 41.38 | lr 3.00e-04 | last 200 steps: 43.1s | total: 997s
#   step  4800 | loss 2.8374 | avg 3.6783 | ppl 39.58 | lr 3.00e-04 | last 200 steps: 43.1s | total: 1041s
#   step  5000 | loss 2.6249 | avg 3.6357 | ppl 37.93 | lr 3.00e-04 | last 200 steps: 43.2s | total: 1084s
#   step  5200 | loss 2.3445 | avg 3.5950 | ppl 36.41 | lr 3.00e-04 | last 200 steps: 43.2s | total: 1127s
#   step  5400 | loss 2.4491 | avg 3.5567 | ppl 35.05 | lr 3.00e-04 | last 200 steps: 43.2s | total: 1170s
#   step  5600 | loss 2.5275 | avg 3.5200 | ppl 33.78 | lr 3.00e-04 | last 200 steps: 43.3s | total: 1213s
#   step  5800 | loss 2.5531 | avg 3.4847 | ppl 32.61 | lr 3.00e-04 | last 200 steps: 43.4s | total: 1257s
#   step  6000 | loss 2.4138 | avg 3.4509 | ppl 31.53 | lr 3.00e-04 | last 200 steps: 43.2s | total: 1300s
#   step  6200 | loss 2.3515 | avg 3.4187 | ppl 30.53 | lr 3.00e-04 | last 200 steps: 43.1s | total: 1343s
#   step  6400 | loss 2.4568 | avg 3.3876 | ppl 29.60 | lr 3.00e-04 | last 200 steps: 43.1s | total: 1386s
#   step  6600 | loss 2.2641 | avg 3.3582 | ppl 28.74 | lr 3.00e-04 | last 200 steps: 43.2s | total: 1429s
#   step  6800 | loss 2.3093 | avg 3.3294 | ppl 27.92 | lr 3.00e-04 | last 200 steps: 43.2s | total: 1473s
#   step  7000 | loss 2.3169 | avg 3.3022 | ppl 27.17 | lr 3.00e-04 | last 200 steps: 43.2s | total: 1516s
#   step  7200 | loss 2.3753 | avg 3.2762 | ppl 26.48 | lr 3.00e-04 | last 200 steps: 43.2s | total: 1559s
#   step  7400 | loss 2.4180 | avg 3.2511 | ppl 25.82 | lr 3.00e-04 | last 200 steps: 43.1s | total: 1602s
#   step  7600 | loss 2.4596 | avg 3.2267 | ppl 25.20 | lr 3.00e-04 | last 200 steps: 43.1s | total: 1645s
#   step  7800 | loss 2.2223 | avg 3.2032 | ppl 24.61 | lr 3.00e-04 | last 200 steps: 43.2s | total: 1688s
#   step  8000 | loss 2.2055 | avg 3.1807 | ppl 24.06 | lr 3.00e-04 | last 200 steps: 43.2s | total: 1732s
#   step  8200 | loss 2.2953 | avg 3.1589 | ppl 23.55 | lr 3.00e-04 | last 200 steps: 43.1s | total: 1775s
#   step  8400 | loss 2.3844 | avg 3.1382 | ppl 23.06 | lr 3.00e-04 | last 200 steps: 43.1s | total: 1818s
#   step  8600 | loss 2.1720 | avg 3.1180 | ppl 22.60 | lr 3.00e-04 | last 200 steps: 43.1s | total: 1861s
#   step  8800 | loss 2.2129 | avg 3.0986 | ppl 22.17 | lr 3.00e-04 | last 200 steps: 43.1s | total: 1904s
#   step  9000 | loss 2.3003 | avg 3.0799 | ppl 21.76 | lr 3.00e-04 | last 200 steps: 43.2s | total: 1947s
#   step  9200 | loss 2.2996 | avg 3.0618 | ppl 21.37 | lr 3.00e-04 | last 200 steps: 43.2s | total: 1990s
#   step  9400 | loss 2.0548 | avg 3.0441 | ppl 20.99 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2033s
#   step  9600 | loss 2.1745 | avg 3.0271 | ppl 20.64 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2077s
#   step  9800 | loss 2.1663 | avg 3.0105 | ppl 20.30 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2120s
#   step 10000 | loss 2.2605 | avg 2.9947 | ppl 19.98 | lr 3.00e-04 | last 200 steps: 43.2s | total: 2163s
#   step 10200 | loss 2.3557 | avg 2.9790 | ppl 19.67 | lr 3.00e-04 | last 200 steps: 43.2s | total: 2206s
#   step 10400 | loss 2.1382 | avg 2.9641 | ppl 19.38 | lr 3.00e-04 | last 200 steps: 43.2s | total: 2249s
#   step 10600 | loss 2.2627 | avg 2.9494 | ppl 19.09 | lr 3.00e-04 | last 200 steps: 43.2s | total: 2292s
#   step 10800 | loss 2.1150 | avg 2.9351 | ppl 18.82 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2336s
#   step 11000 | loss 2.1208 | avg 2.9212 | ppl 18.56 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2379s
#   step 11200 | loss 2.2039 | avg 2.9077 | ppl 18.31 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2422s
#   step 11400 | loss 2.1236 | avg 2.8947 | ppl 18.08 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2465s
#   step 11600 | loss 2.1715 | avg 2.8818 | ppl 17.85 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2508s
#   step 11800 | loss 2.1644 | avg 2.8693 | ppl 17.62 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2551s
#   step 12000 | loss 2.1012 | avg 2.8572 | ppl 17.41 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2594s
#   step 12200 | loss 2.3190 | avg 2.8454 | ppl 17.21 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2637s
#   step 12400 | loss 2.2388 | avg 2.8338 | ppl 17.01 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2681s
#   step 12600 | loss 2.2626 | avg 2.8226 | ppl 16.82 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2724s
#   step 12800 | loss 2.2263 | avg 2.8115 | ppl 16.63 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2767s
#   step 13000 | loss 2.1186 | avg 2.8008 | ppl 16.46 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2810s
#   step 13200 | loss 2.0976 | avg 2.7904 | ppl 16.29 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2853s
#   step 13400 | loss 2.1368 | avg 2.7803 | ppl 16.12 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2896s
#   step 13600 | loss 2.0545 | avg 2.7703 | ppl 15.96 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2939s
#   step 13800 | loss 1.9577 | avg 2.7605 | ppl 15.81 | lr 3.00e-04 | last 200 steps: 43.1s | total: 2982s
#   step 14000 | loss 2.1045 | avg 2.7511 | ppl 15.66 | lr 3.00e-04 | last 200 steps: 43.1s | total: 3026s
#   step 14200 | loss 2.0120 | avg 2.7418 | ppl 15.51 | lr 3.00e-04 | last 200 steps: 43.1s | total: 3069s
#   step 14400 | loss 1.9905 | avg 2.7327 | ppl 15.37 | lr 2.99e-04 | last 200 steps: 43.1s | total: 3112s
#   step 14600 | loss 1.9801 | avg 2.7239 | ppl 15.24 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3155s
#   step 14800 | loss 2.1572 | avg 2.7152 | ppl 15.11 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3198s
#   step 15000 | loss 1.8955 | avg 2.7066 | ppl 14.98 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3241s
#   step 15200 | loss 2.1113 | avg 2.6982 | ppl 14.85 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3285s
#   step 15400 | loss 2.0246 | avg 2.6901 | ppl 14.73 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3328s
#   step 15600 | loss 2.0011 | avg 2.6820 | ppl 14.61 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3371s
#   step 15800 | loss 2.0265 | avg 2.6742 | ppl 14.50 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3414s
#   step 16000 | loss 2.0677 | avg 2.6664 | ppl 14.39 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3457s
#   step 16200 | loss 2.0127 | avg 2.6589 | ppl 14.28 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3501s
#   step 16400 | loss 2.0696 | avg 2.6516 | ppl 14.18 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3544s
#   step 16600 | loss 1.8798 | avg 2.6441 | ppl 14.07 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3587s
#   step 16800 | loss 2.0446 | avg 2.6369 | ppl 13.97 | lr 2.99e-04 | last 200 steps: 43.1s | total: 3630s
#   step 17000 | loss 2.0553 | avg 2.6298 | ppl 13.87 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3673s
#   step 17200 | loss 2.0633 | avg 2.6231 | ppl 13.78 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3716s
#   step 17400 | loss 2.0240 | avg 2.6163 | ppl 13.69 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3760s
#   step 17600 | loss 2.0169 | avg 2.6098 | ppl 13.60 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3803s
#   step 17800 | loss 1.9825 | avg 2.6034 | ppl 13.51 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3846s
#   step 18000 | loss 2.1224 | avg 2.5970 | ppl 13.42 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3889s
#   step 18200 | loss 2.2062 | avg 2.5906 | ppl 13.34 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3932s
#   step 18400 | loss 1.9891 | avg 2.5843 | ppl 13.25 | lr 2.99e-04 | last 200 steps: 43.2s | total: 3975s
#   step 18600 | loss 1.9228 | avg 2.5781 | ppl 13.17 | lr 2.99e-04 | last 200 steps: 43.2s | total: 4019s
#   Shard done — avg loss: 2.5743 | ppl 13.12
#
# Epoch 1 complete — avg loss: 2.5743 | ppl 13.12
# Epoch checkpoint saved → checkpoints_v3/epoch_1.pt
#
# ============================================================
# Epoch 2/3
# ============================================================
#
# [Epoch 2] Shard 1/1 — shard_0000.pt
#   step     0 | loss 2.0618 | avg 2.0618 | ppl 7.86 | lr 2.99e-04 | last 200 steps: 2.5s | total: 2s
#   step   200 | loss 2.0059 | avg 2.0044 | ppl 7.42 | lr 2.99e-04 | last 200 steps: 43.4s | total: 46s
#   step   400 | loss 1.9112 | avg 2.0000 | ppl 7.39 | lr 2.99e-04 | last 200 steps: 43.4s | total: 89s
#   step   600 | loss 2.0079 | avg 2.0022 | ppl 7.41 | lr 2.99e-04 | last 200 steps: 43.3s | total: 133s
#   step   800 | loss 2.1303 | avg 2.0027 | ppl 7.41 | lr 2.99e-04 | last 200 steps: 43.2s | total: 176s
#   step  1000 | loss 2.1402 | avg 2.0026 | ppl 7.41 | lr 2.99e-04 | last 200 steps: 43.2s | total: 219s
#   step  1200 | loss 1.9471 | avg 2.0035 | ppl 7.41 | lr 2.99e-04 | last 200 steps: 43.2s | total: 262s
#   step  1400 | loss 2.0166 | avg 2.0037 | ppl 7.42 | lr 2.99e-04 | last 200 steps: 43.2s | total: 305s
#   step  1600 | loss 2.0526 | avg 2.0027 | ppl 7.41 | lr 2.99e-04 | last 200 steps: 43.2s | total: 349s
#   step  1800 | loss 1.9415 | avg 2.0019 | ppl 7.40 | lr 2.99e-04 | last 200 steps: 43.2s | total: 392s
#   step  2000 | loss 1.9468 | avg 2.0006 | ppl 7.39 | lr 2.99e-04 | last 200 steps: 43.2s | total: 435s
#   step  2200 | loss 1.9663 | avg 2.0003 | ppl 7.39 | lr 2.99e-04 | last 200 steps: 43.2s | total: 478s
#   step  2400 | loss 2.0041 | avg 1.9991 | ppl 7.38 | lr 2.99e-04 | last 200 steps: 43.2s | total: 521s
#   step  2600 | loss 2.0101 | avg 1.9979 | ppl 7.37 | lr 2.99e-04 | last 200 steps: 43.2s | total: 565s
#   step  2800 | loss 1.9213 | avg 1.9971 | ppl 7.37 | lr 2.99e-04 | last 200 steps: 43.2s | total: 608s
#   step  3000 | loss 1.9573 | avg 1.9961 | ppl 7.36 | lr 2.99e-04 | last 200 steps: 43.2s | total: 651s
#   step  3200 | loss 1.8361 | avg 1.9952 | ppl 7.35 | lr 2.99e-04 | last 200 steps: 43.2s | total: 694s
#   step  3400 | loss 1.8181 | avg 1.9947 | ppl 7.35 | lr 2.99e-04 | last 200 steps: 43.2s | total: 738s
#   step  3600 | loss 1.9858 | avg 1.9939 | ppl 7.34 | lr 2.99e-04 | last 200 steps: 43.3s | total: 781s
#   step  3800 | loss 2.0376 | avg 1.9929 | ppl 7.34 | lr 2.99e-04 | last 200 steps: 43.2s | total: 824s
#   step  4000 | loss 1.9935 | avg 1.9915 | ppl 7.33 | lr 2.99e-04 | last 200 steps: 43.2s | total: 867s
#   step  4200 | loss 1.8298 | avg 1.9905 | ppl 7.32 | lr 2.99e-04 | last 200 steps: 43.2s | total: 911s
#   step  4400 | loss 1.9426 | avg 1.9894 | ppl 7.31 | lr 2.99e-04 | last 200 steps: 43.2s | total: 954s
#   step  4600 | loss 1.9547 | avg 1.9887 | ppl 7.31 | lr 2.99e-04 | last 200 steps: 43.2s | total: 997s
#   step  4800 | loss 2.0440 | avg 1.9881 | ppl 7.30 | lr 2.99e-04 | last 200 steps: 43.2s | total: 1040s
#   step  5000 | loss 2.0172 | avg 1.9872 | ppl 7.30 | lr 2.99e-04 | last 200 steps: 43.3s | total: 1083s
#   step  5200 | loss 1.9284 | avg 1.9864 | ppl 7.29 | lr 2.99e-04 | last 200 steps: 43.3s | total: 1127s
#   step  5400 | loss 1.9185 | avg 1.9855 | ppl 7.28 | lr 2.99e-04 | last 200 steps: 43.2s | total: 1170s
#   step  5600 | loss 2.2546 | avg 1.9846 | ppl 7.28 | lr 2.99e-04 | last 200 steps: 43.3s | total: 1213s
#   step  5800 | loss 1.9927 | avg 1.9839 | ppl 7.27 | lr 2.99e-04 | last 200 steps: 43.2s | total: 1256s
#   step  6000 | loss 1.9699 | avg 1.9834 | ppl 7.27 | lr 2.98e-04 | last 200 steps: 43.2s | total: 1300s
#   step  6200 | loss 1.9120 | avg 1.9824 | ppl 7.26 | lr 2.98e-04 | last 200 steps: 43.3s | total: 1343s
#   step  6400 | loss 2.0334 | avg 1.9816 | ppl 7.25 | lr 2.98e-04 | last 200 steps: 43.2s | total: 1386s
#   step  6600 | loss 2.0124 | avg 1.9808 | ppl 7.25 | lr 2.98e-04 | last 200 steps: 43.2s | total: 1429s
#   step  6800 | loss 2.0136 | avg 1.9800 | ppl 7.24 | lr 2.98e-04 | last 200 steps: 43.2s | total: 1473s
#   step  7000 | loss 1.7733 | avg 1.9793 | ppl 7.24 | lr 2.98e-04 | last 200 steps: 43.2s | total: 1516s
#   step  7200 | loss 1.8658 | avg 1.9786 | ppl 7.23 | lr 2.98e-04 | last 200 steps: 43.2s | total: 1559s
#   step  7400 | loss 2.2346 | avg 1.9778 | ppl 7.23 | lr 2.98e-04 | last 200 steps: 43.2s | total: 1602s
#   step  7600 | loss 1.9976 | avg 1.9769 | ppl 7.22 | lr 2.98e-04 | last 200 steps: 43.2s | total: 1645s
#   step  7800 | loss 1.9745 | avg 1.9763 | ppl 7.22 | lr 2.98e-04 | last 200 steps: 43.2s | total: 1689s
#   step  8000 | loss 1.9411 | avg 1.9754 | ppl 7.21 | lr 2.98e-04 | last 200 steps: 43.2s | total: 1732s
#   step  8200 | loss 1.9339 | avg 1.9746 | ppl 7.20 | lr 2.98e-04 | last 200 steps: 43.2s | total: 1775s
#   step  8400 | loss 1.9555 | avg 1.9739 | ppl 7.20 | lr 2.98e-04 | last 200 steps: 43.2s | total: 1818s
#   step  8600 | loss 1.8964 | avg 1.9731 | ppl 7.19 | lr 2.98e-04 | last 200 steps: 43.2s | total: 1862s
#   step  8800 | loss 2.0657 | avg 1.9726 | ppl 7.19 | lr 2.98e-04 | last 200 steps: 43.2s | total: 1905s
#   step  9000 | loss 1.9555 | avg 1.9719 | ppl 7.18 | lr 2.98e-04 | last 200 steps: 43.2s | total: 1948s
#   step  9200 | loss 1.8886 | avg 1.9711 | ppl 7.18 | lr 2.98e-04 | last 200 steps: 43.2s | total: 1991s
#   step  9400 | loss 1.9891 | avg 1.9703 | ppl 7.17 | lr 2.98e-04 | last 200 steps: 43.3s | total: 2035s
#   step  9600 | loss 1.8573 | avg 1.9696 | ppl 7.17 | lr 2.98e-04 | last 200 steps: 43.3s | total: 2078s
#   step  9800 | loss 1.8671 | avg 1.9689 | ppl 7.16 | lr 2.98e-04 | last 200 steps: 43.2s | total: 2121s
#   step 10000 | loss 1.9055 | avg 1.9681 | ppl 7.16 | lr 2.98e-04 | last 200 steps: 43.2s | total: 2164s
#   step 10200 | loss 2.0492 | avg 1.9674 | ppl 7.15 | lr 2.98e-04 | last 200 steps: 43.2s | total: 2208s
#   step 10400 | loss 1.8456 | avg 1.9667 | ppl 7.15 | lr 2.98e-04 | last 200 steps: 43.2s | total: 2251s
#   step 10600 | loss 2.0309 | avg 1.9660 | ppl 7.14 | lr 2.98e-04 | last 200 steps: 43.3s | total: 2294s
#   step 10800 | loss 1.8817 | avg 1.9651 | ppl 7.14 | lr 2.98e-04 | last 200 steps: 43.2s | total: 2337s
#   step 11000 | loss 1.9516 | avg 1.9644 | ppl 7.13 | lr 2.98e-04 | last 200 steps: 43.3s | total: 2381s
#   step 11200 | loss 2.0979 | avg 1.9636 | ppl 7.12 | lr 2.98e-04 | last 200 steps: 43.3s | total: 2424s
#   step 11400 | loss 2.0259 | avg 1.9630 | ppl 7.12 | lr 2.98e-04 | last 200 steps: 43.3s | total: 2467s
#   step 11600 | loss 2.1221 | avg 1.9623 | ppl 7.12 | lr 2.98e-04 | last 200 steps: 43.3s | total: 2510s
#   step 11800 | loss 1.8101 | avg 1.9617 | ppl 7.11 | lr 2.98e-04 | last 200 steps: 43.3s | total: 2554s
#   step 12000 | loss 1.8241 | avg 1.9609 | ppl 7.11 | lr 2.98e-04 | last 200 steps: 43.3s | total: 2597s
#   step 12200 | loss 1.9337 | avg 1.9602 | ppl 7.10 | lr 2.98e-04 | last 200 steps: 43.3s | total: 2640s
#   step 12400 | loss 2.0885 | avg 1.9597 | ppl 7.10 | lr 2.98e-04 | last 200 steps: 43.3s | total: 2684s
#   step 12600 | loss 1.8567 | avg 1.9590 | ppl 7.09 | lr 2.98e-04 | last 200 steps: 43.3s | total: 2727s
#   step 12800 | loss 2.0487 | avg 1.9583 | ppl 7.09 | lr 2.98e-04 | last 200 steps: 43.3s | total: 2770s
#   step 13000 | loss 1.9866 | avg 1.9577 | ppl 7.08 | lr 2.98e-04 | last 200 steps: 43.3s | total: 2813s
#   step 13200 | loss 1.8815 | avg 1.9572 | ppl 7.08 | lr 2.97e-04 | last 200 steps: 43.3s | total: 2857s
#   step 13400 | loss 1.9728 | avg 1.9566 | ppl 7.08 | lr 2.97e-04 | last 200 steps: 43.3s | total: 2900s
#   step 13600 | loss 1.8135 | avg 1.9559 | ppl 7.07 | lr 2.97e-04 | last 200 steps: 43.2s | total: 2943s
#   step 13800 | loss 1.8227 | avg 1.9552 | ppl 7.07 | lr 2.97e-04 | last 200 steps: 43.3s | total: 2986s
#   step 14000 | loss 1.8860 | avg 1.9546 | ppl 7.06 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3030s
#   step 14200 | loss 1.8592 | avg 1.9540 | ppl 7.06 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3073s
#   step 14400 | loss 1.8830 | avg 1.9535 | ppl 7.05 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3116s
#   step 14600 | loss 2.0050 | avg 1.9529 | ppl 7.05 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3159s
#   step 14800 | loss 1.8453 | avg 1.9522 | ppl 7.04 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3203s
#   step 15000 | loss 2.0474 | avg 1.9516 | ppl 7.04 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3246s
#   step 15200 | loss 1.9726 | avg 1.9510 | ppl 7.04 | lr 2.97e-04 | last 200 steps: 43.2s | total: 3289s
#   step 15400 | loss 1.9747 | avg 1.9506 | ppl 7.03 | lr 2.97e-04 | last 200 steps: 43.2s | total: 3333s
#   step 15600 | loss 1.9178 | avg 1.9500 | ppl 7.03 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3376s
#   step 15800 | loss 1.7199 | avg 1.9495 | ppl 7.02 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3419s
#   step 16000 | loss 2.0603 | avg 1.9490 | ppl 7.02 | lr 2.97e-04 | last 200 steps: 43.2s | total: 3462s
#   step 16200 | loss 1.9435 | avg 1.9484 | ppl 7.02 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3506s
#   step 16400 | loss 1.9681 | avg 1.9477 | ppl 7.01 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3549s
#   step 16600 | loss 1.9318 | avg 1.9472 | ppl 7.01 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3592s
#   step 16800 | loss 1.8777 | avg 1.9465 | ppl 7.00 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3635s
#   step 17000 | loss 1.8546 | avg 1.9460 | ppl 7.00 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3679s
#   step 17200 | loss 1.8618 | avg 1.9453 | ppl 7.00 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3722s
#   step 17400 | loss 1.9414 | avg 1.9448 | ppl 6.99 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3765s
#   step 17600 | loss 1.9599 | avg 1.9443 | ppl 6.99 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3809s
#   step 17800 | loss 2.0388 | avg 1.9438 | ppl 6.99 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3852s
#   step 18000 | loss 1.9552 | avg 1.9433 | ppl 6.98 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3895s
#   step 18200 | loss 1.8682 | avg 1.9428 | ppl 6.98 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3938s
#   step 18400 | loss 1.8558 | avg 1.9423 | ppl 6.97 | lr 2.97e-04 | last 200 steps: 43.3s | total: 3982s
#   step 18600 | loss 1.9039 | avg 1.9418 | ppl 6.97 | lr 2.97e-04 | last 200 steps: 43.3s | total: 4025s
#   Shard done — avg loss: 1.9415 | ppl 6.97
#
# Epoch 2 complete — avg loss: 1.9415 | ppl 6.97
# Epoch checkpoint saved → checkpoints_v3/epoch_2.pt
#
# ============================================================
# Epoch 3/3
# ============================================================
#
# [Epoch 3] Shard 1/1 — shard_0000.pt
#   step     0 | loss 1.9161 | avg 1.9161 | ppl 6.79 | lr 2.97e-04 | last 200 steps: 2.4s | total: 2s
#   step   200 | loss 1.8761 | avg 1.8790 | ppl 6.55 | lr 2.97e-04 | last 200 steps: 43.4s | total: 46s
#   step   400 | loss 1.9104 | avg 1.8790 | ppl 6.55 | lr 2.96e-04 | last 200 steps: 43.4s | total: 89s
#   step   600 | loss 1.8467 | avg 1.8801 | ppl 6.55 | lr 2.96e-04 | last 200 steps: 43.4s | total: 133s
#   step   800 | loss 1.7736 | avg 1.8814 | ppl 6.56 | lr 2.96e-04 | last 200 steps: 43.3s | total: 176s
#   step  1000 | loss 1.8134 | avg 1.8813 | ppl 6.56 | lr 2.96e-04 | last 200 steps: 43.3s | total: 219s
#   step  1200 | loss 1.8852 | avg 1.8796 | ppl 6.55 | lr 2.96e-04 | last 200 steps: 43.3s | total: 263s
#   step  1400 | loss 1.9343 | avg 1.8793 | ppl 6.55 | lr 2.96e-04 | last 200 steps: 43.3s | total: 306s
#   step  1600 | loss 1.9301 | avg 1.8783 | ppl 6.54 | lr 2.96e-04 | last 200 steps: 43.3s | total: 349s
#   step  1800 | loss 1.8487 | avg 1.8781 | ppl 6.54 | lr 2.96e-04 | last 200 steps: 43.3s | total: 392s
#   step  2000 | loss 1.8982 | avg 1.8767 | ppl 6.53 | lr 2.96e-04 | last 200 steps: 43.3s | total: 436s
#   step  2200 | loss 1.6915 | avg 1.8765 | ppl 6.53 | lr 2.96e-04 | last 200 steps: 43.3s | total: 479s
#   step  2400 | loss 1.8912 | avg 1.8763 | ppl 6.53 | lr 2.96e-04 | last 200 steps: 43.3s | total: 522s
#   step  2600 | loss 2.0496 | avg 1.8764 | ppl 6.53 | lr 2.96e-04 | last 200 steps: 43.3s | total: 566s
#   step  2800 | loss 1.8375 | avg 1.8764 | ppl 6.53 | lr 2.96e-04 | last 200 steps: 43.3s | total: 609s
#   step  3000 | loss 1.8840 | avg 1.8763 | ppl 6.53 | lr 2.96e-04 | last 200 steps: 43.3s | total: 652s
#   step  3200 | loss 1.7713 | avg 1.8761 | ppl 6.53 | lr 2.96e-04 | last 200 steps: 43.3s | total: 696s
#   step  3400 | loss 1.8082 | avg 1.8765 | ppl 6.53 | lr 2.96e-04 | last 200 steps: 43.3s | total: 739s
#   step  3600 | loss 1.8857 | avg 1.8767 | ppl 6.53 | lr 2.96e-04 | last 200 steps: 43.3s | total: 782s
#   step  3800 | loss 1.9226 | avg 1.8761 | ppl 6.53 | lr 2.96e-04 | last 200 steps: 43.4s | total: 826s
#   step  4000 | loss 1.7743 | avg 1.8756 | ppl 6.52 | lr 2.96e-04 | last 200 steps: 43.3s | total: 869s
#   step  4200 | loss 1.9117 | avg 1.8756 | ppl 6.52 | lr 2.96e-04 | last 200 steps: 43.3s | total: 912s
#   step  4400 | loss 1.7167 | avg 1.8752 | ppl 6.52 | lr 2.96e-04 | last 200 steps: 43.4s | total: 956s
#   step  4600 | loss 1.9657 | avg 1.8748 | ppl 6.52 | lr 2.96e-04 | last 200 steps: 43.4s | total: 999s
#   step  4800 | loss 1.8603 | avg 1.8750 | ppl 6.52 | lr 2.96e-04 | last 200 steps: 43.3s | total: 1042s
#   step  5000 | loss 1.7409 | avg 1.8745 | ppl 6.52 | lr 2.96e-04 | last 200 steps: 43.3s | total: 1086s
#   step  5200 | loss 1.8025 | avg 1.8744 | ppl 6.52 | lr 2.96e-04 | last 200 steps: 43.4s | total: 1129s
#   step  5400 | loss 1.7688 | avg 1.8747 | ppl 6.52 | lr 2.96e-04 | last 200 steps: 43.4s | total: 1173s
#   step  5600 | loss 1.7938 | avg 1.8743 | ppl 6.52 | lr 2.95e-04 | last 200 steps: 43.4s | total: 1216s
#   step  5800 | loss 1.8533 | avg 1.8742 | ppl 6.52 | lr 2.95e-04 | last 200 steps: 43.4s | total: 1259s
#   step  6000 | loss 1.8918 | avg 1.8742 | ppl 6.52 | lr 2.95e-04 | last 200 steps: 43.4s | total: 1303s
#   step  6200 | loss 1.8589 | avg 1.8742 | ppl 6.52 | lr 2.95e-04 | last 200 steps: 43.4s | total: 1346s
#   step  6400 | loss 1.8568 | avg 1.8739 | ppl 6.51 | lr 2.95e-04 | last 200 steps: 43.3s | total: 1389s
#   step  6600 | loss 1.7849 | avg 1.8735 | ppl 6.51 | lr 2.95e-04 | last 200 steps: 43.3s | total: 1433s
#   step  6800 | loss 1.8588 | avg 1.8734 | ppl 6.51 | lr 2.95e-04 | last 200 steps: 43.4s | total: 1476s
#   step  7000 | loss 1.8701 | avg 1.8733 | ppl 6.51 | lr 2.95e-04 | last 200 steps: 43.3s | total: 1519s
#   step  7200 | loss 1.9275 | avg 1.8732 | ppl 6.51 | lr 2.95e-04 | last 200 steps: 43.3s | total: 1563s
#   step  7400 | loss 2.0779 | avg 1.8730 | ppl 6.51 | lr 2.95e-04 | last 200 steps: 43.3s | total: 1606s
#   step  7600 | loss 2.0415 | avg 1.8727 | ppl 6.51 | lr 2.95e-04 | last 200 steps: 43.4s | total: 1649s
#   step  7800 | loss 1.8962 | avg 1.8724 | ppl 6.50 | lr 2.95e-04 | last 200 steps: 43.3s | total: 1693s
#   step  8000 | loss 1.8435 | avg 1.8722 | ppl 6.50 | lr 2.95e-04 | last 200 steps: 43.3s | total: 1736s
#   step  8200 | loss 1.9423 | avg 1.8720 | ppl 6.50 | lr 2.95e-04 | last 200 steps: 43.4s | total: 1780s
#   step  8400 | loss 1.7772 | avg 1.8716 | ppl 6.50 | lr 2.95e-04 | last 200 steps: 43.3s | total: 1823s
#   step  8600 | loss 1.8091 | avg 1.8712 | ppl 6.50 | lr 2.95e-04 | last 200 steps: 43.4s | total: 1866s
#   step  8800 | loss 1.9417 | avg 1.8711 | ppl 6.50 | lr 2.95e-04 | last 200 steps: 43.3s | total: 1910s
#   step  9000 | loss 1.8706 | avg 1.8708 | ppl 6.49 | lr 2.95e-04 | last 200 steps: 43.3s | total: 1953s
#   step  9200 | loss 1.8595 | avg 1.8706 | ppl 6.49 | lr 2.95e-04 | last 200 steps: 43.4s | total: 1996s
#   step  9400 | loss 1.9084 | avg 1.8702 | ppl 6.49 | lr 2.95e-04 | last 200 steps: 43.4s | total: 2040s
#   step  9600 | loss 1.9469 | avg 1.8701 | ppl 6.49 | lr 2.95e-04 | last 200 steps: 43.4s | total: 2083s
#   step  9800 | loss 1.8652 | avg 1.8697 | ppl 6.49 | lr 2.95e-04 | last 200 steps: 43.4s | total: 2126s
#   step 10000 | loss 1.7344 | avg 1.8693 | ppl 6.48 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2170s
#   step 10200 | loss 1.8341 | avg 1.8691 | ppl 6.48 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2213s
#   step 10400 | loss 1.5877 | avg 1.8689 | ppl 6.48 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2256s
#   step 10600 | loss 1.7950 | avg 1.8686 | ppl 6.48 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2300s
#   step 10800 | loss 1.8872 | avg 1.8682 | ppl 6.48 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2343s
#   step 11000 | loss 1.8086 | avg 1.8678 | ppl 6.47 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2387s
#   step 11200 | loss 1.8402 | avg 1.8677 | ppl 6.47 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2430s
#   step 11400 | loss 1.7971 | avg 1.8673 | ppl 6.47 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2473s
#   step 11600 | loss 1.8477 | avg 1.8670 | ppl 6.47 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2517s
#   step 11800 | loss 1.9207 | avg 1.8667 | ppl 6.47 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2560s
#   step 12000 | loss 1.8941 | avg 1.8664 | ppl 6.46 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2604s
#   step 12200 | loss 1.8095 | avg 1.8662 | ppl 6.46 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2647s
#   step 12400 | loss 1.7032 | avg 1.8659 | ppl 6.46 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2690s
#   step 12600 | loss 1.9570 | avg 1.8655 | ppl 6.46 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2734s
#   step 12800 | loss 1.8565 | avg 1.8651 | ppl 6.46 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2777s
#   step 13000 | loss 1.7700 | avg 1.8648 | ppl 6.45 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2821s
#   step 13200 | loss 1.9209 | avg 1.8645 | ppl 6.45 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2864s
#   step 13400 | loss 1.7378 | avg 1.8643 | ppl 6.45 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2907s
#   step 13600 | loss 1.8370 | avg 1.8639 | ppl 6.45 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2951s
#   step 13800 | loss 1.8243 | avg 1.8636 | ppl 6.45 | lr 2.94e-04 | last 200 steps: 43.4s | total: 2994s
#   step 14000 | loss 1.7919 | avg 1.8633 | ppl 6.45 | lr 2.94e-04 | last 200 steps: 43.4s | total: 3038s
#   step 14200 | loss 1.7861 | avg 1.8629 | ppl 6.44 | lr 2.93e-04 | last 200 steps: 43.4s | total: 3081s
#   step 14400 | loss 1.9150 | avg 1.8626 | ppl 6.44 | lr 2.93e-04 | last 200 steps: 43.5s | total: 3124s
#   step 14600 | loss 1.9370 | avg 1.8624 | ppl 6.44 | lr 2.93e-04 | last 200 steps: 43.4s | total: 3168s
#   step 14800 | loss 1.8404 | avg 1.8622 | ppl 6.44 | lr 2.93e-04 | last 200 steps: 43.4s | total: 3211s
#   step 15000 | loss 2.0039 | avg 1.8618 | ppl 6.44 | lr 2.93e-04 | last 200 steps: 43.4s | total: 3255s
#   step 15200 | loss 1.8973 | avg 1.8616 | ppl 6.43 | lr 2.93e-04 | last 200 steps: 43.4s | total: 3298s
#   step 15400 | loss 1.8438 | avg 1.8614 | ppl 6.43 | lr 2.93e-04 | last 200 steps: 43.4s | total: 3342s
#   step 15600 | loss 1.9571 | avg 1.8612 | ppl 6.43 | lr 2.93e-04 | last 200 steps: 43.4s | total: 3385s
#   step 15800 | loss 1.9501 | avg 1.8611 | ppl 6.43 | lr 2.93e-04 | last 200 steps: 43.4s | total: 3428s
#   step 16000 | loss 1.8667 | avg 1.8608 | ppl 6.43 | lr 2.93e-04 | last 200 steps: 43.4s | total: 3472s
#   step 16200 | loss 1.8182 | avg 1.8606 | ppl 6.43 | lr 2.93e-04 | last 200 steps: 43.4s | total: 3515s
#   step 16400 | loss 1.8722 | avg 1.8604 | ppl 6.43 | lr 2.93e-04 | last 200 steps: 43.4s | total: 3558s
#   step 16600 | loss 1.8159 | avg 1.8600 | ppl 6.42 | lr 2.93e-04 | last 200 steps: 43.4s | total: 3602s
#   step 16800 | loss 1.7599 | avg 1.8598 | ppl 6.42 | lr 2.93e-04 | last 200 steps: 43.4s | total: 3645s
#   step 17000 | loss 1.7198 | avg 1.8596 | ppl 6.42 | lr 2.93e-04 | last 200 steps: 43.4s | total: 3689s
#   step 17200 | loss 1.8781 | avg 1.8593 | ppl 6.42 | lr 2.93e-04 | last 200 steps: 43.4s | total: 3732s
#   step 17400 | loss 1.8513 | avg 1.8590 | ppl 6.42 | lr 2.93e-04 | last 200 steps: 43.4s | total: 3775s
#   step 17600 | loss 1.8779 | avg 1.8588 | ppl 6.42 | lr 2.93e-04 | last 200 steps: 43.4s | total: 3819s
#   step 17800 | loss 1.8908 | avg 1.8585 | ppl 6.41 | lr 2.93e-04 | last 200 steps: 43.4s | total: 3862s
#   step 18000 | loss 1.7978 | avg 1.8583 | ppl 6.41 | lr 2.92e-04 | last 200 steps: 43.4s | total: 3906s
#   step 18200 | loss 1.8386 | avg 1.8581 | ppl 6.41 | lr 2.92e-04 | last 200 steps: 43.4s | total: 3949s
#   step 18400 | loss 1.8374 | avg 1.8578 | ppl 6.41 | lr 2.92e-04 | last 200 steps: 43.4s | total: 3992s
#   step 18600 | loss 1.8326 | avg 1.8575 | ppl 6.41 | lr 2.92e-04 | last 200 steps: 43.4s | total: 4036s
#   Shard done — avg loss: 1.8573 | ppl 6.41
#
# Epoch 3 complete — avg loss: 1.8573 | ppl 6.41
# Epoch checkpoint saved → checkpoints_v3/epoch_3.pt
#
# Training complete.

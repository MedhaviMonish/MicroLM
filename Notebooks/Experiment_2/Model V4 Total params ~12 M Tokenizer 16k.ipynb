# %%
import torch
import torch.nn as nn
import numpy as np
import math
import time

# Load frozen embedding table
embedding_table = np.load("tokenizer_v3/token_embeddings.npy")
embedding_tensor = torch.tensor(embedding_table, dtype=torch.float32)

VOCAB_SIZE    = embedding_tensor.shape[0]   # 4096
MINILM_DIM    = embedding_tensor.shape[1]   # 384
print(f"Vocab size : {VOCAB_SIZE}")
print(f"MiniLM dim : {MINILM_DIM}")
# Out:
# Vocab size : 16384
# MiniLM dim : 384

# %%
import torch.nn.functional as F 

DIM      = 384
N_HEADS  = 4
N_LAYERS = 4
FFN_DIM  = 768
HEAD_DIM = DIM // N_HEADS 

def sinusoidal_encoding(seq_len, dim, device):
    pe       = torch.zeros(seq_len, dim, device=device)
    position = torch.arange(seq_len, device=device).unsqueeze(1)
    div_term = torch.exp(torch.arange(0, dim, 2, device=device) * (-math.log(10000.0) / dim))
    pe[:, 0::2] = torch.sin(position * div_term)
    pe[:, 1::2] = torch.cos(position * div_term)
    return pe  # (seq_len, dim)

class LayerNorm(nn.Module):
    """
    y = ((x - mean) / sqrt(var + eps)) * gamma + beta
    gamma, beta are learned per-feature scalars — shape (dim,)
    """
    def __init__(self, dim, eps=1e-5):
        super().__init__()
        self.eps   = eps
        self.gamma = nn.Parameter(torch.ones(dim))   # scale
        self.beta  = nn.Parameter(torch.zeros(dim))  # shift

    def forward(self, x):
        mean = x.mean(dim=-1, keepdim=True)           # (B, T, 1)
        var  = x.var(dim=-1, keepdim=True, unbiased=False)  # (B, T, 1)
        x_norm = (x - mean) / torch.sqrt(var + self.eps)    # (B, T, D)
        return self.gamma * x_norm + self.beta               # (B, T, D)

class MultiHeadCausalAttention(nn.Module):
    """
    Projects input into Q, K, V — splits into H heads — computes scaled
    dot-product attention with a causal mask — concatenates heads — projects out.

    Q = x W_q      shape: (B, T, D)
    K = x W_k      shape: (B, T, D)
    V = x W_v      shape: (B, T, D)

    Reshape to (B, H, T, head_dim), then:
        scores = Q @ Kᵀ / sqrt(head_dim)    (B, H, T, T)
        scores = scores + causal_mask        (upper triangle = -inf)
        weights = softmax(scores, dim=-1)    (B, H, T, T)
        out = weights @ V                    (B, H, T, head_dim)

    Concat heads → (B, T, D), project out via W_o
    """
    def __init__(self, dim, n_heads, dropout=0.1):
        super().__init__()
        assert dim % n_heads == 0, "dim must be divisible by n_heads"
        self.n_heads  = n_heads
        self.head_dim = dim // n_heads       # 48
        self.scale    = self.head_dim ** -0.5

        self.W_q = nn.Linear(dim, dim, bias=False)
        self.W_k = nn.Linear(dim, dim, bias=False)
        self.W_v = nn.Linear(dim, dim, bias=False)
        self.W_o = nn.Linear(dim, dim, bias=False)

        self.attn_drop = nn.Dropout(dropout)

    def forward(self, x):
        B, T, D = x.shape

        # --- Project & split into heads ---
        Q = self.W_q(x)  # (B, T, D)
        K = self.W_k(x)  # (B, T, D)
        V = self.W_v(x)  # (B, T, D)

        # Reshape: (B, T, D) → (B, H, T, head_dim)
        Q = Q.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)
        K = K.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)
        V = V.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)

        # --- Scaled dot-product attention ---
        # (B, H, T, head_dim) @ (B, H, head_dim, T) → (B, H, T, T)
        scores = (Q @ K.transpose(-2, -1)) * self.scale

        # Causal mask: positions can only attend to themselves and earlier tokens
        # Upper triangle (future tokens) set to -inf → softmax drives them to 0
        causal_mask = torch.triu(
            torch.ones(T, T, device=x.device, dtype=torch.bool), diagonal=1
        )
        scores = scores.masked_fill(causal_mask, float('-inf'))

        weights = torch.softmax(scores, dim=-1)  # (B, H, T, T)
        weights = self.attn_drop(weights)

        # (B, H, T, T) @ (B, H, T, head_dim) → (B, H, T, head_dim)
        out = weights @ V

        # --- Concat heads & project ---
        # (B, H, T, head_dim) → (B, T, H*head_dim) = (B, T, D)
        out = out.transpose(1, 2).contiguous().view(B, T, D)
        return self.W_o(out)  # (B, T, D)

class FeedForward(nn.Module):
    """
    Two-layer MLP with GELU activation.
    FFN(x) = GELU(x W_1 + b_1) W_2 + b_2

    Expands dim → ffn_dim (wider representation),
    then projects back down ffn_dim → dim.
    """
    def __init__(self, dim, ffn_dim, dropout=0.1):
        super().__init__()
        self.W_1 = nn.Linear(dim, ffn_dim)       # expand
        self.W_2 = nn.Linear(ffn_dim, dim)       # contract
        self.drop = nn.Dropout(dropout)

    def forward(self, x):
        x = F.gelu(self.W_1(x))   # (B, T, ffn_dim)
        x = self.drop(x)
        x = self.W_2(x)           # (B, T, dim)
        return x

class TransformerBlock(nn.Module):
    """
    Pre-norm residual block (norm_first=True, same as your original config).

    x = x + Attention(LayerNorm(x))   ← self-attention sub-layer
    x = x + FFN(LayerNorm(x))         ← feed-forward sub-layer

    Pre-norm (LN before the sub-layer) stabilises training at depth
    vs post-norm (LN after the residual add).
    """
    def __init__(self, dim, n_heads, ffn_dim, dropout=0.1):
        super().__init__()
        self.norm_1 = LayerNorm(dim)
        self.attn   = MultiHeadCausalAttention(dim, n_heads, dropout)
        self.norm_2 = LayerNorm(dim)
        self.ffn    = FeedForward(dim, ffn_dim, dropout)
        self.drop   = nn.Dropout(dropout)

    def forward(self, x):
        x = x + self.drop(self.attn(self.norm_1(x)))  # (B, T, D)
        x = x + self.drop(self.ffn(self.norm_2(x)))   # (B, T, D)
        return x

class MicroLM(nn.Module):
    """
    Full architecture:
      1. Frozen MiniLM embedding lookup         → (B, T, 384)
      2. Sinusoidal positional encoding added   → (B, T, 384)
      3. N_LAYERS x TransformerBlock            → (B, T, 384)
      4. Final LayerNorm                        → (B, T, 384)
      5. Linear output head → logits            → (B, T, VOCAB_SIZE)
    """
    def __init__(self):
        super().__init__()
        self.register_buffer("embedding_table", embedding_tensor)

        self.blocks = nn.ModuleList([
            TransformerBlock(DIM, N_HEADS, FFN_DIM, dropout=0.1)
            for _ in range(N_LAYERS)
        ])

        self.norm        = LayerNorm(DIM)
        self.output_head = nn.Linear(DIM, VOCAB_SIZE, bias=False)

    def forward(self, token_ids):
        B, T = token_ids.shape

        x = self.embedding_table[token_ids]                    # (B, T, 384)
        x = x + sinusoidal_encoding(T, DIM, token_ids.device) # (B, T, 384)

        for block in self.blocks:
            x = block(x)   # (B, T, 384)

        x = self.norm(x)
        return self.output_head(x)  # (B, T, VOCAB_SIZE)

# %%
model     = MicroLM()
total     = sum(p.numel() for p in model.parameters())
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
frozen    = total - trainable

print(f"Trainable params : {trainable:,}")
print(f"Frozen params    : {frozen:,}  (embedding table)")
print(f"Total params     : {total:,}")

# print(f"\nParam breakdown:")
# for name, p in model.named_parameters():
#     if p.requires_grad:
#         print(f"  {name:55s} {p.numel():>10,}")

# Forward pass
x      = torch.randint(0, VOCAB_SIZE, (2, 32))
logits = model(x)
print(f"\nInput  : {x.shape}")
print(f"Output : {logits.shape}")
# Out:
# Trainable params : 11,021,568
# Frozen params    : 0  (embedding table)
# Total params     : 11,021,568
#
# Input  : torch.Size([2, 32])
# Output : torch.Size([2, 32, 16384])

# %%
# ── Training Config ───────────────────────────────────────────────────────────
import gc
import json
import random
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from pathlib import Path

SHARD_DIR  = Path("dataset_shards_v2")
SEQ_LEN    = 512
BATCH_SIZE = 32
N_EPOCHS   = 3
LOG_EVERY  = 200
CKPT_DIR   = Path("checkpoints_v4")
CKPT_DIR.mkdir(parents=True, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device      : {device}")
print(f"Model params: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# Device      : cuda
# Model params: 11,021,568

# %%
from torch.utils.data import Dataset

SEQ_LEN = 512    # window size
STRIDE  = 448    # step size → 64-token overlap

class ShardDataset(Dataset):
    def __init__(self, shard_path, seq_len=SEQ_LEN, stride=STRIDE):
        flat = torch.load(shard_path, weights_only=True)

        self.flat    = flat.to(torch.int16)
        self.seq_len = seq_len
        self.stride  = stride

        # number of full windows we can extract
        # +1 because we need seq_len+1 tokens (x + y target)
        n_tokens = len(self.flat)
        self.num_samples = max(0, (n_tokens - seq_len - 1) // stride + 1)

    def __len__(self):
        return self.num_samples

    def __getitem__(self, idx):
        start  = idx * self.stride
        tokens = self.flat[start : start + self.seq_len + 1].to(torch.long)  # ← cast here
        
        if len(tokens) < self.seq_len + 1:
            pad    = torch.full((self.seq_len + 1 - len(tokens),), PAD_ID, dtype=torch.long)
            tokens = torch.cat([tokens, pad])

        x = tokens[:-1]
        y = tokens[1:]
        return x, y


BOS_ID       = 2
EOS_ID       = 3

def collate_fn(batch):
    xs, ys = zip(*batch)
    # all samples are now fixed-length (seq_len), so no padding needed here
    x_pad = torch.stack(xs)          # [B, seq_len]
    y_pad = torch.stack(ys).clone()  # [B, seq_len]

    # mask out targets after the first EOS in each sequence
    for i, y in enumerate(y_pad):
        eos_positions = (y == EOS_ID).nonzero(as_tuple=True)[0]
        if len(eos_positions) > 0:
            eos_pos = eos_positions[0].item()
            if eos_pos + 1 < y.size(0):
                y_pad[i, eos_pos + 1:] = -100

    return x_pad, y_pad

# %% [markdown]
# from tokenizers import Tokenizer
# TOKENIZER_PATH   = "tokenizer/tokenizer.json"
# tokenizer = Tokenizer.from_file(TOKENIZER_PATH)
# dataset = ShardDataset("dataset_shards/shard_0000.pt")
# for i in range(10,11):
#     x, y = dataset[i]
#     print(f"\nSample {i}")
#     print(f"  x: {x.tolist()}")
#     print(f"  y: {tokenizer.decode(x.tolist(), skip_special_tokens=False)}")
#     # print(f"  y: {y.tolist()}")
# for idx  in x.tolist():
#     tok = tokenizer.decode([idx], skip_special_tokens=False)
#     print(f"{idx} === '{tok}' ")

# %%
# run once after sharding
# meta = {
#     "total_samples": sum(len(ShardDataset(p)) for p in sorted(SHARD_DIR.glob("shard_*.pt"))),
#     "seq_len": SEQ_LEN,
#     "stride": STRIDE,
# }
# with open(SHARD_DIR / "meta.json", "w") as f:
#     json.dump(meta, f, indent=2)
    
# ── Optimizer & Scheduler ─────────────────────────────────────────────────────

with open(SHARD_DIR / "meta.json") as f:
    meta = json.load(f)

total_steps = (meta['total_samples'] // BATCH_SIZE) * N_EPOCHS

optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4, weight_decay=0.1)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=total_steps, eta_min=1e-5
)
scaler    = torch.cuda.amp.GradScaler()

print(f"Total samples: {meta['total_samples']:,}")
print(f"Total steps  : {total_steps:,}")
# Out:
# Total samples: 3,601,677
# Total steps  : 337,656
# /tmp/ipykernel_41107/3492270537.py:21: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler    = torch.cuda.amp.GradScaler()

# %%
model.to(device)
# Out:
# MicroLM(
#   (blocks): ModuleList(
#     (0-3): 4 x TransformerBlock(
#       (norm_1): LayerNorm()
#       (attn): MultiHeadCausalAttention(
#         (W_q): Linear(in_features=384, out_features=384, bias=False)
#         (W_k): Linear(in_features=384, out_features=384, bias=False)
#         (W_v): Linear(in_features=384, out_features=384, bias=False)
#         (W_o): Linear(in_features=384, out_features=384, bias=False)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#       )
#       (norm_2): LayerNorm()
#       (ffn): FeedForward(
#         (W_1): Linear(in_features=384, out_features=768, bias=True)
#         (W_2): Linear(in_features=768, out_features=384, bias=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#       (drop): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (norm): LayerNorm()
#   (output_head): Linear(in_features=384, out_features=16384, bias=False)
# )

# %%
shard_files  = sorted(SHARD_DIR.glob("shard_*.pt"))[:1]
shard_files
# Out:
# [PosixPath('dataset_shards_v2/shard_0000.pt')]

# %%
# ── Training Loop with Resume ─────────────────────────────────────────────────
import math

shard_files  = sorted(SHARD_DIR.glob("shard_*.pt"))[:1]
loss_history = []
start_epoch  = 0
start_shard  = 0

# ── Resume from latest checkpoint ────────────────────────────────────────────
# Check mid-epoch checkpoints first, then epoch checkpoints
all_ckpts = sorted(CKPT_DIR.glob("epoch_*.pt"))
mid_ckpts  = [c for c in all_ckpts if "shard" in c.name]
epoch_ckpts = [c for c in all_ckpts if "shard" not in c.name]

if mid_ckpts:
    latest = mid_ckpts[-1]
    print(f"Resuming from mid-epoch checkpoint {latest}...")
    ckpt = torch.load(latest, map_location=device)
    model.load_state_dict(ckpt["model"])
    optimizer.load_state_dict(ckpt["optimizer"])
    scheduler.load_state_dict(ckpt["scheduler"])
    loss_history = ckpt.get("loss_history", [])
    start_epoch  = ckpt["epoch"] - 1        # epoch is 1-indexed, range is 0-indexed
    start_shard  = ckpt["shard"] + 1        # resume from next shard
    print(f"Resumed — epoch {start_epoch+1}, starting from shard {start_shard+1}")

elif epoch_ckpts:
    latest = epoch_ckpts[-1]
    print(f"Resuming from epoch checkpoint {latest}...")
    ckpt = torch.load(latest, map_location=device)
    model.load_state_dict(ckpt["model"])
    optimizer.load_state_dict(ckpt["optimizer"])
    scheduler.load_state_dict(ckpt["scheduler"])
    loss_history = ckpt.get("loss_history", [])
    start_epoch  = ckpt["epoch"]            # full epoch completed
    start_shard  = 0                        # start from beginning of next epoch
    print(f"Resumed — starting from epoch {start_epoch+1}")

else:
    print("No checkpoint found — training from scratch")

model.to(device)
model.train()

for epoch in range(start_epoch, N_EPOCHS):
    epoch_loss  = 0.0
    epoch_steps = 0

    # no shuffle — sequential shard order
    shard_order = list(range(len(shard_files)))

    # if resuming mid-epoch, skip already completed shards
    if epoch == start_epoch and start_shard > 0:
        shard_order = shard_order[start_shard:]
        print(f"Skipping shards 0-{start_shard-1}, resuming from shard {start_shard}")

    print(f"\n{'='*60}")
    print(f"Epoch {epoch+1}/{N_EPOCHS}")
    print(f"{'='*60}")

    for shard_num, shard_idx in enumerate(shard_order):
        # just before the step loop:
        shard_start = time.time()
        interval_start = time.time()
        
        # actual shard number in epoch (accounts for skipped shards on resume)
        actual_shard_num = shard_idx  

        shard_path = shard_files[shard_idx]
        print(f"\n[Epoch {epoch+1}] Shard {actual_shard_num+1}/{len(shard_files)} — {shard_path.name}")

        ds     = ShardDataset(shard_path)
        loader = DataLoader(
            ds,
            batch_size=BATCH_SIZE,
            shuffle=True,
            collate_fn=collate_fn,
            num_workers=0,
            pin_memory=True,
        )

        shard_loss  = 0.0
        shard_steps = 0

        for step, (x, y) in enumerate(loader):
            x = x.to(device)
            y = y.to(device)

            optimizer.zero_grad()

            with torch.autocast(device_type="cuda", dtype=torch.bfloat16):
                logits = model(x)
                loss   = F.cross_entropy(
                    logits.view(-1, logits.size(-1)),
                    y.view(-1),
                    ignore_index=-100,
                )
                del logits  # free 268MB immediately before backward


            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()

            if not math.isnan(loss.item()):
                shard_loss  += loss.item()
                shard_steps += 1
                epoch_loss  += loss.item()
                epoch_steps += 1

            if step % LOG_EVERY == 0:
                avg = shard_loss / max(shard_steps, 1)
                ppl = math.exp(min(avg, 20))
                lr  = scheduler.get_last_lr()[0]
                elapsed_total = time.time() - shard_start
                interval_time = time.time() - interval_start
                print(f"  step {step:>5} | loss {loss.item():.4f} | avg {avg:.4f} | ppl {ppl:.2f} | lr {lr:.2e} | last {LOG_EVERY} steps: {interval_time:.1f}s | total: {elapsed_total:.0f}s")
                interval_start = time.time()  # reset for next interval

            del loss, x, y
        shard_avg = shard_loss / max(shard_steps, 1)
        shard_ppl = math.exp(min(shard_avg, 20))
        loss_history.append({
            "epoch":      epoch + 1,
            "shard":      actual_shard_num,
            "avg_loss":   shard_avg,
            "perplexity": shard_ppl,
        })
        print(f"  Shard done — avg loss: {shard_avg:.4f} | ppl {shard_ppl:.2f}")

        del ds, loader
        gc.collect()
        torch.cuda.empty_cache()

        # mid-epoch checkpoint every 5 shards
        if (actual_shard_num + 1) % 2 == 0:
            ckpt_path = CKPT_DIR / f"epoch_{epoch+1}_shard_{actual_shard_num}.pt"
            torch.save({
                "epoch":        epoch + 1,
                "shard":        actual_shard_num,
                "model":        model.state_dict(),
                "optimizer":    optimizer.state_dict(),
                "scheduler":    scheduler.state_dict(),
                "loss_history": loss_history,
            }, ckpt_path)
            print(f"Mid-epoch checkpoint saved → {ckpt_path}")

    # reset start_shard after first resumed epoch
    start_shard = 0

    epoch_avg = epoch_loss / max(epoch_steps, 1)
    epoch_ppl = math.exp(min(epoch_avg, 20))
    print(f"\nEpoch {epoch+1} complete — avg loss: {epoch_avg:.4f} | ppl {epoch_ppl:.2f}")

    ckpt_path = CKPT_DIR / f"epoch_{epoch+1}.pt"
    torch.save({
        "epoch":        epoch + 1,
        "shard":        -1,
        "model":        model.state_dict(),
        "optimizer":    optimizer.state_dict(),
        "scheduler":    scheduler.state_dict(),
        "loss_history": loss_history,
    }, ckpt_path)
    print(f"Epoch checkpoint saved → {ckpt_path}")

    with open(CKPT_DIR / "loss_history.json", "w") as f:
        json.dump(loss_history, f, indent=2)

print("\nTraining complete.")
# Out:
# No checkpoint found — training from scratch
#
# ============================================================
# Epoch 1/3
# ============================================================
#
# [Epoch 1] Shard 1/1 — shard_0000.pt
#   step     0 | loss 9.9176 | avg 9.9176 | ppl 20283.30 | lr 3.00e-04 | last 200 steps: 2.9s | total: 3s
#   step   200 | loss 5.4386 | avg 6.0400 | ppl 419.88 | lr 3.00e-04 | last 200 steps: 19.5s | total: 22s
#   step   400 | loss 5.2140 | avg 5.6794 | ppl 292.78 | lr 3.00e-04 | last 200 steps: 19.7s | total: 42s
#   step   600 | loss 5.0108 | avg 5.4608 | ppl 235.28 | lr 3.00e-04 | last 200 steps: 19.9s | total: 62s
#   step   800 | loss 4.6237 | avg 5.2755 | ppl 195.50 | lr 3.00e-04 | last 200 steps: 20.1s | total: 82s
#   step  1000 | loss 4.2126 | avg 5.1059 | ppl 164.99 | lr 3.00e-04 | last 200 steps: 20.3s | total: 103s
#   step  1200 | loss 4.0106 | avg 4.9506 | ppl 141.26 | lr 3.00e-04 | last 200 steps: 20.3s | total: 123s
#   step  1400 | loss 3.8686 | avg 4.8112 | ppl 122.88 | lr 3.00e-04 | last 200 steps: 20.3s | total: 143s
#   step  1600 | loss 3.5647 | avg 4.6849 | ppl 108.30 | lr 3.00e-04 | last 200 steps: 20.3s | total: 163s
#   step  1800 | loss 3.6709 | avg 4.5719 | ppl 96.73 | lr 3.00e-04 | last 200 steps: 20.3s | total: 184s
#   step  2000 | loss 3.4018 | avg 4.4719 | ppl 87.52 | lr 3.00e-04 | last 200 steps: 20.3s | total: 204s
#   step  2200 | loss 3.3779 | avg 4.3816 | ppl 79.97 | lr 3.00e-04 | last 200 steps: 20.3s | total: 224s
#   step  2400 | loss 3.5828 | avg 4.2988 | ppl 73.61 | lr 3.00e-04 | last 200 steps: 20.3s | total: 245s
#   step  2600 | loss 3.5430 | avg 4.2245 | ppl 68.34 | lr 3.00e-04 | last 200 steps: 20.3s | total: 265s
#   step  2800 | loss 3.3200 | avg 4.1559 | ppl 63.81 | lr 3.00e-04 | last 200 steps: 20.3s | total: 285s
#   step  3000 | loss 3.1113 | avg 4.0938 | ppl 59.97 | lr 3.00e-04 | last 200 steps: 20.3s | total: 306s
#   step  3200 | loss 3.3204 | avg 4.0365 | ppl 56.63 | lr 3.00e-04 | last 200 steps: 20.3s | total: 326s
#   step  3400 | loss 3.1850 | avg 3.9835 | ppl 53.70 | lr 3.00e-04 | last 200 steps: 20.3s | total: 346s
#   step  3600 | loss 3.1102 | avg 3.9341 | ppl 51.12 | lr 3.00e-04 | last 200 steps: 20.3s | total: 367s
#   step  3800 | loss 3.0267 | avg 3.8881 | ppl 48.82 | lr 3.00e-04 | last 200 steps: 20.4s | total: 387s
#   step  4000 | loss 3.1410 | avg 3.8445 | ppl 46.73 | lr 3.00e-04 | last 200 steps: 20.4s | total: 408s
#   step  4200 | loss 2.9539 | avg 3.8034 | ppl 44.85 | lr 3.00e-04 | last 200 steps: 20.5s | total: 428s
#   step  4400 | loss 3.0283 | avg 3.7648 | ppl 43.16 | lr 3.00e-04 | last 200 steps: 20.5s | total: 449s
#   step  4600 | loss 2.8491 | avg 3.7282 | ppl 41.61 | lr 3.00e-04 | last 200 steps: 20.6s | total: 469s
#   step  4800 | loss 2.7730 | avg 3.6940 | ppl 40.20 | lr 3.00e-04 | last 200 steps: 20.6s | total: 490s
#   step  5000 | loss 2.9719 | avg 3.6617 | ppl 38.93 | lr 3.00e-04 | last 200 steps: 20.6s | total: 510s
#   step  5200 | loss 2.7960 | avg 3.6313 | ppl 37.76 | lr 3.00e-04 | last 200 steps: 20.6s | total: 531s
#   step  5400 | loss 2.7569 | avg 3.6020 | ppl 36.67 | lr 3.00e-04 | last 200 steps: 20.6s | total: 552s
#   step  5600 | loss 2.7566 | avg 3.5734 | ppl 35.64 | lr 3.00e-04 | last 200 steps: 20.5s | total: 572s
#   step  5800 | loss 2.8565 | avg 3.5465 | ppl 34.69 | lr 3.00e-04 | last 200 steps: 20.6s | total: 593s
#   step  6000 | loss 2.7186 | avg 3.5210 | ppl 33.82 | lr 3.00e-04 | last 200 steps: 20.6s | total: 613s
#   step  6200 | loss 2.7326 | avg 3.4966 | ppl 33.00 | lr 3.00e-04 | last 200 steps: 20.7s | total: 634s
#   step  6400 | loss 2.8257 | avg 3.4735 | ppl 32.25 | lr 3.00e-04 | last 200 steps: 20.6s | total: 655s
#   step  6600 | loss 2.6317 | avg 3.4506 | ppl 31.52 | lr 3.00e-04 | last 200 steps: 20.8s | total: 675s
#   step  6800 | loss 2.7413 | avg 3.4285 | ppl 30.83 | lr 3.00e-04 | last 200 steps: 20.5s | total: 696s
#   step  7000 | loss 2.7367 | avg 3.4075 | ppl 30.19 | lr 3.00e-04 | last 200 steps: 20.6s | total: 717s
#   step  7200 | loss 2.4417 | avg 3.3875 | ppl 29.59 | lr 3.00e-04 | last 200 steps: 20.8s | total: 737s
#   step  7400 | loss 2.6434 | avg 3.3685 | ppl 29.03 | lr 3.00e-04 | last 200 steps: 20.6s | total: 758s
#   step  7600 | loss 2.5131 | avg 3.3497 | ppl 28.49 | lr 3.00e-04 | last 200 steps: 20.7s | total: 779s
#   step  7800 | loss 2.6014 | avg 3.3313 | ppl 27.98 | lr 3.00e-04 | last 200 steps: 20.8s | total: 800s
#   step  8000 | loss 2.4519 | avg 3.3138 | ppl 27.49 | lr 3.00e-04 | last 200 steps: 20.9s | total: 820s
#   step  8200 | loss 2.5029 | avg 3.2971 | ppl 27.03 | lr 3.00e-04 | last 200 steps: 20.7s | total: 841s
#   step  8400 | loss 2.6531 | avg 3.2810 | ppl 26.60 | lr 3.00e-04 | last 200 steps: 20.9s | total: 862s
#   step  8600 | loss 2.5985 | avg 3.2654 | ppl 26.19 | lr 3.00e-04 | last 200 steps: 20.8s | total: 883s
#   step  8800 | loss 2.5441 | avg 3.2502 | ppl 25.80 | lr 3.00e-04 | last 200 steps: 20.9s | total: 904s
#   step  9000 | loss 2.7690 | avg 3.2357 | ppl 25.42 | lr 2.99e-04 | last 200 steps: 20.8s | total: 924s
#   step  9200 | loss 2.4665 | avg 3.2216 | ppl 25.07 | lr 2.99e-04 | last 200 steps: 20.7s | total: 945s
#   step  9400 | loss 2.5032 | avg 3.2075 | ppl 24.72 | lr 2.99e-04 | last 200 steps: 20.9s | total: 966s
#   step  9600 | loss 2.5113 | avg 3.1937 | ppl 24.38 | lr 2.99e-04 | last 200 steps: 20.8s | total: 987s
#   step  9800 | loss 2.5652 | avg 3.1807 | ppl 24.06 | lr 2.99e-04 | last 200 steps: 20.6s | total: 1007s
#   step 10000 | loss 2.7001 | avg 3.1682 | ppl 23.76 | lr 2.99e-04 | last 200 steps: 20.8s | total: 1028s
#   step 10200 | loss 2.3979 | avg 3.1558 | ppl 23.47 | lr 2.99e-04 | last 200 steps: 20.7s | total: 1049s
#   step 10400 | loss 2.6065 | avg 3.1438 | ppl 23.19 | lr 2.99e-04 | last 200 steps: 20.7s | total: 1070s
#   step 10600 | loss 2.5664 | avg 3.1322 | ppl 22.92 | lr 2.99e-04 | last 200 steps: 20.8s | total: 1090s
#   step 10800 | loss 2.4181 | avg 3.1206 | ppl 22.66 | lr 2.99e-04 | last 200 steps: 20.6s | total: 1111s
#   step 11000 | loss 2.5166 | avg 3.1093 | ppl 22.40 | lr 2.99e-04 | last 200 steps: 20.9s | total: 1132s
#   step 11200 | loss 2.3704 | avg 3.0987 | ppl 22.17 | lr 2.99e-04 | last 200 steps: 21.1s | total: 1153s
#   step 11400 | loss 2.5401 | avg 3.0881 | ppl 21.94 | lr 2.99e-04 | last 200 steps: 20.9s | total: 1174s
#   step 11600 | loss 2.4384 | avg 3.0777 | ppl 21.71 | lr 2.99e-04 | last 200 steps: 20.9s | total: 1195s
#   step 11800 | loss 2.6483 | avg 3.0677 | ppl 21.49 | lr 2.99e-04 | last 200 steps: 21.2s | total: 1216s
#   step 12000 | loss 2.4555 | avg 3.0576 | ppl 21.28 | lr 2.99e-04 | last 200 steps: 21.1s | total: 1237s
#   step 12200 | loss 2.5154 | avg 3.0482 | ppl 21.08 | lr 2.99e-04 | last 200 steps: 21.0s | total: 1258s
#   step 12400 | loss 2.4993 | avg 3.0388 | ppl 20.88 | lr 2.99e-04 | last 200 steps: 21.2s | total: 1279s
#   step 12600 | loss 2.6138 | avg 3.0298 | ppl 20.69 | lr 2.99e-04 | last 200 steps: 21.1s | total: 1300s
#   step 12800 | loss 2.3993 | avg 3.0208 | ppl 20.51 | lr 2.99e-04 | last 200 steps: 21.0s | total: 1321s
#   step 13000 | loss 2.4914 | avg 3.0120 | ppl 20.33 | lr 2.99e-04 | last 200 steps: 21.0s | total: 1342s
#   step 13200 | loss 2.3130 | avg 3.0034 | ppl 20.15 | lr 2.99e-04 | last 200 steps: 20.9s | total: 1363s
#   step 13400 | loss 2.5111 | avg 2.9951 | ppl 19.99 | lr 2.99e-04 | last 200 steps: 20.8s | total: 1384s
#   step 13600 | loss 2.4885 | avg 2.9870 | ppl 19.83 | lr 2.99e-04 | last 200 steps: 21.1s | total: 1405s
#   step 13800 | loss 2.5538 | avg 2.9790 | ppl 19.67 | lr 2.99e-04 | last 200 steps: 20.9s | total: 1426s
#   step 14000 | loss 2.4954 | avg 2.9711 | ppl 19.51 | lr 2.99e-04 | last 200 steps: 20.9s | total: 1447s
#   step 14200 | loss 2.4763 | avg 2.9633 | ppl 19.36 | lr 2.99e-04 | last 200 steps: 21.1s | total: 1468s
#   step 14400 | loss 2.3956 | avg 2.9559 | ppl 19.22 | lr 2.99e-04 | last 200 steps: 20.9s | total: 1489s
#   step 14600 | loss 2.3963 | avg 2.9486 | ppl 19.08 | lr 2.99e-04 | last 200 steps: 20.6s | total: 1510s
#   step 14800 | loss 2.3627 | avg 2.9415 | ppl 18.94 | lr 2.99e-04 | last 200 steps: 21.0s | total: 1531s
#   step 15000 | loss 2.5768 | avg 2.9345 | ppl 18.81 | lr 2.99e-04 | last 200 steps: 21.0s | total: 1552s
#   step 15200 | loss 2.4477 | avg 2.9276 | ppl 18.68 | lr 2.99e-04 | last 200 steps: 21.0s | total: 1572s
#   step 15400 | loss 2.5909 | avg 2.9208 | ppl 18.56 | lr 2.99e-04 | last 200 steps: 20.7s | total: 1593s
#   step 15600 | loss 2.4586 | avg 2.9142 | ppl 18.43 | lr 2.98e-04 | last 200 steps: 20.6s | total: 1614s
#   step 15800 | loss 2.3407 | avg 2.9076 | ppl 18.31 | lr 2.98e-04 | last 200 steps: 20.7s | total: 1635s
#   step 16000 | loss 2.4181 | avg 2.9012 | ppl 18.20 | lr 2.98e-04 | last 200 steps: 20.8s | total: 1655s
#   step 16200 | loss 2.2781 | avg 2.8948 | ppl 18.08 | lr 2.98e-04 | last 200 steps: 20.8s | total: 1676s
#   step 16400 | loss 2.1837 | avg 2.8886 | ppl 17.97 | lr 2.98e-04 | last 200 steps: 20.5s | total: 1697s
#   step 16600 | loss 2.4834 | avg 2.8824 | ppl 17.86 | lr 2.98e-04 | last 200 steps: 20.7s | total: 1717s
#   step 16800 | loss 2.4115 | avg 2.8765 | ppl 17.75 | lr 2.98e-04 | last 200 steps: 20.8s | total: 1738s
#   step 17000 | loss 2.4686 | avg 2.8707 | ppl 17.65 | lr 2.98e-04 | last 200 steps: 20.7s | total: 1759s
#   step 17200 | loss 2.3331 | avg 2.8650 | ppl 17.55 | lr 2.98e-04 | last 200 steps: 20.8s | total: 1780s
#   step 17400 | loss 2.3465 | avg 2.8595 | ppl 17.45 | lr 2.98e-04 | last 200 steps: 20.7s | total: 1800s
#   step 17600 | loss 2.3703 | avg 2.8540 | ppl 17.36 | lr 2.98e-04 | last 200 steps: 20.6s | total: 1821s
#   step 17800 | loss 2.2286 | avg 2.8485 | ppl 17.26 | lr 2.98e-04 | last 200 steps: 20.5s | total: 1841s
#   step 18000 | loss 2.3275 | avg 2.8431 | ppl 17.17 | lr 2.98e-04 | last 200 steps: 20.5s | total: 1862s
#   step 18200 | loss 2.4092 | avg 2.8378 | ppl 17.08 | lr 2.98e-04 | last 200 steps: 20.8s | total: 1883s
#   step 18400 | loss 2.3713 | avg 2.8327 | ppl 16.99 | lr 2.98e-04 | last 200 steps: 20.6s | total: 1903s
#   step 18600 | loss 2.4060 | avg 2.8275 | ppl 16.90 | lr 2.98e-04 | last 200 steps: 20.8s | total: 1924s
#   Shard done — avg loss: 2.8244 | ppl 16.85
#
# Epoch 1 complete — avg loss: 2.8244 | ppl 16.85
# Epoch checkpoint saved → checkpoints_v4/epoch_1.pt
#
# ============================================================
# Epoch 2/3
# ============================================================
#
# [Epoch 2] Shard 1/1 — shard_0000.pt
#   step     0 | loss 2.4517 | avg 2.4517 | ppl 11.61 | lr 2.98e-04 | last 200 steps: 1.5s | total: 2s
#   step   200 | loss 2.3306 | avg 2.3406 | ppl 10.39 | lr 2.98e-04 | last 200 steps: 20.4s | total: 22s
#   step   400 | loss 2.2341 | avg 2.3358 | ppl 10.34 | lr 2.98e-04 | last 200 steps: 20.5s | total: 42s
#   step   600 | loss 2.4190 | avg 2.3349 | ppl 10.33 | lr 2.98e-04 | last 200 steps: 20.6s | total: 63s
#   step   800 | loss 2.2974 | avg 2.3369 | ppl 10.35 | lr 2.98e-04 | last 200 steps: 20.8s | total: 84s
#   step  1000 | loss 2.3574 | avg 2.3339 | ppl 10.32 | lr 2.98e-04 | last 200 steps: 20.8s | total: 105s
#   step  1200 | loss 2.2923 | avg 2.3329 | ppl 10.31 | lr 2.98e-04 | last 200 steps: 20.7s | total: 125s
#   step  1400 | loss 2.2215 | avg 2.3322 | ppl 10.30 | lr 2.97e-04 | last 200 steps: 20.8s | total: 146s
#   step  1600 | loss 2.3273 | avg 2.3303 | ppl 10.28 | lr 2.97e-04 | last 200 steps: 20.6s | total: 167s
#   step  1800 | loss 2.4150 | avg 2.3308 | ppl 10.29 | lr 2.97e-04 | last 200 steps: 20.6s | total: 187s
#   step  2000 | loss 2.3292 | avg 2.3296 | ppl 10.27 | lr 2.97e-04 | last 200 steps: 21.1s | total: 208s
#   step  2200 | loss 2.3893 | avg 2.3287 | ppl 10.26 | lr 2.97e-04 | last 200 steps: 20.8s | total: 229s
#   step  2400 | loss 2.3510 | avg 2.3278 | ppl 10.26 | lr 2.97e-04 | last 200 steps: 21.5s | total: 251s
#   step  2600 | loss 2.2688 | avg 2.3268 | ppl 10.25 | lr 2.97e-04 | last 200 steps: 21.4s | total: 272s
#   step  2800 | loss 2.2439 | avg 2.3253 | ppl 10.23 | lr 2.97e-04 | last 200 steps: 22.5s | total: 295s
#   step  3000 | loss 2.2223 | avg 2.3245 | ppl 10.22 | lr 2.97e-04 | last 200 steps: 21.0s | total: 316s
#   step  3200 | loss 2.2427 | avg 2.3235 | ppl 10.21 | lr 2.97e-04 | last 200 steps: 20.8s | total: 336s
#   step  3400 | loss 2.1877 | avg 2.3228 | ppl 10.20 | lr 2.97e-04 | last 200 steps: 22.6s | total: 359s
#   step  3600 | loss 2.3778 | avg 2.3222 | ppl 10.20 | lr 2.97e-04 | last 200 steps: 21.5s | total: 380s
#   step  3800 | loss 2.1149 | avg 2.3208 | ppl 10.18 | lr 2.97e-04 | last 200 steps: 21.7s | total: 402s
#   step  4000 | loss 2.3309 | avg 2.3199 | ppl 10.17 | lr 2.97e-04 | last 200 steps: 21.0s | total: 423s
#   step  4200 | loss 2.2736 | avg 2.3188 | ppl 10.16 | lr 2.97e-04 | last 200 steps: 21.0s | total: 444s
#   step  4400 | loss 2.4668 | avg 2.3183 | ppl 10.16 | lr 2.97e-04 | last 200 steps: 21.0s | total: 465s
#   step  4600 | loss 2.0450 | avg 2.3174 | ppl 10.15 | lr 2.97e-04 | last 200 steps: 20.9s | total: 486s
#   step  4800 | loss 2.3594 | avg 2.3165 | ppl 10.14 | lr 2.97e-04 | last 200 steps: 20.8s | total: 507s
#   step  5000 | loss 2.3400 | avg 2.3160 | ppl 10.14 | lr 2.96e-04 | last 200 steps: 20.7s | total: 527s
#   step  5200 | loss 2.2404 | avg 2.3151 | ppl 10.13 | lr 2.96e-04 | last 200 steps: 20.9s | total: 548s
#   step  5400 | loss 2.2411 | avg 2.3148 | ppl 10.12 | lr 2.96e-04 | last 200 steps: 20.9s | total: 569s
#   step  5600 | loss 2.1456 | avg 2.3143 | ppl 10.12 | lr 2.96e-04 | last 200 steps: 21.2s | total: 590s
#   step  5800 | loss 2.3424 | avg 2.3137 | ppl 10.11 | lr 2.96e-04 | last 200 steps: 20.5s | total: 611s
#   step  6000 | loss 2.1724 | avg 2.3126 | ppl 10.10 | lr 2.96e-04 | last 200 steps: 20.7s | total: 632s
#   step  6200 | loss 2.2745 | avg 2.3121 | ppl 10.10 | lr 2.96e-04 | last 200 steps: 21.0s | total: 653s
#   step  6400 | loss 2.3537 | avg 2.3110 | ppl 10.08 | lr 2.96e-04 | last 200 steps: 20.7s | total: 673s
#   step  6600 | loss 2.2462 | avg 2.3105 | ppl 10.08 | lr 2.96e-04 | last 200 steps: 20.8s | total: 694s
#   step  6800 | loss 2.1764 | avg 2.3099 | ppl 10.07 | lr 2.96e-04 | last 200 steps: 20.5s | total: 715s
#   step  7000 | loss 2.2119 | avg 2.3090 | ppl 10.06 | lr 2.96e-04 | last 200 steps: 20.5s | total: 735s
#   step  7200 | loss 2.2640 | avg 2.3083 | ppl 10.06 | lr 2.96e-04 | last 200 steps: 20.5s | total: 756s
#   step  7400 | loss 2.2828 | avg 2.3072 | ppl 10.05 | lr 2.96e-04 | last 200 steps: 20.5s | total: 776s
#   step  7600 | loss 2.3236 | avg 2.3066 | ppl 10.04 | lr 2.96e-04 | last 200 steps: 20.5s | total: 797s
#   step  7800 | loss 2.2311 | avg 2.3056 | ppl 10.03 | lr 2.96e-04 | last 200 steps: 20.8s | total: 817s
#   step  8000 | loss 2.2261 | avg 2.3048 | ppl 10.02 | lr 2.96e-04 | last 200 steps: 20.7s | total: 838s
#   step  8200 | loss 2.1847 | avg 2.3038 | ppl 10.01 | lr 2.95e-04 | last 200 steps: 21.0s | total: 859s
#   step  8400 | loss 2.2799 | avg 2.3025 | ppl 10.00 | lr 2.95e-04 | last 200 steps: 20.7s | total: 880s
#   step  8600 | loss 2.2338 | avg 2.3020 | ppl 9.99 | lr 2.95e-04 | last 200 steps: 20.7s | total: 900s
#   step  8800 | loss 2.1997 | avg 2.3011 | ppl 9.99 | lr 2.95e-04 | last 200 steps: 20.6s | total: 921s
#   step  9000 | loss 2.1926 | avg 2.3007 | ppl 9.98 | lr 2.95e-04 | last 200 steps: 20.8s | total: 942s
#   step  9200 | loss 2.2809 | avg 2.2998 | ppl 9.97 | lr 2.95e-04 | last 200 steps: 20.8s | total: 963s
#   step  9400 | loss 2.2836 | avg 2.2988 | ppl 9.96 | lr 2.95e-04 | last 200 steps: 20.7s | total: 983s
#   step  9600 | loss 2.2781 | avg 2.2980 | ppl 9.95 | lr 2.95e-04 | last 200 steps: 20.7s | total: 1004s
#   step  9800 | loss 2.3067 | avg 2.2972 | ppl 9.95 | lr 2.95e-04 | last 200 steps: 20.7s | total: 1025s
#   step 10000 | loss 2.3020 | avg 2.2966 | ppl 9.94 | lr 2.95e-04 | last 200 steps: 20.5s | total: 1045s
#   step 10200 | loss 2.2921 | avg 2.2959 | ppl 9.93 | lr 2.95e-04 | last 200 steps: 20.9s | total: 1066s
#   step 10400 | loss 2.1653 | avg 2.2951 | ppl 9.93 | lr 2.95e-04 | last 200 steps: 20.7s | total: 1087s
#   step 10600 | loss 2.3897 | avg 2.2942 | ppl 9.92 | lr 2.95e-04 | last 200 steps: 20.7s | total: 1108s
#   step 10800 | loss 2.2154 | avg 2.2935 | ppl 9.91 | lr 2.95e-04 | last 200 steps: 20.7s | total: 1128s
#   step 11000 | loss 2.2797 | avg 2.2927 | ppl 9.90 | lr 2.94e-04 | last 200 steps: 20.7s | total: 1149s
#   step 11200 | loss 2.1873 | avg 2.2919 | ppl 9.89 | lr 2.94e-04 | last 200 steps: 20.6s | total: 1170s
#   step 11400 | loss 2.2849 | avg 2.2910 | ppl 9.89 | lr 2.94e-04 | last 200 steps: 20.7s | total: 1190s
#   step 11600 | loss 2.2209 | avg 2.2904 | ppl 9.88 | lr 2.94e-04 | last 200 steps: 20.6s | total: 1211s
#   step 11800 | loss 2.2494 | avg 2.2897 | ppl 9.87 | lr 2.94e-04 | last 200 steps: 20.7s | total: 1232s
#   step 12000 | loss 2.2268 | avg 2.2888 | ppl 9.86 | lr 2.94e-04 | last 200 steps: 20.7s | total: 1252s
#   step 12200 | loss 2.2444 | avg 2.2882 | ppl 9.86 | lr 2.94e-04 | last 200 steps: 20.8s | total: 1273s
#   step 12400 | loss 2.1540 | avg 2.2875 | ppl 9.85 | lr 2.94e-04 | last 200 steps: 21.0s | total: 1294s
#   step 12600 | loss 2.2701 | avg 2.2865 | ppl 9.84 | lr 2.94e-04 | last 200 steps: 21.0s | total: 1315s
#   step 12800 | loss 2.1718 | avg 2.2858 | ppl 9.83 | lr 2.94e-04 | last 200 steps: 20.9s | total: 1336s
#   step 13000 | loss 2.3512 | avg 2.2850 | ppl 9.83 | lr 2.94e-04 | last 200 steps: 20.7s | total: 1357s
#   step 13200 | loss 2.1957 | avg 2.2843 | ppl 9.82 | lr 2.94e-04 | last 200 steps: 20.6s | total: 1377s
#   step 13400 | loss 2.2347 | avg 2.2835 | ppl 9.81 | lr 2.94e-04 | last 200 steps: 20.8s | total: 1398s
#   step 13600 | loss 2.3548 | avg 2.2828 | ppl 9.80 | lr 2.93e-04 | last 200 steps: 20.9s | total: 1419s
#   step 13800 | loss 2.2688 | avg 2.2822 | ppl 9.80 | lr 2.93e-04 | last 200 steps: 20.5s | total: 1439s
#   step 14000 | loss 2.3375 | avg 2.2814 | ppl 9.79 | lr 2.93e-04 | last 200 steps: 20.7s | total: 1460s
#   step 14200 | loss 2.3130 | avg 2.2808 | ppl 9.78 | lr 2.93e-04 | last 200 steps: 20.8s | total: 1481s
#   step 14400 | loss 2.3731 | avg 2.2801 | ppl 9.78 | lr 2.93e-04 | last 200 steps: 20.7s | total: 1502s
#   step 14600 | loss 2.2838 | avg 2.2794 | ppl 9.77 | lr 2.93e-04 | last 200 steps: 20.6s | total: 1522s
#   step 14800 | loss 2.5831 | avg 2.2787 | ppl 9.76 | lr 2.93e-04 | last 200 steps: 20.8s | total: 1543s
#   step 15000 | loss 2.2127 | avg 2.2780 | ppl 9.76 | lr 2.93e-04 | last 200 steps: 20.9s | total: 1564s
#   step 15200 | loss 2.2948 | avg 2.2776 | ppl 9.75 | lr 2.93e-04 | last 200 steps: 20.7s | total: 1585s
#   step 15400 | loss 2.2050 | avg 2.2770 | ppl 9.75 | lr 2.93e-04 | last 200 steps: 20.7s | total: 1605s
#   step 15600 | loss 2.1755 | avg 2.2764 | ppl 9.74 | lr 2.93e-04 | last 200 steps: 20.6s | total: 1626s
#   step 15800 | loss 2.1755 | avg 2.2758 | ppl 9.74 | lr 2.93e-04 | last 200 steps: 20.8s | total: 1647s
#   step 16000 | loss 2.1663 | avg 2.2752 | ppl 9.73 | lr 2.92e-04 | last 200 steps: 20.7s | total: 1668s
#   step 16200 | loss 2.3100 | avg 2.2745 | ppl 9.72 | lr 2.92e-04 | last 200 steps: 20.7s | total: 1688s
#   step 16400 | loss 2.2889 | avg 2.2739 | ppl 9.72 | lr 2.92e-04 | last 200 steps: 20.5s | total: 1709s
#   step 16600 | loss 2.2169 | avg 2.2733 | ppl 9.71 | lr 2.92e-04 | last 200 steps: 21.1s | total: 1730s
#   step 16800 | loss 2.4261 | avg 2.2727 | ppl 9.71 | lr 2.92e-04 | last 200 steps: 20.9s | total: 1751s
#   step 17000 | loss 2.1794 | avg 2.2720 | ppl 9.70 | lr 2.92e-04 | last 200 steps: 20.8s | total: 1772s
#   step 17200 | loss 2.3998 | avg 2.2714 | ppl 9.69 | lr 2.92e-04 | last 200 steps: 21.0s | total: 1792s
#   step 17400 | loss 2.2412 | avg 2.2708 | ppl 9.69 | lr 2.92e-04 | last 200 steps: 20.8s | total: 1813s
#   step 17600 | loss 2.1143 | avg 2.2701 | ppl 9.68 | lr 2.92e-04 | last 200 steps: 20.9s | total: 1834s
#   step 17800 | loss 2.1648 | avg 2.2695 | ppl 9.67 | lr 2.92e-04 | last 200 steps: 20.8s | total: 1855s
#   step 18000 | loss 2.2681 | avg 2.2690 | ppl 9.67 | lr 2.92e-04 | last 200 steps: 21.2s | total: 1876s
#   step 18200 | loss 2.3371 | avg 2.2684 | ppl 9.66 | lr 2.92e-04 | last 200 steps: 21.0s | total: 1897s
#   step 18400 | loss 2.1893 | avg 2.2678 | ppl 9.66 | lr 2.91e-04 | last 200 steps: 21.1s | total: 1918s
#   step 18600 | loss 2.1227 | avg 2.2673 | ppl 9.65 | lr 2.91e-04 | last 200 steps: 21.1s | total: 1939s
#   Shard done — avg loss: 2.2669 | ppl 9.65
#
# Epoch 2 complete — avg loss: 2.2669 | ppl 9.65
# Epoch checkpoint saved → checkpoints_v4/epoch_2.pt
#
# ============================================================
# Epoch 3/3
# ============================================================
#
# [Epoch 3] Shard 1/1 — shard_0000.pt
#   step     0 | loss 2.1335 | avg 2.1335 | ppl 8.44 | lr 2.91e-04 | last 200 steps: 2.5s | total: 2s
#   step   200 | loss 2.0658 | avg 2.2093 | ppl 9.11 | lr 2.91e-04 | last 200 steps: 20.6s | total: 23s
#   step   400 | loss 2.0688 | avg 2.2067 | ppl 9.09 | lr 2.91e-04 | last 200 steps: 21.0s | total: 44s
#   step   600 | loss 2.2789 | avg 2.2048 | ppl 9.07 | lr 2.91e-04 | last 200 steps: 21.0s | total: 65s
#   step   800 | loss 2.2691 | avg 2.2066 | ppl 9.08 | lr 2.91e-04 | last 200 steps: 21.2s | total: 86s
#   step  1000 | loss 2.0195 | avg 2.2057 | ppl 9.08 | lr 2.91e-04 | last 200 steps: 21.2s | total: 107s
#   step  1200 | loss 2.0697 | avg 2.2075 | ppl 9.09 | lr 2.91e-04 | last 200 steps: 20.6s | total: 128s
#   step  1400 | loss 2.0772 | avg 2.2071 | ppl 9.09 | lr 2.91e-04 | last 200 steps: 21.2s | total: 149s
#   step  1600 | loss 2.1549 | avg 2.2054 | ppl 9.07 | lr 2.91e-04 | last 200 steps: 21.3s | total: 171s
#   step  1800 | loss 2.4922 | avg 2.2055 | ppl 9.07 | lr 2.90e-04 | last 200 steps: 21.1s | total: 192s
#   step  2000 | loss 2.2475 | avg 2.2038 | ppl 9.06 | lr 2.90e-04 | last 200 steps: 21.3s | total: 213s
#   step  2200 | loss 2.0992 | avg 2.2036 | ppl 9.06 | lr 2.90e-04 | last 200 steps: 21.3s | total: 234s
#   step  2400 | loss 2.1942 | avg 2.2035 | ppl 9.06 | lr 2.90e-04 | last 200 steps: 21.2s | total: 255s
#   step  2600 | loss 2.0668 | avg 2.2034 | ppl 9.06 | lr 2.90e-04 | last 200 steps: 21.2s | total: 277s
#   step  2800 | loss 2.2878 | avg 2.2037 | ppl 9.06 | lr 2.90e-04 | last 200 steps: 22.0s | total: 299s
#   step  3000 | loss 2.2210 | avg 2.2030 | ppl 9.05 | lr 2.90e-04 | last 200 steps: 21.3s | total: 320s
#   step  3200 | loss 2.1901 | avg 2.2025 | ppl 9.05 | lr 2.90e-04 | last 200 steps: 21.1s | total: 341s
#   step  3400 | loss 2.1021 | avg 2.2019 | ppl 9.04 | lr 2.90e-04 | last 200 steps: 21.2s | total: 362s
#   step  3600 | loss 2.0652 | avg 2.2017 | ppl 9.04 | lr 2.90e-04 | last 200 steps: 29.0s | total: 391s
#   step  3800 | loss 2.1956 | avg 2.2009 | ppl 9.03 | lr 2.89e-04 | last 200 steps: 46.8s | total: 438s
#   step  4000 | loss 2.1784 | avg 2.2008 | ppl 9.03 | lr 2.89e-04 | last 200 steps: 46.6s | total: 485s
#   step  4200 | loss 2.2631 | avg 2.1999 | ppl 9.02 | lr 2.89e-04 | last 200 steps: 46.7s | total: 531s
#   step  4400 | loss 2.0827 | avg 2.1999 | ppl 9.02 | lr 2.89e-04 | last 200 steps: 46.6s | total: 578s
#   step  4600 | loss 2.3619 | avg 2.1994 | ppl 9.02 | lr 2.89e-04 | last 200 steps: 46.9s | total: 625s
#   step  4800 | loss 2.0991 | avg 2.1997 | ppl 9.02 | lr 2.89e-04 | last 200 steps: 47.9s | total: 673s
#   step  5000 | loss 2.1547 | avg 2.1994 | ppl 9.02 | lr 2.89e-04 | last 200 steps: 46.5s | total: 719s
#   step  5200 | loss 2.0357 | avg 2.1992 | ppl 9.02 | lr 2.89e-04 | last 200 steps: 46.8s | total: 766s
#   step  5400 | loss 2.0467 | avg 2.1986 | ppl 9.01 | lr 2.89e-04 | last 200 steps: 46.5s | total: 813s
#   step  5600 | loss 2.1910 | avg 2.1981 | ppl 9.01 | lr 2.89e-04 | last 200 steps: 46.5s | total: 859s
#   step  5800 | loss 2.1376 | avg 2.1977 | ppl 9.00 | lr 2.88e-04 | last 200 steps: 46.6s | total: 906s
#   step  6000 | loss 2.2052 | avg 2.1972 | ppl 9.00 | lr 2.88e-04 | last 200 steps: 46.7s | total: 952s
#   step  6200 | loss 2.2948 | avg 2.1970 | ppl 9.00 | lr 2.88e-04 | last 200 steps: 46.7s | total: 999s
#   step  6400 | loss 2.1927 | avg 2.1966 | ppl 8.99 | lr 2.88e-04 | last 200 steps: 46.7s | total: 1046s
#   step  6600 | loss 2.3545 | avg 2.1964 | ppl 8.99 | lr 2.88e-04 | last 200 steps: 46.7s | total: 1093s
#   step  6800 | loss 2.0904 | avg 2.1961 | ppl 8.99 | lr 2.88e-04 | last 200 steps: 46.6s | total: 1139s
#   step  7000 | loss 2.1700 | avg 2.1954 | ppl 8.98 | lr 2.88e-04 | last 200 steps: 46.8s | total: 1186s
#   step  7200 | loss 2.1970 | avg 2.1953 | ppl 8.98 | lr 2.88e-04 | last 200 steps: 47.0s | total: 1233s
#   step  7400 | loss 2.2269 | avg 2.1949 | ppl 8.98 | lr 2.88e-04 | last 200 steps: 47.0s | total: 1280s
#   step  7600 | loss 2.1550 | avg 2.1944 | ppl 8.97 | lr 2.87e-04 | last 200 steps: 46.7s | total: 1327s
#   step  7800 | loss 2.1574 | avg 2.1942 | ppl 8.97 | lr 2.87e-04 | last 200 steps: 46.6s | total: 1373s
#   step  8000 | loss 2.0703 | avg 2.1938 | ppl 8.97 | lr 2.87e-04 | last 200 steps: 46.7s | total: 1420s
#   step  8200 | loss 2.2583 | avg 2.1934 | ppl 8.97 | lr 2.87e-04 | last 200 steps: 46.8s | total: 1467s
#   step  8400 | loss 2.1865 | avg 2.1933 | ppl 8.96 | lr 2.87e-04 | last 200 steps: 46.3s | total: 1513s
#   step  8600 | loss 2.1587 | avg 2.1929 | ppl 8.96 | lr 2.87e-04 | last 200 steps: 47.0s | total: 1560s
#   step  8800 | loss 2.3411 | avg 2.1926 | ppl 8.96 | lr 2.87e-04 | last 200 steps: 46.8s | total: 1607s
#   step  9000 | loss 2.0523 | avg 2.1921 | ppl 8.95 | lr 2.87e-04 | last 200 steps: 46.5s | total: 1653s
#   step  9200 | loss 2.2393 | avg 2.1920 | ppl 8.95 | lr 2.87e-04 | last 200 steps: 46.6s | total: 1700s
#   step  9400 | loss 2.0952 | avg 2.1920 | ppl 8.95 | lr 2.86e-04 | last 200 steps: 46.3s | total: 1746s
#   step  9600 | loss 2.2515 | avg 2.1917 | ppl 8.95 | lr 2.86e-04 | last 200 steps: 46.4s | total: 1793s
#   step  9800 | loss 2.2913 | avg 2.1912 | ppl 8.95 | lr 2.86e-04 | last 200 steps: 46.5s | total: 1839s
#   step 10000 | loss 2.3302 | avg 2.1909 | ppl 8.94 | lr 2.86e-04 | last 200 steps: 46.4s | total: 1886s
#   step 10200 | loss 2.1182 | avg 2.1906 | ppl 8.94 | lr 2.86e-04 | last 200 steps: 46.4s | total: 1932s
#   step 10400 | loss 2.2590 | avg 2.1900 | ppl 8.94 | lr 2.86e-04 | last 200 steps: 46.6s | total: 1978s
#   step 10600 | loss 2.1605 | avg 2.1898 | ppl 8.93 | lr 2.86e-04 | last 200 steps: 46.6s | total: 2025s
#   step 10800 | loss 2.2370 | avg 2.1897 | ppl 8.93 | lr 2.86e-04 | last 200 steps: 46.9s | total: 2072s
#   step 11000 | loss 2.1558 | avg 2.1896 | ppl 8.93 | lr 2.86e-04 | last 200 steps: 46.5s | total: 2118s
#   step 11200 | loss 2.2789 | avg 2.1895 | ppl 8.93 | lr 2.85e-04 | last 200 steps: 46.6s | total: 2165s
#   step 11400 | loss 2.1463 | avg 2.1893 | ppl 8.93 | lr 2.85e-04 | last 200 steps: 46.5s | total: 2211s
#   step 11600 | loss 2.0669 | avg 2.1890 | ppl 8.93 | lr 2.85e-04 | last 200 steps: 46.4s | total: 2258s
#   step 11800 | loss 2.2913 | avg 2.1888 | ppl 8.92 | lr 2.85e-04 | last 200 steps: 46.8s | total: 2305s
#   step 12000 | loss 2.3330 | avg 2.1886 | ppl 8.92 | lr 2.85e-04 | last 200 steps: 46.7s | total: 2351s
#   step 12200 | loss 2.1670 | avg 2.1883 | ppl 8.92 | lr 2.85e-04 | last 200 steps: 46.8s | total: 2398s
#   step 12400 | loss 2.0801 | avg 2.1880 | ppl 8.92 | lr 2.85e-04 | last 200 steps: 46.5s | total: 2445s
#   step 12600 | loss 2.0782 | avg 2.1878 | ppl 8.92 | lr 2.85e-04 | last 200 steps: 46.6s | total: 2491s
#   step 12800 | loss 2.0732 | avg 2.1876 | ppl 8.91 | lr 2.84e-04 | last 200 steps: 46.6s | total: 2538s
#   step 13000 | loss 1.9886 | avg 2.1876 | ppl 8.91 | lr 2.84e-04 | last 200 steps: 46.2s | total: 2584s
#   step 13200 | loss 2.1240 | avg 2.1875 | ppl 8.91 | lr 2.84e-04 | last 200 steps: 46.6s | total: 2631s
#   step 13400 | loss 2.1481 | avg 2.1872 | ppl 8.91 | lr 2.84e-04 | last 200 steps: 46.3s | total: 2677s
#   step 13600 | loss 1.9440 | avg 2.1871 | ppl 8.91 | lr 2.84e-04 | last 200 steps: 46.1s | total: 2723s
#   step 13800 | loss 2.0844 | avg 2.1868 | ppl 8.91 | lr 2.84e-04 | last 200 steps: 46.2s | total: 2769s
#   step 14000 | loss 2.1782 | avg 2.1866 | ppl 8.91 | lr 2.84e-04 | last 200 steps: 46.0s | total: 2815s
#   step 14200 | loss 2.2516 | avg 2.1863 | ppl 8.90 | lr 2.84e-04 | last 200 steps: 46.5s | total: 2862s
#   step 14400 | loss 2.1566 | avg 2.1861 | ppl 8.90 | lr 2.83e-04 | last 200 steps: 46.3s | total: 2908s
#   step 14600 | loss 2.1782 | avg 2.1859 | ppl 8.90 | lr 2.83e-04 | last 200 steps: 46.2s | total: 2954s
#   step 14800 | loss 2.1352 | avg 2.1856 | ppl 8.90 | lr 2.83e-04 | last 200 steps: 46.0s | total: 3000s
#   step 15000 | loss 2.4276 | avg 2.1853 | ppl 8.89 | lr 2.83e-04 | last 200 steps: 46.3s | total: 3046s
#   step 15200 | loss 2.2138 | avg 2.1851 | ppl 8.89 | lr 2.83e-04 | last 200 steps: 46.2s | total: 3093s
#   step 15400 | loss 2.2255 | avg 2.1847 | ppl 8.89 | lr 2.83e-04 | last 200 steps: 46.3s | total: 3139s
#   step 15600 | loss 2.1398 | avg 2.1845 | ppl 8.89 | lr 2.83e-04 | last 200 steps: 46.3s | total: 3185s
#   step 15800 | loss 2.1257 | avg 2.1842 | ppl 8.88 | lr 2.83e-04 | last 200 steps: 46.1s | total: 3231s
#   step 16000 | loss 2.2146 | avg 2.1840 | ppl 8.88 | lr 2.82e-04 | last 200 steps: 46.1s | total: 3277s
#   step 16200 | loss 2.1753 | avg 2.1839 | ppl 8.88 | lr 2.82e-04 | last 200 steps: 46.1s | total: 3324s
#   step 16400 | loss 2.2614 | avg 2.1837 | ppl 8.88 | lr 2.82e-04 | last 200 steps: 45.9s | total: 3369s
#   step 16600 | loss 2.2154 | avg 2.1835 | ppl 8.88 | lr 2.82e-04 | last 200 steps: 46.0s | total: 3415s
#   step 16800 | loss 2.1998 | avg 2.1832 | ppl 8.87 | lr 2.82e-04 | last 200 steps: 46.1s | total: 3462s
#   step 17000 | loss 2.0762 | avg 2.1829 | ppl 8.87 | lr 2.82e-04 | last 200 steps: 46.1s | total: 3508s
#   step 17200 | loss 2.1128 | avg 2.1827 | ppl 8.87 | lr 2.82e-04 | last 200 steps: 46.0s | total: 3554s
#   step 17400 | loss 2.2866 | avg 2.1825 | ppl 8.87 | lr 2.82e-04 | last 200 steps: 46.0s | total: 3600s
#   step 17600 | loss 2.1760 | avg 2.1822 | ppl 8.87 | lr 2.81e-04 | last 200 steps: 45.7s | total: 3645s
#   step 17800 | loss 2.2492 | avg 2.1820 | ppl 8.86 | lr 2.81e-04 | last 200 steps: 45.9s | total: 3691s
#   step 18000 | loss 2.2213 | avg 2.1817 | ppl 8.86 | lr 2.81e-04 | last 200 steps: 45.9s | total: 3737s
#   step 18200 | loss 2.1002 | avg 2.1815 | ppl 8.86 | lr 2.81e-04 | last 200 steps: 45.9s | total: 3783s
#   step 18400 | loss 2.0804 | avg 2.1813 | ppl 8.86 | lr 2.81e-04 | last 200 steps: 46.2s | total: 3829s
#   step 18600 | loss 2.0953 | avg 2.1811 | ppl 8.86 | lr 2.81e-04 | last 200 steps: 45.8s | total: 3875s
#   Shard done — avg loss: 2.1810 | ppl 8.85
#
# Epoch 3 complete — avg loss: 2.1810 | ppl 8.85
# Epoch checkpoint saved → checkpoints_v4/epoch_3.pt
#
# Training complete.

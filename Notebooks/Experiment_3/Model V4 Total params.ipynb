# %%
import torch
import torch.nn as nn
import numpy as np
import math
import time

# Load frozen embedding table
TOK_DIR     = "tokenizer_v2-8k/"
embedding_table = np.load(TOK_DIR+"token_embeddings.npy")
embedding_tensor = torch.tensor(embedding_table, dtype=torch.float32)

VOCAB_SIZE    = embedding_tensor.shape[0]   # 4096
MINILM_DIM    = embedding_tensor.shape[1]   # 384
print(f"Vocab size : {VOCAB_SIZE}")
print(f"MiniLM dim : {MINILM_DIM}")
# Out:
# Vocab size : 8192
# MiniLM dim : 384

# %%
import torch.nn.functional as F 

EXPANDED_DIM = 512
N_HEADS  = 8
N_LAYERS = 2
FFN_DIM  = 768
HEAD_DIM = EXPANDED_DIM // N_HEADS 

def sinusoidal_encoding(seq_len, dim, device):
    pe       = torch.zeros(seq_len, dim, device=device)
    position = torch.arange(seq_len, device=device).unsqueeze(1)
    div_term = torch.exp(torch.arange(0, dim, 2, device=device) * (-math.log(10000.0) / dim))
    pe[:, 0::2] = torch.sin(position * div_term)
    pe[:, 1::2] = torch.cos(position * div_term)
    return pe  # (seq_len, dim)

class LayerNorm(nn.Module):
    """
    y = ((x - mean) / sqrt(var + eps)) * gamma + beta
    gamma, beta are learned per-feature scalars — shape (dim,)
    """
    def __init__(self, dim, eps=1e-5):
        super().__init__()
        self.eps   = eps
        self.gamma = nn.Parameter(torch.ones(dim))   # scale
        self.beta  = nn.Parameter(torch.zeros(dim))  # shift

    def forward(self, x):
        mean = x.mean(dim=-1, keepdim=True)           # (B, T, 1)
        var  = x.var(dim=-1, keepdim=True, unbiased=False)  # (B, T, 1)
        x_norm = (x - mean) / torch.sqrt(var + self.eps)    # (B, T, D)
        return self.gamma * x_norm + self.beta               # (B, T, D)

class MultiHeadCausalAttention(nn.Module):
    """
    Projects input into Q, K, V — splits into H heads — computes scaled
    dot-product attention with a causal mask — concatenates heads — projects out.

    Q = x W_q      shape: (B, T, D)
    K = x W_k      shape: (B, T, D)
    V = x W_v      shape: (B, T, D)

    Reshape to (B, H, T, head_dim), then:
        scores = Q @ Kᵀ / sqrt(head_dim)    (B, H, T, T)
        scores = scores + causal_mask        (upper triangle = -inf)
        weights = softmax(scores, dim=-1)    (B, H, T, T)
        out = weights @ V                    (B, H, T, head_dim)

    Concat heads → (B, T, D), project out via W_o
    """
    def __init__(self, dim, n_heads, dropout=0.0):
        super().__init__()
        assert dim % n_heads == 0, "dim must be divisible by n_heads"
        self.n_heads  = n_heads
        self.head_dim = dim // n_heads       # 48
        self.scale    = self.head_dim ** -0.5

        self.W_q = nn.Linear(dim, dim, bias=False)
        self.W_k = nn.Linear(dim, dim, bias=False)
        self.W_v = nn.Linear(dim, dim, bias=False)
        self.W_o = nn.Linear(dim, dim, bias=False)

        self.attn_drop = nn.Dropout(dropout)

    def forward(self, x):
        B, T, D = x.shape

        # --- Project & split into heads ---
        Q = self.W_q(x)  # (B, T, D)
        K = self.W_k(x)  # (B, T, D)
        V = self.W_v(x)  # (B, T, D)

        # Reshape: (B, T, D) → (B, H, T, head_dim)
        Q = Q.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)
        K = K.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)
        V = V.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)

        # --- Scaled dot-product attention ---
        # (B, H, T, head_dim) @ (B, H, head_dim, T) → (B, H, T, T)
        scores = (Q @ K.transpose(-2, -1)) * self.scale

        # Causal mask: positions can only attend to themselves and earlier tokens
        # Upper triangle (future tokens) set to -inf → softmax drives them to 0
        causal_mask = torch.triu(
            torch.ones(T, T, device=x.device, dtype=torch.bool), diagonal=1
        )
        scores = scores.masked_fill(causal_mask, float('-inf'))

        weights = torch.softmax(scores, dim=-1)  # (B, H, T, T)
        weights = self.attn_drop(weights)

        # (B, H, T, T) @ (B, H, T, head_dim) → (B, H, T, head_dim)
        out = weights @ V

        # --- Concat heads & project ---
        # (B, H, T, head_dim) → (B, T, H*head_dim) = (B, T, D)
        out = out.transpose(1, 2).contiguous().view(B, T, D)
        return self.W_o(out)  # (B, T, D)

class FeedForward(nn.Module):
    """
    Two-layer MLP with GELU activation.
    FFN(x) = GELU(x W_1 + b_1) W_2 + b_2

    Expands dim → ffn_dim (wider representation),
    then projects back down ffn_dim → dim.
    """
    def __init__(self, dim, ffn_dim, dropout=0.0):
        super().__init__()
        self.W_1 = nn.Linear(dim, ffn_dim)       # expand
        self.W_2 = nn.Linear(ffn_dim, ffn_dim)       # maintain
        self.W_3 = nn.Linear(ffn_dim, dim)       # contract
        # self.drop = nn.Dropout(dropout)

    def forward(self, x):
        x = F.gelu(self.W_1(x))   # (B, T, ffn_dim)
        # x = self.drop(x)
        x = F.gelu(self.W_2(x))   
        # x = self.drop(x)
        x = self.W_3(x)           # (B, T, dim)
        return x

class TransformerBlock(nn.Module):
    """
    Pre-norm residual block (norm_first=True, same as your original config).

    x = x + Attention(LayerNorm(x))   ← self-attention sub-layer
    x = x + FFN(LayerNorm(x))         ← feed-forward sub-layer

    Pre-norm (LN before the sub-layer) stabilises training at depth
    vs post-norm (LN after the residual add).
    """
    def __init__(self, dim, n_heads, ffn_dim, dropout=0.0):
        super().__init__()
        self.norm_1 = LayerNorm(dim)
        self.attn   = MultiHeadCausalAttention(dim, n_heads, dropout)
        self.norm_2 = LayerNorm(dim)
        self.ffn    = FeedForward(dim, ffn_dim, dropout)
        self.drop   = nn.Dropout(dropout)

    def forward(self, x):
        x = x + self.drop(self.attn(self.norm_1(x)))  # (B, T, D)
        x = x + self.drop(self.ffn(self.norm_2(x)))   # (B, T, D)
        return x

class MicroLM(nn.Module):
    """
    Full architecture:
      1. Frozen MiniLM embedding lookup         → (B, T, 384)
      2. Sinusoidal positional encoding added   → (B, T, 384)
      3. N_LAYERS x TransformerBlock            → (B, T, 384)
      4. Final LayerNorm                        → (B, T, 384)
      5. Linear output head → logits            → (B, T, VOCAB_SIZE)
    """
    def __init__(self):
        super().__init__()
        self.register_buffer("embedding_table", embedding_tensor)

        # Expander 384 -> 512
        self.mapper = nn.Sequential(
            nn.Linear(MINILM_DIM, EXPANDED_DIM),
            nn.GELU(),
            # nn.Dropout(0.05),
            # nn.Linear(HIDDEN_DIM_1, HIDDEN_DIM_2),
            # nn.GELU(),
            # nn.Dropout(0.05),
            # nn.Linear(HIDDEN_DIM_1, EXPANDED_DIM),
            nn.LayerNorm(EXPANDED_DIM),
        )

        self.blocks = nn.ModuleList([
            TransformerBlock(EXPANDED_DIM, N_HEADS, FFN_DIM, dropout=0.0)
            for _ in range(N_LAYERS)
        ])

        self.norm        = LayerNorm(EXPANDED_DIM)
        self.output_head = nn.Linear(EXPANDED_DIM, VOCAB_SIZE, bias=False)

    def forward(self, token_ids):
        B, T = token_ids.shape

        x = self.embedding_table[token_ids]                    # (B, T, 384)
        x = self.mapper(x)
        x = x + sinusoidal_encoding(T, EXPANDED_DIM, token_ids.device) # (B, T, 384)

        for block in self.blocks:
            x = block(x)   # (B, T, 384)

        x = self.norm(x)
        return self.output_head(x)  # (B, T, VOCAB_SIZE)

# %%
model     = MicroLM()
total     = sum(p.numel() for p in model.parameters())
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
frozen    = total - trainable

print(f"Trainable params : {trainable:,}")
print(f"Frozen params    : {frozen:,}  (embedding table)")
print(f"Total params     : {total:,}")

# print(f"\nParam breakdown:")
# for name, p in model.named_parameters():
#     if p.requires_grad:
#         print(f"  {name:55s} {p.numel():>10,}")

# Forward pass
x      = torch.randint(0, VOCAB_SIZE, (2, 32))
logits = model(x)
print(f"\nInput  : {x.shape}")
print(f"Output : {logits.shape}")
# Out:
# Trainable params : 9,251,328
# Frozen params    : 0  (embedding table)
# Total params     : 9,251,328
#
# Input  : torch.Size([2, 32])
# Output : torch.Size([2, 32, 8192])

# %%
# ── Training Config ───────────────────────────────────────────────────────────
import gc
import json
import random
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from pathlib import Path

SHARD_DIR  = Path("dataset_shards_v2-8k")
SEQ_LEN    = 512
STRIDE  = 448    # step size → 64-token overlap
BATCH_SIZE = 16
N_EPOCHS   = 40
LOG_EVERY  = 200
CKPT_DIR   = Path("checkpoints_v4")
CKPT_DIR.mkdir(parents=True, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device      : {device}")
print(f"Model params: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# Device      : cuda
# Model params: 9,251,328

# %%
from torch.utils.data import Dataset


class ShardDataset(Dataset):
    def __init__(self, shard_path, seq_len=SEQ_LEN, stride=STRIDE):
        flat = torch.load(shard_path, weights_only=True)

        self.flat    = flat.to(torch.int16)[:2_000_000]
        self.seq_len = seq_len
        self.stride  = stride

        # number of full windows we can extract
        # +1 because we need seq_len+1 tokens (x + y target)
        n_tokens = len(self.flat)
        self.num_samples = max(0, (n_tokens - seq_len - 1) // stride + 1)

    def __len__(self):
        return self.num_samples

    def __getitem__(self, idx):
        start  = idx * self.stride
        tokens = self.flat[start : start + self.seq_len + 1].to(torch.long)  # ← cast here
        
        if len(tokens) < self.seq_len + 1:
            pad    = torch.full((self.seq_len + 1 - len(tokens),), PAD_ID, dtype=torch.long)
            tokens = torch.cat([tokens, pad])

        x = tokens[:-1]
        y = tokens[1:]
        return x, y


BOS_ID       = 2
EOS_ID       = 3

def collate_fn(batch):
    xs, ys = zip(*batch)
    # all samples are now fixed-length (seq_len), so no padding needed here
    x_pad = torch.stack(xs)          # [B, seq_len]
    y_pad = torch.stack(ys).clone()  # [B, seq_len]

    # mask out targets after the first EOS in each sequence
    for i, y in enumerate(y_pad):
        eos_positions = (y == EOS_ID).nonzero(as_tuple=True)[0]
        if len(eos_positions) > 0:
            eos_pos = eos_positions[0].item()
            if eos_pos + 1 < y.size(0):
                y_pad[i, eos_pos + 1:] = -100

    return x_pad, y_pad

# %%
# run once after sharding
meta = {
    "total_samples": sum(len(ShardDataset(p)) for p in sorted(SHARD_DIR.glob("shard_*.pt"))[:1]),
    "seq_len": SEQ_LEN,
    "stride": STRIDE,
}
with open(SHARD_DIR / "meta.json", "w") as f:
    json.dump(meta, f, indent=2)
    
# ── Optimizer & Scheduler ─────────────────────────────────────────────────────

with open(SHARD_DIR / "meta.json") as f:
    meta = json.load(f)
total_steps = (meta['total_samples'] // BATCH_SIZE) * N_EPOCHS

optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=total_steps, eta_min=1e-5
)
scaler    = torch.cuda.amp.GradScaler()

print(f"Total samples: {meta['total_samples']:,}")
print(f"Total steps  : {total_steps:,}")
# Out:
# Total samples: 4,464
# Total steps  : 11,160
# /tmp/ipykernel_119724/2601078807.py:20: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler    = torch.cuda.amp.GradScaler()

# %%
model.to(device)
# Out:
# MicroLM(
#   (mapper): Sequential(
#     (0): Linear(in_features=384, out_features=512, bias=True)
#     (1): GELU(approximate='none')
#     (2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (blocks): ModuleList(
#     (0-1): 2 x TransformerBlock(
#       (norm_1): LayerNorm()
#       (attn): MultiHeadCausalAttention(
#         (W_q): Linear(in_features=512, out_features=512, bias=False)
#         (W_k): Linear(in_features=512, out_features=512, bias=False)
#         (W_v): Linear(in_features=512, out_features=512, bias=False)
#         (W_o): Linear(in_features=512, out_features=512, bias=False)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#       )
#       (norm_2): LayerNorm()
#       (ffn): FeedForward(
#         (W_1): Linear(in_features=512, out_features=768, bias=True)
#         (W_2): Linear(in_features=768, out_features=768, bias=True)
#         (W_3): Linear(in_features=768, out_features=512, bias=True)
#       )
#       (drop): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (norm): LayerNorm()
#   (output_head): Linear(in_features=512, out_features=8192, bias=False)
# )

# %%
shard_files  = sorted(SHARD_DIR.glob("shard_*.pt"))[:1]
shard_files
# Out:
# [PosixPath('dataset_shards_v2-8k/shard_0000.pt')]

# %%
epoch_ckpts = [c for c in all_ckpts if "shard" not in c.name][-6:-5]
epoch_ckpts
# Out:
# [PosixPath('checkpoints_v4/epoch_40.pt')]

# %%
# ── Training Loop with Resume ─────────────────────────────────────────────────
import math

shard_files  = sorted(SHARD_DIR.glob("shard_*.pt"))[:1]
loss_history = []
start_epoch  = 0
start_shard  = 0

# ── Resume from latest checkpoint ────────────────────────────────────────────
# Check mid-epoch checkpoints first, then epoch checkpoints
all_ckpts = sorted(CKPT_DIR.glob("epoch_*.pt"))
epoch_ckpts = [c for c in all_ckpts if "shard" not in c.name][-6:-5]

if epoch_ckpts:
    latest = epoch_ckpts[-1]
    print(f"Resuming from epoch checkpoint {latest}...")
    ckpt = torch.load(latest, map_location=device)
    model.load_state_dict(ckpt["model"])
    optimizer.load_state_dict(ckpt["optimizer"])
    scheduler.load_state_dict(ckpt["scheduler"])
    loss_history = ckpt.get("loss_history", [])
    start_epoch  = ckpt["epoch"]            # full epoch completed
    start_shard  = 0                        # start from beginning of next epoch
    print(f"Resumed — starting from epoch {start_epoch+1}")

else:
    print("No checkpoint found — training from scratch")

optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4)
model.to(device)
model.train()

for epoch in range(start_epoch, 100):
    epoch_loss  = 0.0
    epoch_steps = 0

    # no shuffle — sequential shard order
    shard_order = list(range(len(shard_files)))

    # if resuming mid-epoch, skip already completed shards
    if epoch == start_epoch and start_shard > 0:
        shard_order = shard_order[start_shard:]
        print(f"Skipping shards 0-{start_shard-1}, resuming from shard {start_shard}")

    print(f"\n{'='*60}")
    print(f"Epoch {epoch+1}/{N_EPOCHS}")
    print(f"{'='*60}")

    for shard_num, shard_idx in enumerate(shard_order):
        # just before the step loop:
        shard_start = time.time()
        interval_start = time.time()
        
        # actual shard number in epoch (accounts for skipped shards on resume)
        actual_shard_num = shard_idx  

        shard_path = shard_files[shard_idx]
        print(f"\n[Epoch {epoch+1}] Shard {actual_shard_num+1}/{len(shard_files)} — {shard_path.name}")

        ds     = ShardDataset(shard_path)
        loader = DataLoader(
            ds,
            batch_size=BATCH_SIZE,
            shuffle=True,
            collate_fn=collate_fn,
            num_workers=0,
            pin_memory=True,
        )

        shard_loss  = 0.0
        shard_steps = 0

        for step, (x, y) in enumerate(loader):
            x = x.to(device)
            y = y.to(device)

            optimizer.zero_grad()

            with torch.autocast(device_type="cuda", dtype=torch.bfloat16):
                logits = model(x)
                loss   = F.cross_entropy(
                    logits.view(-1, logits.size(-1)),
                    y.view(-1),
                    ignore_index=-100,
                )
                del logits  # free 268MB immediately before backward


            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()

            if not math.isnan(loss.item()):
                shard_loss  += loss.item()
                shard_steps += 1
                epoch_loss  += loss.item()
                epoch_steps += 1

            if step % LOG_EVERY == 0:
                # scheduler.step()
                avg = shard_loss / max(shard_steps, 1)
                ppl = math.exp(min(avg, 20))
                lr  = scheduler.get_last_lr()[0]
                elapsed_total = time.time() - shard_start
                interval_time = time.time() - interval_start
                print(f"  step {step:>5} | loss {loss.item():.4f} | avg {avg:.4f} | ppl {ppl:.2f} | lr {lr:.2e} | last {LOG_EVERY} steps: {interval_time:.1f}s | total: {elapsed_total:.0f}s")
                interval_start = time.time()  # reset for next interval

            del loss, x, y
        shard_avg = shard_loss / max(shard_steps, 1)
        shard_ppl = math.exp(min(shard_avg, 20))
        loss_history.append({
            "epoch":      epoch + 1,
            "shard":      actual_shard_num,
            "avg_loss":   shard_avg,
            "perplexity": shard_ppl,
        })
        print(f"  Shard done — avg loss: {shard_avg:.4f} | ppl {shard_ppl:.2f}")

        del ds, loader
        gc.collect()
        torch.cuda.empty_cache()

    # reset start_shard after first resumed epoch
    start_shard = 0

    epoch_avg = epoch_loss / max(epoch_steps, 1)
    epoch_ppl = math.exp(min(epoch_avg, 20))
    print(f"\nEpoch {epoch+1} complete — avg loss: {epoch_avg:.4f} | ppl {epoch_ppl:.2f}")

    ckpt_path = CKPT_DIR / f"epoch_{epoch+1}.pt"
    torch.save({
        "epoch":        epoch + 1,
        "shard":        -1,
        "model":        model.state_dict(),
        "optimizer":    optimizer.state_dict(),
        "scheduler":    scheduler.state_dict(),
        "loss_history": loss_history,
    }, ckpt_path)
    print(f"Epoch checkpoint saved → {ckpt_path}")

    with open(CKPT_DIR / "loss_history.json", "w") as f:
        json.dump(loss_history, f, indent=2)

print("\nTraining complete.")
# Out:
# Resuming from epoch checkpoint checkpoints_v4/epoch_40.pt...
# Resumed — starting from epoch 41
#
# ============================================================
# Epoch 41/40
# ============================================================
#
# [Epoch 41] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.7631 | avg 0.7631 | ppl 2.14 | lr 3.00e-04 | last 200 steps: 2.4s | total: 2s
#   step   200 | loss 1.2032 | avg 1.1074 | ppl 3.03 | lr 3.00e-04 | last 200 steps: 8.1s | total: 10s
#   Shard done — avg loss: 1.1512 | ppl 3.16
#
# Epoch 41 complete — avg loss: 1.1512 | ppl 3.16
# Epoch checkpoint saved → checkpoints_v4/epoch_41.pt
#
# ============================================================
# Epoch 42/40
# ============================================================
#
# [Epoch 42] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.8440 | avg 0.8440 | ppl 2.33 | lr 3.00e-04 | last 200 steps: 1.8s | total: 2s
#   step   200 | loss 1.2990 | avg 1.0159 | ppl 2.76 | lr 3.00e-04 | last 200 steps: 8.0s | total: 10s
#   Shard done — avg loss: 1.0646 | ppl 2.90
#
# Epoch 42 complete — avg loss: 1.0646 | ppl 2.90
# Epoch checkpoint saved → checkpoints_v4/epoch_42.pt
#
# ============================================================
# Epoch 43/40
# ============================================================
#
# [Epoch 43] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.7889 | avg 0.7889 | ppl 2.20 | lr 3.00e-04 | last 200 steps: 2.0s | total: 2s
#   step   200 | loss 1.0573 | avg 0.9722 | ppl 2.64 | lr 3.00e-04 | last 200 steps: 8.1s | total: 10s
#   Shard done — avg loss: 1.0244 | ppl 2.79
#
# Epoch 43 complete — avg loss: 1.0244 | ppl 2.79
# Epoch checkpoint saved → checkpoints_v4/epoch_43.pt
#
# ============================================================
# Epoch 44/40
# ============================================================
#
# [Epoch 44] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.8293 | avg 0.8293 | ppl 2.29 | lr 3.00e-04 | last 200 steps: 1.8s | total: 2s
#   step   200 | loss 1.0364 | avg 0.9346 | ppl 2.55 | lr 3.00e-04 | last 200 steps: 8.2s | total: 10s
#   Shard done — avg loss: 0.9785 | ppl 2.66
#
# Epoch 44 complete — avg loss: 0.9785 | ppl 2.66
# Epoch checkpoint saved → checkpoints_v4/epoch_44.pt
#
# ============================================================
# Epoch 45/40
# ============================================================
#
# [Epoch 45] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.6255 | avg 0.6255 | ppl 1.87 | lr 3.00e-04 | last 200 steps: 2.3s | total: 2s
#   step   200 | loss 1.0167 | avg 0.9029 | ppl 2.47 | lr 3.00e-04 | last 200 steps: 8.2s | total: 10s
#   Shard done — avg loss: 0.9459 | ppl 2.58
#
# Epoch 45 complete — avg loss: 0.9459 | ppl 2.58
# Epoch checkpoint saved → checkpoints_v4/epoch_45.pt
#
# ============================================================
# Epoch 46/40
# ============================================================
#
# [Epoch 46] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.7829 | avg 0.7829 | ppl 2.19 | lr 3.00e-04 | last 200 steps: 1.6s | total: 2s
#   step   200 | loss 1.0131 | avg 0.8651 | ppl 2.38 | lr 3.00e-04 | last 200 steps: 8.2s | total: 10s
#   Shard done — avg loss: 0.9099 | ppl 2.48
#
# Epoch 46 complete — avg loss: 0.9099 | ppl 2.48
# Epoch checkpoint saved → checkpoints_v4/epoch_46.pt
#
# ============================================================
# Epoch 47/40
# ============================================================
#
# [Epoch 47] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.6879 | avg 0.6879 | ppl 1.99 | lr 3.00e-04 | last 200 steps: 1.4s | total: 1s
#   step   200 | loss 1.0132 | avg 0.8328 | ppl 2.30 | lr 3.00e-04 | last 200 steps: 8.4s | total: 10s
#   Shard done — avg loss: 0.8774 | ppl 2.40
#
# Epoch 47 complete — avg loss: 0.8774 | ppl 2.40
# Epoch checkpoint saved → checkpoints_v4/epoch_47.pt
#
# ============================================================
# Epoch 48/40
# ============================================================
#
# [Epoch 48] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.5882 | avg 0.5882 | ppl 1.80 | lr 3.00e-04 | last 200 steps: 1.6s | total: 2s
#   step   200 | loss 0.9872 | avg 0.8002 | ppl 2.23 | lr 3.00e-04 | last 200 steps: 8.2s | total: 10s
#   Shard done — avg loss: 0.8506 | ppl 2.34
#
# Epoch 48 complete — avg loss: 0.8506 | ppl 2.34
# Epoch checkpoint saved → checkpoints_v4/epoch_48.pt
#
# ============================================================
# Epoch 49/40
# ============================================================
#
# [Epoch 49] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.5730 | avg 0.5730 | ppl 1.77 | lr 3.00e-04 | last 200 steps: 2.0s | total: 2s
#   step   200 | loss 0.8316 | avg 0.7679 | ppl 2.16 | lr 3.00e-04 | last 200 steps: 8.2s | total: 10s
#   Shard done — avg loss: 0.8200 | ppl 2.27
#
# Epoch 49 complete — avg loss: 0.8200 | ppl 2.27
# Epoch checkpoint saved → checkpoints_v4/epoch_49.pt
#
# ============================================================
# Epoch 50/40
# ============================================================
#
# [Epoch 50] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.7140 | avg 0.7140 | ppl 2.04 | lr 3.00e-04 | last 200 steps: 1.9s | total: 2s
#   step   200 | loss 0.8550 | avg 0.7485 | ppl 2.11 | lr 3.00e-04 | last 200 steps: 8.2s | total: 10s
#   Shard done — avg loss: 0.7907 | ppl 2.21
#
# Epoch 50 complete — avg loss: 0.7907 | ppl 2.21
# Epoch checkpoint saved → checkpoints_v4/epoch_50.pt
#
# ============================================================
# Epoch 51/40
# ============================================================
#
# [Epoch 51] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.6517 | avg 0.6517 | ppl 1.92 | lr 3.00e-04 | last 200 steps: 2.6s | total: 3s
#   step   200 | loss 0.8152 | avg 0.7227 | ppl 2.06 | lr 3.00e-04 | last 200 steps: 8.4s | total: 11s
#   Shard done — avg loss: 0.7695 | ppl 2.16
#
# Epoch 51 complete — avg loss: 0.7695 | ppl 2.16
# Epoch checkpoint saved → checkpoints_v4/epoch_51.pt
#
# ============================================================
# Epoch 52/40
# ============================================================
#
# [Epoch 52] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.5504 | avg 0.5504 | ppl 1.73 | lr 3.00e-04 | last 200 steps: 2.6s | total: 3s
#   step   200 | loss 0.7850 | avg 0.7059 | ppl 2.03 | lr 3.00e-04 | last 200 steps: 8.3s | total: 11s
#   Shard done — avg loss: 0.7459 | ppl 2.11
#
# Epoch 52 complete — avg loss: 0.7459 | ppl 2.11
# Epoch checkpoint saved → checkpoints_v4/epoch_52.pt
#
# ============================================================
# Epoch 53/40
# ============================================================
#
# [Epoch 53] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.5948 | avg 0.5948 | ppl 1.81 | lr 3.00e-04 | last 200 steps: 2.2s | total: 2s
#   step   200 | loss 0.7381 | avg 0.6797 | ppl 1.97 | lr 3.00e-04 | last 200 steps: 8.5s | total: 11s
#   Shard done — avg loss: 0.7186 | ppl 2.05
#
# Epoch 53 complete — avg loss: 0.7186 | ppl 2.05
# Epoch checkpoint saved → checkpoints_v4/epoch_53.pt
#
# ============================================================
# Epoch 54/40
# ============================================================
#
# [Epoch 54] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.5336 | avg 0.5336 | ppl 1.71 | lr 3.00e-04 | last 200 steps: 2.2s | total: 2s
#   step   200 | loss 0.7135 | avg 0.6607 | ppl 1.94 | lr 3.00e-04 | last 200 steps: 8.3s | total: 11s
#   Shard done — avg loss: 0.7017 | ppl 2.02
#
# Epoch 54 complete — avg loss: 0.7017 | ppl 2.02
# Epoch checkpoint saved → checkpoints_v4/epoch_54.pt
#
# ============================================================
# Epoch 55/40
# ============================================================
#
# [Epoch 55] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.5156 | avg 0.5156 | ppl 1.67 | lr 3.00e-04 | last 200 steps: 2.3s | total: 2s
#   step   200 | loss 0.7900 | avg 0.6379 | ppl 1.89 | lr 3.00e-04 | last 200 steps: 8.5s | total: 11s
#   Shard done — avg loss: 0.6789 | ppl 1.97
#
# Epoch 55 complete — avg loss: 0.6789 | ppl 1.97
# Epoch checkpoint saved → checkpoints_v4/epoch_55.pt
#
# ============================================================
# Epoch 56/40
# ============================================================
#
# [Epoch 56] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.4643 | avg 0.4643 | ppl 1.59 | lr 3.00e-04 | last 200 steps: 1.9s | total: 2s
#   step   200 | loss 0.7569 | avg 0.6195 | ppl 1.86 | lr 3.00e-04 | last 200 steps: 8.2s | total: 10s
#   Shard done — avg loss: 0.6570 | ppl 1.93
#
# Epoch 56 complete — avg loss: 0.6570 | ppl 1.93
# Epoch checkpoint saved → checkpoints_v4/epoch_56.pt
#
# ============================================================
# Epoch 57/40
# ============================================================
#
# [Epoch 57] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.4728 | avg 0.4728 | ppl 1.60 | lr 3.00e-04 | last 200 steps: 2.4s | total: 2s
#   step   200 | loss 0.7444 | avg 0.6009 | ppl 1.82 | lr 3.00e-04 | last 200 steps: 8.4s | total: 11s
#   Shard done — avg loss: 0.6421 | ppl 1.90
#
# Epoch 57 complete — avg loss: 0.6421 | ppl 1.90
# Epoch checkpoint saved → checkpoints_v4/epoch_57.pt
#
# ============================================================
# Epoch 58/40
# ============================================================
#
# [Epoch 58] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.4181 | avg 0.4181 | ppl 1.52 | lr 3.00e-04 | last 200 steps: 2.0s | total: 2s
#   step   200 | loss 0.6074 | avg 0.5799 | ppl 1.79 | lr 3.00e-04 | last 200 steps: 8.2s | total: 10s
#   Shard done — avg loss: 0.6174 | ppl 1.85
#
# Epoch 58 complete — avg loss: 0.6174 | ppl 1.85
# Epoch checkpoint saved → checkpoints_v4/epoch_58.pt
#
# ============================================================
# Epoch 59/40
# ============================================================
#
# [Epoch 59] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.4352 | avg 0.4352 | ppl 1.55 | lr 3.00e-04 | last 200 steps: 1.5s | total: 2s
#   step   200 | loss 0.7069 | avg 0.5696 | ppl 1.77 | lr 3.00e-04 | last 200 steps: 8.2s | total: 10s
#   Shard done — avg loss: 0.6034 | ppl 1.83
#
# Epoch 59 complete — avg loss: 0.6034 | ppl 1.83
# Epoch checkpoint saved → checkpoints_v4/epoch_59.pt
#
# ============================================================
# Epoch 60/40
# ============================================================
#
# [Epoch 60] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.3773 | avg 0.3773 | ppl 1.46 | lr 3.00e-04 | last 200 steps: 2.1s | total: 2s
#   step   200 | loss 0.6987 | avg 0.5534 | ppl 1.74 | lr 3.00e-04 | last 200 steps: 8.2s | total: 10s
#   Shard done — avg loss: 0.5925 | ppl 1.81
#
# Epoch 60 complete — avg loss: 0.5925 | ppl 1.81
# Epoch checkpoint saved → checkpoints_v4/epoch_60.pt
#
# ============================================================
# Epoch 61/40
# ============================================================
#
# [Epoch 61] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.4411 | avg 0.4411 | ppl 1.55 | lr 3.00e-04 | last 200 steps: 2.0s | total: 2s
#   step   200 | loss 0.6633 | avg 0.5330 | ppl 1.70 | lr 3.00e-04 | last 200 steps: 8.1s | total: 10s
#   Shard done — avg loss: 0.5711 | ppl 1.77
#
# Epoch 61 complete — avg loss: 0.5711 | ppl 1.77
# Epoch checkpoint saved → checkpoints_v4/epoch_61.pt
#
# ============================================================
# Epoch 62/40
# ============================================================
#
# [Epoch 62] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.3659 | avg 0.3659 | ppl 1.44 | lr 3.00e-04 | last 200 steps: 2.1s | total: 2s
#   step   200 | loss 0.6285 | avg 0.5236 | ppl 1.69 | lr 3.00e-04 | last 200 steps: 8.2s | total: 10s
#   Shard done — avg loss: 0.5613 | ppl 1.75
#
# Epoch 62 complete — avg loss: 0.5613 | ppl 1.75
# Epoch checkpoint saved → checkpoints_v4/epoch_62.pt
#
# ============================================================
# Epoch 63/40
# ============================================================
#
# [Epoch 63] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.3678 | avg 0.3678 | ppl 1.44 | lr 3.00e-04 | last 200 steps: 1.8s | total: 2s
#   step   200 | loss 0.5381 | avg 0.5204 | ppl 1.68 | lr 3.00e-04 | last 200 steps: 8.2s | total: 10s
#   Shard done — avg loss: 0.5516 | ppl 1.74
#
# Epoch 63 complete — avg loss: 0.5516 | ppl 1.74
# Epoch checkpoint saved → checkpoints_v4/epoch_63.pt
#
# ============================================================
# Epoch 64/40
# ============================================================
#
# [Epoch 64] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.4471 | avg 0.4471 | ppl 1.56 | lr 3.00e-04 | last 200 steps: 2.3s | total: 2s
#   step   200 | loss 0.6354 | avg 0.5027 | ppl 1.65 | lr 3.00e-04 | last 200 steps: 8.2s | total: 11s
#   Shard done — avg loss: 0.5376 | ppl 1.71
#
# Epoch 64 complete — avg loss: 0.5376 | ppl 1.71
# Epoch checkpoint saved → checkpoints_v4/epoch_64.pt
#
# ============================================================
# Epoch 65/40
# ============================================================
#
# [Epoch 65] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.3085 | avg 0.3085 | ppl 1.36 | lr 3.00e-04 | last 200 steps: 1.9s | total: 2s
#   step   200 | loss 0.5639 | avg 0.4901 | ppl 1.63 | lr 3.00e-04 | last 200 steps: 8.2s | total: 10s
#   Shard done — avg loss: 0.5261 | ppl 1.69
#
# Epoch 65 complete — avg loss: 0.5261 | ppl 1.69
# Epoch checkpoint saved → checkpoints_v4/epoch_65.pt
#
# ============================================================
# Epoch 66/40
# ============================================================
#
# [Epoch 66] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.4029 | avg 0.4029 | ppl 1.50 | lr 3.00e-04 | last 200 steps: 2.0s | total: 2s
#   step   200 | loss 0.5591 | avg 0.4746 | ppl 1.61 | lr 3.00e-04 | last 200 steps: 8.4s | total: 10s
#   Shard done — avg loss: 0.5076 | ppl 1.66
#
# Epoch 66 complete — avg loss: 0.5076 | ppl 1.66
# Epoch checkpoint saved → checkpoints_v4/epoch_66.pt
#
# ============================================================
# Epoch 67/40
# ============================================================
#
# [Epoch 67] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.3827 | avg 0.3827 | ppl 1.47 | lr 3.00e-04 | last 200 steps: 1.9s | total: 2s
#   step   200 | loss 0.5992 | avg 0.4601 | ppl 1.58 | lr 3.00e-04 | last 200 steps: 8.2s | total: 10s
#   Shard done — avg loss: 0.4963 | ppl 1.64
#
# Epoch 67 complete — avg loss: 0.4963 | ppl 1.64
# Epoch checkpoint saved → checkpoints_v4/epoch_67.pt
#
# ============================================================
# Epoch 68/40
# ============================================================
#
# [Epoch 68] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.3779 | avg 0.3779 | ppl 1.46 | lr 3.00e-04 | last 200 steps: 1.7s | total: 2s
#   step   200 | loss 0.5335 | avg 0.4563 | ppl 1.58 | lr 3.00e-04 | last 200 steps: 8.3s | total: 10s
#   Shard done — avg loss: 0.4912 | ppl 1.63
#
# Epoch 68 complete — avg loss: 0.4912 | ppl 1.63
# Epoch checkpoint saved → checkpoints_v4/epoch_68.pt
#
# ============================================================
# Epoch 69/40
# ============================================================
#
# [Epoch 69] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.3365 | avg 0.3365 | ppl 1.40 | lr 3.00e-04 | last 200 steps: 1.8s | total: 2s
#   step   200 | loss 0.5496 | avg 0.4473 | ppl 1.56 | lr 3.00e-04 | last 200 steps: 8.2s | total: 10s
#   Shard done — avg loss: 0.4793 | ppl 1.61
#
# Epoch 69 complete — avg loss: 0.4793 | ppl 1.61
# Epoch checkpoint saved → checkpoints_v4/epoch_69.pt
#
# ============================================================
# Epoch 70/40
# ============================================================
#
# [Epoch 70] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.3083 | avg 0.3083 | ppl 1.36 | lr 3.00e-04 | last 200 steps: 2.6s | total: 3s
#   step   200 | loss 0.5129 | avg 0.4379 | ppl 1.55 | lr 3.00e-04 | last 200 steps: 8.3s | total: 11s
#   Shard done — avg loss: 0.4696 | ppl 1.60
#
# Epoch 70 complete — avg loss: 0.4696 | ppl 1.60
# Epoch checkpoint saved → checkpoints_v4/epoch_70.pt
#
# ============================================================
# Epoch 71/40
# ============================================================
#
# [Epoch 71] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.3165 | avg 0.3165 | ppl 1.37 | lr 3.00e-04 | last 200 steps: 1.9s | total: 2s
#   step   200 | loss 0.5395 | avg 0.4307 | ppl 1.54 | lr 3.00e-04 | last 200 steps: 8.2s | total: 10s
#   Shard done — avg loss: 0.4619 | ppl 1.59
#
# Epoch 71 complete — avg loss: 0.4619 | ppl 1.59
# Epoch checkpoint saved → checkpoints_v4/epoch_71.pt
#
# ============================================================
# Epoch 72/40
# ============================================================
#
# [Epoch 72] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.3600 | avg 0.3600 | ppl 1.43 | lr 3.00e-04 | last 200 steps: 2.1s | total: 2s
#   step   200 | loss 0.5009 | avg 0.4326 | ppl 1.54 | lr 3.00e-04 | last 200 steps: 8.3s | total: 10s
#   Shard done — avg loss: 0.4610 | ppl 1.59
#
# Epoch 72 complete — avg loss: 0.4610 | ppl 1.59
# Epoch checkpoint saved → checkpoints_v4/epoch_72.pt
#
# ============================================================
# Epoch 73/40
# ============================================================
#
# [Epoch 73] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.3197 | avg 0.3197 | ppl 1.38 | lr 3.00e-04 | last 200 steps: 1.9s | total: 2s
#   step   200 | loss 0.5126 | avg 0.4102 | ppl 1.51 | lr 3.00e-04 | last 200 steps: 8.2s | total: 10s
#   Shard done — avg loss: 0.4428 | ppl 1.56
#
# Epoch 73 complete — avg loss: 0.4428 | ppl 1.56
# Epoch checkpoint saved → checkpoints_v4/epoch_73.pt
#
# ============================================================
# Epoch 74/40
# ============================================================
#
# [Epoch 74] Shard 1/1 — shard_0000.pt
#   step     0 | loss 0.2659 | avg 0.2659 | ppl 1.30 | lr 3.00e-04 | last 200 steps: 2.0s | total: 2s
#   step   200 | loss 0.5189 | avg 0.4102 | ppl 1.51 | lr 3.00e-04 | last 200 steps: 8.3s | total: 10s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 89
#      81     loss   = F.cross_entropy(
#      82         logits.view(-1, logits.size(-1)),
#      83         y.view(-1),
#      84         ignore_index=-100,
#      85     )
#      86     del logits  # free 268MB immediately before backward
# ---> 89 scaler.scale(loss).backward()
#      90 scaler.unscale_(optimizer)
#      91 torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
#
# File ~/.local/lib/python3.10/site-packages/torch/_tensor.py:631, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     621 if has_torch_function_unary(self):
#     622     return handle_torch_function(
#     623         Tensor.backward,
#     624         (self,),
#    (...)
#     629         inputs=inputs,
#     630     )
# --> 631 torch.autograd.backward(
#     632     self, gradient, retain_graph, create_graph, inputs=inputs
#     633 )
#
# File ~/.local/lib/python3.10/site-packages/torch/autograd/__init__.py:381, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     376     retain_graph = create_graph
#     378 # The reason we repeat the same comment below is that
#     379 # some Python versions print out the first line of a multi-line function
#     380 # calls in the traceback and some print out the last line
# --> 381 _engine_run_backward(
#     382     tensors,
#     383     grad_tensors_,
#     384     retain_graph,
#     385     create_graph,
#     386     inputs_tuple,
#     387     allow_unreachable=True,
#     388     accumulate_grad=True,
#     389 )
#
# File ~/.local/lib/python3.10/site-packages/torch/autograd/graph.py:869, in _engine_run_backward(t_outputs, *args, **kwargs)
#     867     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     868 try:
# --> 869     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     870         t_outputs, *args, **kwargs
#     871     )  # Calls into the C++ engine to run the backward pass
#     872 finally:
#     873     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
model.to("cuda")
1
# Out:
# 1

# %%
# ── Inference ─────────────────────────────────────────────────────────────────
from tokenizers import Tokenizer

tok = Tokenizer.from_file(TOK_DIR+"tokenizer.json")

# Special token IDs
BOS_ID       = 2
EOS_ID       = 3
USER_ID      = 5
ASSISTANT_ID = 6

SPECIAL_IDS = set()  # 0-49, all special tokens
MAX_SEQ = 2048
def generate(prompt, max_new_tokens=200, temperature=0.8, top_k=1, mode="text"):
    ids = tok.encode(prompt).ids

    if mode == "text":
        ids = [BOS_ID] + ids
    elif mode == "chat":
        ids = [BOS_ID, USER_ID] + ids + [ASSISTANT_ID]

    x = torch.tensor([ids], dtype=torch.long).to(device)

    with torch.no_grad():
        for _ in range(max_new_tokens):
            logits = model(x[:, -MAX_SEQ:])
            logits = logits[:, -1, :] / temperature
            top_vals, top_idx = torch.topk(logits, top_k)
            probs   = torch.softmax(top_vals, dim=-1)
            next_id = top_idx[0][torch.multinomial(probs, 1)]
            x = torch.cat([x, next_id.view(1, 1)], dim=1)
            if next_id.item() == EOS_ID:
                break

    # manually filter special token IDs before decoding
    clean_ids = [t for t in x[0].tolist() if t not in SPECIAL_IDS]
    return tok.decode(clean_ids)

# ── Text generation prompts ───────────────────────────────────────────────────

text_prompts = [
    "Want Tori to Coach You Too?",
]

print("=" * 60)
print("TEXT GENERATION MODE")
print("=" * 60)
for prompt in text_prompts:
    print(f"\nPrompt : {prompt}")
    print(f"Output : {generate(prompt, mode='chat')}")
# Out:
# ============================================================
# TEXT GENERATION MODE
# ============================================================
#
# Prompt : Want Tori to Coach You Too?
# Output : Want Tori to Coach You Too?s justan ass fromombian Surround Ciel and notahiliary, in both houses of Degrants.
# By allowing the Stellants to the Law, therees, the upsex marzones of the Second Worlds, shahie We know all that we must gize ourselves in your community and will missouly be a threat to these are passionate. Will we find us in that discour country with well-wing, but we must not forget in a span.
# And on September 11thING these are privilege and self-yarnie Institute will perform a new Year old grand Mayor maytoyla bigluke Reiterary to repat their dreamed their fundamental things. But may they pay the time igning them, as well.
# Cited "Stowenough to Invest in the world and it's a helical truth-."
# The only system that the ankeys

# %%
ds     = ShardDataset(shard_path)
ds

# %%
tok.decode(ds.flat[:20].tolist())
# Out:
# "Want Tori to Coach You Too?\nTori's Health Step by"

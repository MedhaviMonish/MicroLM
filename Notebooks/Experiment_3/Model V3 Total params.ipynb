# %%
import torch
import torch.nn as nn
import numpy as np
import math
import time

# Load frozen embedding table
embedding_table = np.load("tokenizer/token_embeddings.npy")
embedding_tensor = torch.tensor(embedding_table, dtype=torch.float32)

VOCAB_SIZE    = embedding_tensor.shape[0]   # 4096
MINILM_DIM    = embedding_tensor.shape[1]   # 384
print(f"Vocab size : {VOCAB_SIZE}")
print(f"MiniLM dim : {MINILM_DIM}")

# %%
import torch.nn.functional as F 

DIM      = 384
N_HEADS  = 16
N_LAYERS = 2
FFN_DIM  = 768
HEAD_DIM = DIM // N_HEADS 

def sinusoidal_encoding(seq_len, dim, device):
    pe       = torch.zeros(seq_len, dim, device=device)
    position = torch.arange(seq_len, device=device).unsqueeze(1)
    div_term = torch.exp(torch.arange(0, dim, 2, device=device) * (-math.log(10000.0) / dim))
    pe[:, 0::2] = torch.sin(position * div_term)
    pe[:, 1::2] = torch.cos(position * div_term)
    return pe  # (seq_len, dim)

class LayerNorm(nn.Module):
    """
    y = ((x - mean) / sqrt(var + eps)) * gamma + beta
    gamma, beta are learned per-feature scalars — shape (dim,)
    """
    def __init__(self, dim, eps=1e-5):
        super().__init__()
        self.eps   = eps
        self.gamma = nn.Parameter(torch.ones(dim))   # scale
        self.beta  = nn.Parameter(torch.zeros(dim))  # shift

    def forward(self, x):
        mean = x.mean(dim=-1, keepdim=True)           # (B, T, 1)
        var  = x.var(dim=-1, keepdim=True, unbiased=False)  # (B, T, 1)
        x_norm = (x - mean) / torch.sqrt(var + self.eps)    # (B, T, D)
        return self.gamma * x_norm + self.beta               # (B, T, D)

class MultiHeadCausalAttention(nn.Module):
    """
    Projects input into Q, K, V — splits into H heads — computes scaled
    dot-product attention with a causal mask — concatenates heads — projects out.

    Q = x W_q      shape: (B, T, D)
    K = x W_k      shape: (B, T, D)
    V = x W_v      shape: (B, T, D)

    Reshape to (B, H, T, head_dim), then:
        scores = Q @ Kᵀ / sqrt(head_dim)    (B, H, T, T)
        scores = scores + causal_mask        (upper triangle = -inf)
        weights = softmax(scores, dim=-1)    (B, H, T, T)
        out = weights @ V                    (B, H, T, head_dim)

    Concat heads → (B, T, D), project out via W_o
    """
    def __init__(self, dim, n_heads, dropout=0.0):
        super().__init__()
        assert dim % n_heads == 0, "dim must be divisible by n_heads"
        self.n_heads  = n_heads
        self.head_dim = dim // n_heads       # 48
        self.scale    = self.head_dim ** -0.5

        self.W_q = nn.Linear(dim, dim, bias=False)
        self.W_k = nn.Linear(dim, dim, bias=False)
        self.W_v = nn.Linear(dim, dim, bias=False)
        self.W_o = nn.Linear(dim, dim, bias=False)

        self.attn_drop = nn.Dropout(dropout)

    def forward(self, x):
        B, T, D = x.shape

        # --- Project & split into heads ---
        Q = self.W_q(x)  # (B, T, D)
        K = self.W_k(x)  # (B, T, D)
        V = self.W_v(x)  # (B, T, D)

        # Reshape: (B, T, D) → (B, H, T, head_dim)
        Q = Q.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)
        K = K.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)
        V = V.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)

        # --- Scaled dot-product attention ---
        # (B, H, T, head_dim) @ (B, H, head_dim, T) → (B, H, T, T)
        scores = (Q @ K.transpose(-2, -1)) * self.scale

        # Causal mask: positions can only attend to themselves and earlier tokens
        # Upper triangle (future tokens) set to -inf → softmax drives them to 0
        causal_mask = torch.triu(
            torch.ones(T, T, device=x.device, dtype=torch.bool), diagonal=1
        )
        scores = scores.masked_fill(causal_mask, float('-inf'))

        weights = torch.softmax(scores, dim=-1)  # (B, H, T, T)
        weights = self.attn_drop(weights)

        # (B, H, T, T) @ (B, H, T, head_dim) → (B, H, T, head_dim)
        out = weights @ V

        # --- Concat heads & project ---
        # (B, H, T, head_dim) → (B, T, H*head_dim) = (B, T, D)
        out = out.transpose(1, 2).contiguous().view(B, T, D)
        return self.W_o(out)  # (B, T, D)

class FeedForward(nn.Module):
    """
    Two-layer MLP with GELU activation.
    FFN(x) = GELU(x W_1 + b_1) W_2 + b_2

    Expands dim → ffn_dim (wider representation),
    then projects back down ffn_dim → dim.
    """
    def __init__(self, dim, ffn_dim, dropout=0.0):
        super().__init__()
        self.W_1 = nn.Linear(dim, ffn_dim)       # expand
        self.W_2 = nn.Linear(ffn_dim, ffn_dim)       # maintain
        self.W_3 = nn.Linear(ffn_dim, dim)       # contract
        self.drop = nn.Dropout(dropout)

    def forward(self, x):
        x = F.gelu(self.W_1(x))   # (B, T, ffn_dim)
        x = self.drop(x)
        x = F.gelu(self.W_2(x))   
        x = self.drop(x)
        x = self.W_3(x)           # (B, T, dim)
        return x

class TransformerBlock(nn.Module):
    """
    Pre-norm residual block (norm_first=True, same as your original config).

    x = x + Attention(LayerNorm(x))   ← self-attention sub-layer
    x = x + FFN(LayerNorm(x))         ← feed-forward sub-layer

    Pre-norm (LN before the sub-layer) stabilises training at depth
    vs post-norm (LN after the residual add).
    """
    def __init__(self, dim, n_heads, ffn_dim, dropout=0.0):
        super().__init__()
        self.norm_1 = LayerNorm(dim)
        self.attn   = MultiHeadCausalAttention(dim, n_heads, dropout)
        self.norm_2 = LayerNorm(dim)
        self.ffn    = FeedForward(dim, ffn_dim, dropout)
        self.drop   = nn.Dropout(dropout)

    def forward(self, x):
        x = x + self.drop(self.attn(self.norm_1(x)))  # (B, T, D)
        x = x + self.drop(self.ffn(self.norm_2(x)))   # (B, T, D)
        return x

class MicroLM(nn.Module):
    """
    Full architecture:
      1. Frozen MiniLM embedding lookup         → (B, T, 384)
      2. Sinusoidal positional encoding added   → (B, T, 384)
      3. N_LAYERS x TransformerBlock            → (B, T, 384)
      4. Final LayerNorm                        → (B, T, 384)
      5. Linear output head → logits            → (B, T, VOCAB_SIZE)
    """
    def __init__(self):
        super().__init__()
        self.register_buffer("embedding_table", embedding_tensor)

        self.blocks = nn.ModuleList([
            TransformerBlock(DIM, N_HEADS, FFN_DIM, dropout=0.0)
            for _ in range(N_LAYERS)
        ])

        self.norm        = LayerNorm(DIM)
        self.output_head = nn.Linear(DIM, VOCAB_SIZE, bias=False)

    def forward(self, token_ids):
        B, T = token_ids.shape

        x = self.embedding_table[token_ids]                    # (B, T, 384)
        x = x + sinusoidal_encoding(T, DIM, token_ids.device) # (B, T, 384)

        for block in self.blocks:
            x = block(x)   # (B, T, 384)

        x = self.norm(x)
        return self.output_head(x)  # (B, T, VOCAB_SIZE)

# %%
model     = MicroLM()
total     = sum(p.numel() for p in model.parameters())
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
frozen    = total - trainable

print(f"Trainable params : {trainable:,}")
print(f"Frozen params    : {frozen:,}  (embedding table)")
print(f"Total params     : {total:,}")

# print(f"\nParam breakdown:")
# for name, p in model.named_parameters():
#     if p.requires_grad:
#         print(f"  {name:55s} {p.numel():>10,}")

# Forward pass
x      = torch.randint(0, VOCAB_SIZE, (2, 32))
logits = model(x)
print(f"\nInput  : {x.shape}")
print(f"Output : {logits.shape}")
# Out:
# Trainable params : 9,838,080
# Frozen params    : 0  (embedding table)
# Total params     : 9,838,080
#
# Input  : torch.Size([2, 32])
# Output : torch.Size([2, 32, 16384])

# %%
model
# Out:
# MicroLM(
#   (blocks): ModuleList(
#     (0-1): 2 x TransformerBlock(
#       (norm_1): LayerNorm()
#       (attn): MultiHeadCausalAttention(
#         (W_q): Linear(in_features=384, out_features=384, bias=False)
#         (W_k): Linear(in_features=384, out_features=384, bias=False)
#         (W_v): Linear(in_features=384, out_features=384, bias=False)
#         (W_o): Linear(in_features=384, out_features=384, bias=False)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#       )
#       (norm_2): LayerNorm()
#       (ffn): FeedForward(
#         (W_1): Linear(in_features=384, out_features=768, bias=True)
#         (W_2): Linear(in_features=768, out_features=768, bias=True)
#         (W_3): Linear(in_features=768, out_features=384, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (norm): LayerNorm()
#   (output_head): Linear(in_features=384, out_features=16384, bias=False)
# )

# %%
# ── Training Config ───────────────────────────────────────────────────────────
import gc
import json
import random
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from pathlib import Path

SHARD_DIR  = Path("dataset_shards")
SEQ_LEN    = 512
BATCH_SIZE = 32
N_EPOCHS   = 10
LOG_EVERY  = 200
CKPT_DIR   = Path("checkpoints_v3")
CKPT_DIR.mkdir(parents=True, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device      : {device}")
print(f"Model params: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# Device      : cuda
# Model params: 9,838,080

# %%
from torch.utils.data import Dataset

SEQ_LEN = 512    # window size
STRIDE  = 448    # step size → 64-token overlap

class ShardDataset(Dataset):
    def __init__(self, shard_path, seq_len=SEQ_LEN, stride=STRIDE):
        flat = torch.load(shard_path, weights_only=True)

        self.flat    = flat.to(torch.int16)
        self.seq_len = seq_len
        self.stride  = stride

        # number of full windows we can extract
        # +1 because we need seq_len+1 tokens (x + y target)
        n_tokens = len(self.flat)
        self.num_samples = max(0, (n_tokens - seq_len - 1) // stride + 1)

    def __len__(self):
        return self.num_samples

    def __getitem__(self, idx):
        start  = idx * self.stride
        tokens = self.flat[start : start + self.seq_len + 1].to(torch.long)  # ← cast here
        
        if len(tokens) < self.seq_len + 1:
            pad    = torch.full((self.seq_len + 1 - len(tokens),), PAD_ID, dtype=torch.long)
            tokens = torch.cat([tokens, pad])

        x = tokens[:-1]
        y = tokens[1:]
        return x, y


BOS_ID       = 2
EOS_ID       = 3

def collate_fn(batch):
    xs, ys = zip(*batch)
    # all samples are now fixed-length (seq_len), so no padding needed here
    x_pad = torch.stack(xs)          # [B, seq_len]
    y_pad = torch.stack(ys).clone()  # [B, seq_len]

    # mask out targets after the first EOS in each sequence
    for i, y in enumerate(y_pad):
        eos_positions = (y == EOS_ID).nonzero(as_tuple=True)[0]
        if len(eos_positions) > 0:
            eos_pos = eos_positions[0].item()
            if eos_pos + 1 < y.size(0):
                y_pad[i, eos_pos + 1:] = -100

    return x_pad, y_pad

# %%
# run once after sharding
meta = {
    "total_samples": sum(len(ShardDataset(p)) for p in sorted(SHARD_DIR.glob("shard_*.pt"))[:1]),
    "seq_len": SEQ_LEN,
    "stride": STRIDE,
}
with open(SHARD_DIR / "meta.json", "w") as f:
    json.dump(meta, f, indent=2)
    
# ── Optimizer & Scheduler ─────────────────────────────────────────────────────

with open(SHARD_DIR / "meta.json") as f:
    meta = json.load(f)

total_steps = (meta['total_samples'] // BATCH_SIZE) * N_EPOCHS

optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=total_steps, eta_min=1e-5
)
scaler    = torch.cuda.amp.GradScaler()

print(f"Total samples: {meta['total_samples']:,}")
print(f"Total steps  : {total_steps:,}")
# Out:
# Total samples: 599,187
# Total steps  : 187,240
# C:\Users\Medhavi Monish\AppData\Local\Temp\ipykernel_30964\2774204176.py:21: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler    = torch.cuda.amp.GradScaler()

# %%
model.to(device)
# Out:
# MicroLM(
#   (blocks): ModuleList(
#     (0-1): 2 x TransformerBlock(
#       (norm_1): LayerNorm()
#       (attn): MultiHeadCausalAttention(
#         (W_q): Linear(in_features=384, out_features=384, bias=False)
#         (W_k): Linear(in_features=384, out_features=384, bias=False)
#         (W_v): Linear(in_features=384, out_features=384, bias=False)
#         (W_o): Linear(in_features=384, out_features=384, bias=False)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#       )
#       (norm_2): LayerNorm()
#       (ffn): FeedForward(
#         (W_1): Linear(in_features=384, out_features=768, bias=True)
#         (W_2): Linear(in_features=768, out_features=768, bias=True)
#         (W_3): Linear(in_features=768, out_features=384, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (norm): LayerNorm()
#   (output_head): Linear(in_features=384, out_features=16384, bias=False)
# )

# %%
shard_files  = sorted(SHARD_DIR.glob("shard_*.pt"))[:1]
shard_files
# Out:
# [WindowsPath('dataset_shards/shard_0000.pt')]

# %%
# ── Training Loop with Resume ─────────────────────────────────────────────────
import math

shard_files  = sorted(SHARD_DIR.glob("shard_*.pt"))[:1]
loss_history = []
start_epoch  = 0
start_shard  = 0

# ── Resume from latest checkpoint ────────────────────────────────────────────
# Check mid-epoch checkpoints first, then epoch checkpoints
all_ckpts = sorted(CKPT_DIR.glob("epoch_*.pt"))
epoch_ckpts = [c for c in all_ckpts if "shard" not in c.name]

if epoch_ckpts:
    latest = epoch_ckpts[-1]
    print(f"Resuming from epoch checkpoint {latest}...")
    ckpt = torch.load(latest, map_location=device)
    model.load_state_dict(ckpt["model"])
    optimizer.load_state_dict(ckpt["optimizer"])
    scheduler.load_state_dict(ckpt["scheduler"])
    loss_history = ckpt.get("loss_history", [])
    start_epoch  = ckpt["epoch"]            # full epoch completed
    start_shard  = 0                        # start from beginning of next epoch
    print(f"Resumed — starting from epoch {start_epoch+1}")

else:
    print("No checkpoint found — training from scratch")

optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4)
model.to(device)
model.train()

for epoch in range(start_epoch, N_EPOCHS):
    epoch_loss  = 0.0
    epoch_steps = 0

    # no shuffle — sequential shard order
    shard_order = list(range(len(shard_files)))

    # if resuming mid-epoch, skip already completed shards
    if epoch == start_epoch and start_shard > 0:
        shard_order = shard_order[start_shard:]
        print(f"Skipping shards 0-{start_shard-1}, resuming from shard {start_shard}")

    print(f"\n{'='*60}")
    print(f"Epoch {epoch+1}/{N_EPOCHS}")
    print(f"{'='*60}")

    for shard_num, shard_idx in enumerate(shard_order):
        # just before the step loop:
        shard_start = time.time()
        interval_start = time.time()
        
        # actual shard number in epoch (accounts for skipped shards on resume)
        actual_shard_num = shard_idx  

        shard_path = shard_files[shard_idx]
        print(f"\n[Epoch {epoch+1}] Shard {actual_shard_num+1}/{len(shard_files)} — {shard_path.name}")

        ds     = ShardDataset(shard_path)
        loader = DataLoader(
            ds,
            batch_size=BATCH_SIZE,
            shuffle=True,
            collate_fn=collate_fn,
            num_workers=0,
            pin_memory=True,
        )

        shard_loss  = 0.0
        shard_steps = 0

        for step, (x, y) in enumerate(loader):
            x = x.to(device)
            y = y.to(device)

            optimizer.zero_grad()

            with torch.autocast(device_type="cuda", dtype=torch.bfloat16):
                logits = model(x)
                loss   = F.cross_entropy(
                    logits.view(-1, logits.size(-1)),
                    y.view(-1),
                    ignore_index=-100,
                )
                del logits  # free 268MB immediately before backward


            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            scaler.step(optimizer)
            scaler.update()

            if not math.isnan(loss.item()):
                shard_loss  += loss.item()
                shard_steps += 1
                epoch_loss  += loss.item()
                epoch_steps += 1

            if step % LOG_EVERY == 0:
                # scheduler.step()
                avg = shard_loss / max(shard_steps, 1)
                ppl = math.exp(min(avg, 20))
                lr  = scheduler.get_last_lr()[0]
                elapsed_total = time.time() - shard_start
                interval_time = time.time() - interval_start
                print(f"  step {step:>5} | loss {loss.item():.4f} | avg {avg:.4f} | ppl {ppl:.2f} | lr {lr:.2e} | last {LOG_EVERY} steps: {interval_time:.1f}s | total: {elapsed_total:.0f}s")
                interval_start = time.time()  # reset for next interval

            del loss, x, y
        shard_avg = shard_loss / max(shard_steps, 1)
        shard_ppl = math.exp(min(shard_avg, 20))
        loss_history.append({
            "epoch":      epoch + 1,
            "shard":      actual_shard_num,
            "avg_loss":   shard_avg,
            "perplexity": shard_ppl,
        })
        print(f"  Shard done — avg loss: {shard_avg:.4f} | ppl {shard_ppl:.2f}")

        del ds, loader
        gc.collect()
        torch.cuda.empty_cache()

    # reset start_shard after first resumed epoch
    start_shard = 0

    epoch_avg = epoch_loss / max(epoch_steps, 1)
    epoch_ppl = math.exp(min(epoch_avg, 20))
    print(f"\nEpoch {epoch+1} complete — avg loss: {epoch_avg:.4f} | ppl {epoch_ppl:.2f}")

    ckpt_path = CKPT_DIR / f"epoch_{epoch+1}.pt"
    torch.save({
        "epoch":        epoch + 1,
        "shard":        -1,
        "model":        model.state_dict(),
        "optimizer":    optimizer.state_dict(),
        "scheduler":    scheduler.state_dict(),
        "loss_history": loss_history,
    }, ckpt_path)
    print(f"Epoch checkpoint saved → {ckpt_path}")

    with open(CKPT_DIR / "loss_history.json", "w") as f:
        json.dump(loss_history, f, indent=2)

print("\nTraining complete.")
# Out:
# Resuming from epoch checkpoint checkpoints_v3\epoch_1.pt...
# Resumed — starting from epoch 2
#
# ============================================================
# Epoch 2/10
# ============================================================
#
# [Epoch 2] Shard 1/1 — shard_0000.pt
#   step     0 | loss 5.0039 | avg 5.0039 | ppl 149.00 | lr 3.00e-04 | last 200 steps: 0.4s | total: 0s
#   step   200 | loss 4.9104 | avg 5.0346 | ppl 153.64 | lr 3.00e-04 | last 200 steps: 21.6s | total: 22s
#   step   400 | loss 4.9213 | avg 4.9997 | ppl 148.37 | lr 3.00e-04 | last 200 steps: 21.3s | total: 43s
#   step   600 | loss 4.9763 | avg 4.9900 | ppl 146.94 | lr 3.00e-04 | last 200 steps: 21.2s | total: 65s
#   step   800 | loss 4.9854 | avg 4.9847 | ppl 146.16 | lr 3.00e-04 | last 200 steps: 20.9s | total: 85s
#   step  1000 | loss 4.9007 | avg 4.9792 | ppl 145.36 | lr 3.00e-04 | last 200 steps: 20.9s | total: 106s
#   step  1200 | loss 4.9451 | avg 4.9757 | ppl 144.85 | lr 3.00e-04 | last 200 steps: 20.9s | total: 127s
#   step  1400 | loss 4.9698 | avg 4.9731 | ppl 144.48 | lr 3.00e-04 | last 200 steps: 20.9s | total: 148s
#   step  1600 | loss 5.0513 | avg 4.9702 | ppl 144.06 | lr 3.00e-04 | last 200 steps: 20.9s | total: 169s
#   step  1800 | loss 4.9987 | avg 4.9681 | ppl 143.75 | lr 3.00e-04 | last 200 steps: 20.9s | total: 190s
#   step  2000 | loss 4.8784 | avg 4.9662 | ppl 143.48 | lr 3.00e-04 | last 200 steps: 21.0s | total: 211s
#   step  2200 | loss 4.7798 | avg 4.9645 | ppl 143.24 | lr 3.00e-04 | last 200 steps: 20.9s | total: 232s
#   step  2400 | loss 4.9369 | avg 4.9628 | ppl 142.99 | lr 3.00e-04 | last 200 steps: 20.9s | total: 253s
#   step  2600 | loss 4.9375 | avg 4.9601 | ppl 142.61 | lr 3.00e-04 | last 200 steps: 21.0s | total: 274s
#   step  2800 | loss 4.8489 | avg 4.9575 | ppl 142.24 | lr 3.00e-04 | last 200 steps: 20.9s | total: 295s
#   step  3000 | loss 4.9208 | avg 4.9556 | ppl 141.96 | lr 3.00e-04 | last 200 steps: 20.9s | total: 316s
#   step  3200 | loss 4.9222 | avg 4.9538 | ppl 141.71 | lr 3.00e-04 | last 200 steps: 20.9s | total: 337s
#   step  3400 | loss 4.8709 | avg 4.9525 | ppl 141.54 | lr 3.00e-04 | last 200 steps: 20.9s | total: 358s
#   step  3600 | loss 4.9083 | avg 4.9503 | ppl 141.21 | lr 3.00e-04 | last 200 steps: 20.9s | total: 378s
#   step  3800 | loss 4.8907 | avg 4.9491 | ppl 141.05 | lr 3.00e-04 | last 200 steps: 20.9s | total: 399s
#   step  4000 | loss 4.8859 | avg 4.9479 | ppl 140.87 | lr 3.00e-04 | last 200 steps: 20.9s | total: 420s
#   step  4200 | loss 4.6870 | avg 4.9462 | ppl 140.63 | lr 3.00e-04 | last 200 steps: 20.9s | total: 441s
#   step  4400 | loss 4.8126 | avg 4.9449 | ppl 140.46 | lr 3.00e-04 | last 200 steps: 20.9s | total: 462s
#   step  4600 | loss 4.7703 | avg 4.9428 | ppl 140.17 | lr 3.00e-04 | last 200 steps: 20.9s | total: 483s
#   step  4800 | loss 4.9530 | avg 4.9414 | ppl 139.96 | lr 3.00e-04 | last 200 steps: 20.9s | total: 504s
#   step  5000 | loss 4.9914 | avg 4.9400 | ppl 139.77 | lr 3.00e-04 | last 200 steps: 20.9s | total: 525s
#   step  5200 | loss 4.9717 | avg 4.9384 | ppl 139.55 | lr 3.00e-04 | last 200 steps: 21.0s | total: 546s
#   step  5400 | loss 4.8300 | avg 4.9368 | ppl 139.32 | lr 3.00e-04 | last 200 steps: 21.0s | total: 567s
#   step  5600 | loss 4.9341 | avg 4.9356 | ppl 139.16 | lr 3.00e-04 | last 200 steps: 20.9s | total: 588s
#   step  5800 | loss 4.8672 | avg 4.9345 | ppl 139.00 | lr 3.00e-04 | last 200 steps: 20.8s | total: 609s
#   step  6000 | loss 4.8405 | avg 4.9331 | ppl 138.81 | lr 3.00e-04 | last 200 steps: 20.9s | total: 629s
#   step  6200 | loss 4.8045 | avg 4.9313 | ppl 138.56 | lr 3.00e-04 | last 200 steps: 20.9s | total: 650s
#   step  6400 | loss 4.8384 | avg 4.9300 | ppl 138.38 | lr 3.00e-04 | last 200 steps: 20.9s | total: 671s
#   step  6600 | loss 4.8329 | avg 4.9284 | ppl 138.16 | lr 3.00e-04 | last 200 steps: 20.9s | total: 692s
#   step  6800 | loss 4.8646 | avg 4.9270 | ppl 137.96 | lr 3.00e-04 | last 200 steps: 20.9s | total: 713s
#   step  7000 | loss 4.8920 | avg 4.9252 | ppl 137.71 | lr 3.00e-04 | last 200 steps: 20.9s | total: 734s
#   step  7200 | loss 4.9902 | avg 4.9240 | ppl 137.56 | lr 3.00e-04 | last 200 steps: 20.9s | total: 755s
#   step  7400 | loss 4.8897 | avg 4.9226 | ppl 137.36 | lr 3.00e-04 | last 200 steps: 20.9s | total: 776s
#   step  7600 | loss 4.8345 | avg 4.9209 | ppl 137.12 | lr 3.00e-04 | last 200 steps: 20.9s | total: 796s
#   step  7800 | loss 4.9088 | avg 4.9198 | ppl 136.97 | lr 3.00e-04 | last 200 steps: 20.9s | total: 817s
#   step  8000 | loss 4.9168 | avg 4.9184 | ppl 136.78 | lr 3.00e-04 | last 200 steps: 20.9s | total: 838s
#   step  8200 | loss 4.7518 | avg 4.9167 | ppl 136.55 | lr 3.00e-04 | last 200 steps: 20.9s | total: 859s
#   step  8400 | loss 4.7554 | avg 4.9152 | ppl 136.35 | lr 3.00e-04 | last 200 steps: 20.9s | total: 880s
#   step  8600 | loss 4.9105 | avg 4.9138 | ppl 136.15 | lr 3.00e-04 | last 200 steps: 20.9s | total: 901s
#   step  8800 | loss 5.0148 | avg 4.9123 | ppl 135.96 | lr 3.00e-04 | last 200 steps: 20.9s | total: 922s
#   step  9000 | loss 4.8822 | avg 4.9109 | ppl 135.76 | lr 3.00e-04 | last 200 steps: 20.9s | total: 943s
#   step  9200 | loss 4.8984 | avg 4.9094 | ppl 135.56 | lr 3.00e-04 | last 200 steps: 20.9s | total: 964s
#   step  9400 | loss 4.8096 | avg 4.9080 | ppl 135.37 | lr 3.00e-04 | last 200 steps: 20.9s | total: 985s
#   step  9600 | loss 4.7673 | avg 4.9067 | ppl 135.19 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1006s
#   step  9800 | loss 5.0268 | avg 4.9053 | ppl 135.01 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1027s
#   step 10000 | loss 4.8744 | avg 4.9040 | ppl 134.82 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1048s
#   step 10200 | loss 4.7719 | avg 4.9030 | ppl 134.70 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1069s
#   step 10400 | loss 4.8026 | avg 4.9020 | ppl 134.57 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1089s
#   step 10600 | loss 4.8142 | avg 4.9008 | ppl 134.39 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1110s
#   step 10800 | loss 4.8893 | avg 4.8994 | ppl 134.21 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1131s
#   step 11000 | loss 4.7890 | avg 4.8981 | ppl 134.03 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1152s
#   step 11200 | loss 4.8482 | avg 4.8967 | ppl 133.85 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1173s
#   step 11400 | loss 4.8083 | avg 4.8954 | ppl 133.68 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1194s
#   step 11600 | loss 4.8641 | avg 4.8941 | ppl 133.50 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1215s
#   step 11800 | loss 4.9392 | avg 4.8930 | ppl 133.35 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1236s
#   step 12000 | loss 4.8070 | avg 4.8916 | ppl 133.16 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1257s
#   step 12200 | loss 4.7322 | avg 4.8902 | ppl 132.98 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1278s
#   step 12400 | loss 4.8100 | avg 4.8890 | ppl 132.82 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1299s
#   step 12600 | loss 4.8588 | avg 4.8877 | ppl 132.65 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1320s
#   step 12800 | loss 4.7620 | avg 4.8867 | ppl 132.51 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1341s
#   step 13000 | loss 4.8461 | avg 4.8856 | ppl 132.38 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1362s
#   step 13200 | loss 4.8283 | avg 4.8845 | ppl 132.23 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1383s
#   step 13400 | loss 4.7723 | avg 4.8833 | ppl 132.07 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1403s
#   step 13600 | loss 4.7907 | avg 4.8822 | ppl 131.92 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1424s
#   step 13800 | loss 4.7422 | avg 4.8810 | ppl 131.76 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1445s
#   step 14000 | loss 4.9930 | avg 4.8798 | ppl 131.61 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1466s
#   step 14200 | loss 4.7197 | avg 4.8785 | ppl 131.44 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1487s
#   step 14400 | loss 4.9316 | avg 4.8773 | ppl 131.28 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1508s
#   step 14600 | loss 4.8703 | avg 4.8760 | ppl 131.11 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1529s
#   step 14800 | loss 4.8239 | avg 4.8750 | ppl 130.97 | lr 3.00e-04 | last 200 steps: 21.1s | total: 1550s
#   step 15000 | loss 4.9019 | avg 4.8738 | ppl 130.82 | lr 3.00e-04 | last 200 steps: 21.3s | total: 1572s
#   step 15200 | loss 4.8322 | avg 4.8727 | ppl 130.67 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1593s
#   step 15400 | loss 4.8266 | avg 4.8716 | ppl 130.53 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1613s
#   step 15600 | loss 4.6963 | avg 4.8705 | ppl 130.39 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1634s
#   step 15800 | loss 4.7237 | avg 4.8696 | ppl 130.26 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1655s
#   step 16000 | loss 4.7166 | avg 4.8684 | ppl 130.11 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1676s
#   step 16200 | loss 4.7230 | avg 4.8673 | ppl 129.97 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1697s
#   step 16400 | loss 4.7408 | avg 4.8662 | ppl 129.82 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1718s
#   step 16600 | loss 4.7981 | avg 4.8651 | ppl 129.68 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1739s
#   step 16800 | loss 4.9521 | avg 4.8639 | ppl 129.53 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1760s
#   step 17000 | loss 4.7779 | avg 4.8628 | ppl 129.39 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1781s
#   step 17200 | loss 4.8162 | avg 4.8618 | ppl 129.26 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1802s
#   step 17400 | loss 4.7537 | avg 4.8607 | ppl 129.11 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1823s
#   step 17600 | loss 4.6819 | avg 4.8596 | ppl 128.98 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1844s
#   step 17800 | loss 4.7528 | avg 4.8585 | ppl 128.83 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1865s
#   step 18000 | loss 4.7223 | avg 4.8574 | ppl 128.69 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1886s
#   step 18200 | loss 4.7746 | avg 4.8564 | ppl 128.56 | lr 3.00e-04 | last 200 steps: 21.1s | total: 1907s
#   step 18400 | loss 4.6624 | avg 4.8553 | ppl 128.42 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1928s
#   step 18600 | loss 4.7950 | avg 4.8543 | ppl 128.29 | lr 3.00e-04 | last 200 steps: 21.1s | total: 1949s
#   Shard done — avg loss: 4.8537 | ppl 128.22
#
# Epoch 2 complete — avg loss: 4.8537 | ppl 128.22
# Epoch checkpoint saved → checkpoints_v3\epoch_2.pt
#
# ============================================================
# Epoch 3/10
# ============================================================
#
# [Epoch 3] Shard 1/1 — shard_0000.pt
#   step     0 | loss 4.7837 | avg 4.7837 | ppl 119.55 | lr 3.00e-04 | last 200 steps: 0.3s | total: 0s
#   step   200 | loss 4.5737 | avg 4.7360 | ppl 113.98 | lr 3.00e-04 | last 200 steps: 21.0s | total: 21s
#   step   400 | loss 4.7745 | avg 4.7324 | ppl 113.57 | lr 3.00e-04 | last 200 steps: 21.1s | total: 42s
#   step   600 | loss 4.7355 | avg 4.7320 | ppl 113.53 | lr 3.00e-04 | last 200 steps: 21.1s | total: 64s
#   step   800 | loss 4.7499 | avg 4.7332 | ppl 113.66 | lr 3.00e-04 | last 200 steps: 21.0s | total: 85s
#   step  1000 | loss 4.7609 | avg 4.7342 | ppl 113.77 | lr 3.00e-04 | last 200 steps: 20.9s | total: 105s
#   step  1200 | loss 4.6525 | avg 4.7338 | ppl 113.72 | lr 3.00e-04 | last 200 steps: 20.9s | total: 126s
#   step  1400 | loss 4.6782 | avg 4.7348 | ppl 113.84 | lr 3.00e-04 | last 200 steps: 20.8s | total: 147s
#   step  1600 | loss 4.9431 | avg 4.7353 | ppl 113.90 | lr 3.00e-04 | last 200 steps: 20.9s | total: 168s
#   step  1800 | loss 4.8193 | avg 4.7345 | ppl 113.81 | lr 3.00e-04 | last 200 steps: 21.0s | total: 189s
#   step  2000 | loss 4.7382 | avg 4.7328 | ppl 113.61 | lr 3.00e-04 | last 200 steps: 20.9s | total: 210s
#   step  2200 | loss 4.7735 | avg 4.7333 | ppl 113.66 | lr 3.00e-04 | last 200 steps: 20.9s | total: 231s
#   step  2400 | loss 4.6471 | avg 4.7333 | ppl 113.67 | lr 3.00e-04 | last 200 steps: 20.9s | total: 252s
#   step  2600 | loss 4.8648 | avg 4.7331 | ppl 113.65 | lr 3.00e-04 | last 200 steps: 20.9s | total: 273s
#   step  2800 | loss 4.6590 | avg 4.7321 | ppl 113.54 | lr 3.00e-04 | last 200 steps: 20.9s | total: 293s
#   step  3000 | loss 4.6987 | avg 4.7315 | ppl 113.46 | lr 3.00e-04 | last 200 steps: 20.9s | total: 314s
#   step  3200 | loss 4.7273 | avg 4.7308 | ppl 113.39 | lr 3.00e-04 | last 200 steps: 21.0s | total: 335s
#   step  3400 | loss 4.7913 | avg 4.7296 | ppl 113.25 | lr 3.00e-04 | last 200 steps: 21.0s | total: 356s
#   step  3600 | loss 4.6953 | avg 4.7290 | ppl 113.18 | lr 3.00e-04 | last 200 steps: 21.1s | total: 377s
#   step  3800 | loss 4.7109 | avg 4.7278 | ppl 113.05 | lr 3.00e-04 | last 200 steps: 21.0s | total: 398s
#   step  4000 | loss 4.8176 | avg 4.7275 | ppl 113.01 | lr 3.00e-04 | last 200 steps: 21.1s | total: 420s
#   step  4200 | loss 4.7559 | avg 4.7270 | ppl 112.96 | lr 3.00e-04 | last 200 steps: 21.1s | total: 441s
#   step  4400 | loss 4.6604 | avg 4.7261 | ppl 112.86 | lr 3.00e-04 | last 200 steps: 21.0s | total: 462s
#   step  4600 | loss 4.6854 | avg 4.7257 | ppl 112.81 | lr 3.00e-04 | last 200 steps: 21.1s | total: 483s
#   step  4800 | loss 4.7433 | avg 4.7252 | ppl 112.75 | lr 3.00e-04 | last 200 steps: 21.0s | total: 504s
#   step  5000 | loss 4.7990 | avg 4.7244 | ppl 112.66 | lr 3.00e-04 | last 200 steps: 21.0s | total: 525s
#   step  5200 | loss 4.8099 | avg 4.7241 | ppl 112.63 | lr 3.00e-04 | last 200 steps: 21.0s | total: 546s
#   step  5400 | loss 4.6602 | avg 4.7235 | ppl 112.56 | lr 3.00e-04 | last 200 steps: 21.0s | total: 567s
#   step  5600 | loss 4.7945 | avg 4.7231 | ppl 112.52 | lr 3.00e-04 | last 200 steps: 20.9s | total: 588s
#   step  5800 | loss 4.5250 | avg 4.7225 | ppl 112.45 | lr 3.00e-04 | last 200 steps: 21.0s | total: 609s
#   step  6000 | loss 4.7908 | avg 4.7222 | ppl 112.41 | lr 3.00e-04 | last 200 steps: 21.0s | total: 630s
#   step  6200 | loss 4.4647 | avg 4.7219 | ppl 112.38 | lr 3.00e-04 | last 200 steps: 21.1s | total: 651s
#   step  6400 | loss 4.6504 | avg 4.7215 | ppl 112.33 | lr 3.00e-04 | last 200 steps: 21.0s | total: 672s
#   step  6600 | loss 4.7381 | avg 4.7208 | ppl 112.26 | lr 3.00e-04 | last 200 steps: 21.0s | total: 693s
#   step  6800 | loss 4.8235 | avg 4.7203 | ppl 112.20 | lr 3.00e-04 | last 200 steps: 21.0s | total: 714s
#   step  7000 | loss 4.6883 | avg 4.7197 | ppl 112.14 | lr 3.00e-04 | last 200 steps: 21.0s | total: 735s
#   step  7200 | loss 4.7069 | avg 4.7191 | ppl 112.07 | lr 3.00e-04 | last 200 steps: 20.9s | total: 756s
#   step  7400 | loss 4.6882 | avg 4.7184 | ppl 111.99 | lr 3.00e-04 | last 200 steps: 21.0s | total: 777s
#   step  7600 | loss 4.7107 | avg 4.7179 | ppl 111.94 | lr 3.00e-04 | last 200 steps: 21.0s | total: 798s
#   step  7800 | loss 4.5866 | avg 4.7175 | ppl 111.88 | lr 3.00e-04 | last 200 steps: 21.0s | total: 818s
#   step  8000 | loss 4.6188 | avg 4.7166 | ppl 111.79 | lr 3.00e-04 | last 200 steps: 21.0s | total: 839s
#   step  8200 | loss 4.6872 | avg 4.7160 | ppl 111.72 | lr 3.00e-04 | last 200 steps: 21.0s | total: 860s
#   step  8400 | loss 4.6988 | avg 4.7155 | ppl 111.66 | lr 3.00e-04 | last 200 steps: 21.0s | total: 881s
#   step  8600 | loss 4.6657 | avg 4.7145 | ppl 111.55 | lr 3.00e-04 | last 200 steps: 21.0s | total: 902s
#   step  8800 | loss 4.6993 | avg 4.7139 | ppl 111.49 | lr 3.00e-04 | last 200 steps: 21.0s | total: 923s
#   step  9000 | loss 4.7254 | avg 4.7135 | ppl 111.44 | lr 3.00e-04 | last 200 steps: 21.0s | total: 944s
#   step  9200 | loss 4.6186 | avg 4.7132 | ppl 111.41 | lr 3.00e-04 | last 200 steps: 21.0s | total: 965s
#   step  9400 | loss 4.7599 | avg 4.7125 | ppl 111.33 | lr 3.00e-04 | last 200 steps: 21.0s | total: 986s
#   step  9600 | loss 4.7704 | avg 4.7118 | ppl 111.25 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1007s
#   step  9800 | loss 4.6601 | avg 4.7113 | ppl 111.19 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1028s
#   step 10000 | loss 4.6127 | avg 4.7106 | ppl 111.12 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1049s
#   step 10200 | loss 4.6443 | avg 4.7100 | ppl 111.05 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1070s
#   step 10400 | loss 4.6642 | avg 4.7092 | ppl 110.96 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1091s
#   step 10600 | loss 4.6039 | avg 4.7086 | ppl 110.89 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1112s
#   step 10800 | loss 4.6397 | avg 4.7078 | ppl 110.81 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1133s
#   step 11000 | loss 4.7430 | avg 4.7071 | ppl 110.73 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1154s
#   step 11200 | loss 4.6685 | avg 4.7064 | ppl 110.65 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1175s
#   step 11400 | loss 4.8215 | avg 4.7057 | ppl 110.57 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1196s
#   step 11600 | loss 4.7366 | avg 4.7050 | ppl 110.50 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1217s
#   step 11800 | loss 4.8482 | avg 4.7044 | ppl 110.44 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1238s
#   step 12000 | loss 4.5487 | avg 4.7037 | ppl 110.35 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1259s
#   step 12200 | loss 4.6200 | avg 4.7027 | ppl 110.25 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1280s
#   step 12400 | loss 4.8377 | avg 4.7021 | ppl 110.17 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1301s
#   step 12600 | loss 4.7503 | avg 4.7013 | ppl 110.09 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1322s
#   step 12800 | loss 4.7283 | avg 4.7005 | ppl 110.00 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1343s
#   step 13000 | loss 4.6411 | avg 4.6995 | ppl 109.89 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1364s
#   step 13200 | loss 4.5970 | avg 4.6987 | ppl 109.81 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1385s
#   step 13400 | loss 4.6984 | avg 4.6981 | ppl 109.74 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1406s
#   step 13600 | loss 4.6404 | avg 4.6975 | ppl 109.68 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1427s
#   step 13800 | loss 4.6870 | avg 4.6968 | ppl 109.59 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1448s
#   step 14000 | loss 4.7200 | avg 4.6961 | ppl 109.52 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1469s
#   step 14200 | loss 4.5975 | avg 4.6953 | ppl 109.43 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1490s
#   step 14400 | loss 4.6424 | avg 4.6945 | ppl 109.34 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1511s
#   step 14600 | loss 4.6151 | avg 4.6936 | ppl 109.24 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1532s
#   step 14800 | loss 4.7291 | avg 4.6928 | ppl 109.15 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1553s
#   step 15000 | loss 4.6625 | avg 4.6918 | ppl 109.05 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1574s
#   step 15200 | loss 4.7638 | avg 4.6910 | ppl 108.96 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1594s
#   step 15400 | loss 4.7767 | avg 4.6902 | ppl 108.87 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1615s
#   step 15600 | loss 4.6806 | avg 4.6893 | ppl 108.77 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1636s
#   step 15800 | loss 4.6802 | avg 4.6884 | ppl 108.68 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1657s
#   step 16000 | loss 4.5842 | avg 4.6877 | ppl 108.60 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1678s
#   step 16200 | loss 4.5956 | avg 4.6869 | ppl 108.52 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1699s
#   step 16400 | loss 4.4569 | avg 4.6860 | ppl 108.42 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1720s
#   step 16600 | loss 4.8038 | avg 4.6851 | ppl 108.32 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1741s
#   step 16800 | loss 4.5647 | avg 4.6843 | ppl 108.23 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1762s
#   step 17000 | loss 4.6071 | avg 4.6835 | ppl 108.15 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1783s
#   step 17200 | loss 4.6795 | avg 4.6828 | ppl 108.07 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1804s
#   step 17400 | loss 4.6350 | avg 4.6819 | ppl 107.97 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1825s
#   step 17600 | loss 4.8056 | avg 4.6810 | ppl 107.88 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1846s
#   step 17800 | loss 4.5895 | avg 4.6799 | ppl 107.76 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1867s
#   step 18000 | loss 4.7039 | avg 4.6791 | ppl 107.67 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1888s
#   step 18200 | loss 4.6113 | avg 4.6781 | ppl 107.57 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1909s
#   step 18400 | loss 4.5958 | avg 4.6771 | ppl 107.46 | lr 3.00e-04 | last 200 steps: 20.9s | total: 1930s
#   step 18600 | loss 4.5469 | avg 4.6764 | ppl 107.38 | lr 3.00e-04 | last 200 steps: 21.0s | total: 1951s
#   Shard done — avg loss: 4.6759 | ppl 107.33
#
# Epoch 3 complete — avg loss: 4.6759 | ppl 107.33
# Epoch checkpoint saved → checkpoints_v3\epoch_3.pt
#
# ============================================================
# Epoch 4/10
# ============================================================
#
# [Epoch 4] Shard 1/1 — shard_0000.pt
#   step     0 | loss 4.5116 | avg 4.5116 | ppl 91.06 | lr 3.00e-04 | last 200 steps: 0.3s | total: 0s
#   step   200 | loss 4.4815 | avg 4.5701 | ppl 96.55 | lr 3.00e-04 | last 200 steps: 21.0s | total: 21s
#   step   400 | loss 4.4697 | avg 4.5733 | ppl 96.86 | lr 3.00e-04 | last 200 steps: 21.0s | total: 42s
#   step   600 | loss 4.5827 | avg 4.5696 | ppl 96.51 | lr 3.00e-04 | last 200 steps: 21.0s | total: 63s
#   step   800 | loss 4.6903 | avg 4.5677 | ppl 96.33 | lr 3.00e-04 | last 200 steps: 20.9s | total: 84s
#   step  1000 | loss 4.6672 | avg 4.5679 | ppl 96.34 | lr 3.00e-04 | last 200 steps: 21.0s | total: 105s
#   step  1200 | loss 4.6195 | avg 4.5701 | ppl 96.55 | lr 3.00e-04 | last 200 steps: 21.1s | total: 126s
#   step  1400 | loss 4.4937 | avg 4.5702 | ppl 96.57 | lr 3.00e-04 | last 200 steps: 21.1s | total: 147s
#   step  1600 | loss 4.5417 | avg 4.5700 | ppl 96.55 | lr 3.00e-04 | last 200 steps: 21.0s | total: 168s
#   step  1800 | loss 4.3872 | avg 4.5687 | ppl 96.42 | lr 3.00e-04 | last 200 steps: 21.1s | total: 190s
#   step  2000 | loss 4.6160 | avg 4.5679 | ppl 96.34 | lr 3.00e-04 | last 200 steps: 20.9s | total: 210s
#   step  2200 | loss 4.5986 | avg 4.5676 | ppl 96.31 | lr 3.00e-04 | last 200 steps: 21.1s | total: 231s
#   step  2400 | loss 4.6117 | avg 4.5677 | ppl 96.32 | lr 3.00e-04 | last 200 steps: 21.1s | total: 253s
#   step  2600 | loss 4.5079 | avg 4.5667 | ppl 96.22 | lr 3.00e-04 | last 200 steps: 21.1s | total: 274s
#   step  2800 | loss 4.6142 | avg 4.5660 | ppl 96.16 | lr 3.00e-04 | last 200 steps: 21.0s | total: 295s
#   step  3000 | loss 4.4671 | avg 4.5654 | ppl 96.10 | lr 3.00e-04 | last 200 steps: 21.0s | total: 316s
#   step  3200 | loss 4.6616 | avg 4.5648 | ppl 96.04 | lr 3.00e-04 | last 200 steps: 21.0s | total: 337s
#   step  3400 | loss 4.4709 | avg 4.5639 | ppl 95.95 | lr 3.00e-04 | last 200 steps: 21.0s | total: 358s
#   step  3600 | loss 4.5560 | avg 4.5630 | ppl 95.87 | lr 3.00e-04 | last 200 steps: 21.0s | total: 379s
#   step  3800 | loss 4.6323 | avg 4.5628 | ppl 95.85 | lr 3.00e-04 | last 200 steps: 21.2s | total: 400s
#   step  4000 | loss 4.6326 | avg 4.5620 | ppl 95.78 | lr 3.00e-04 | last 200 steps: 21.2s | total: 421s
#   step  4200 | loss 4.4563 | avg 4.5614 | ppl 95.72 | lr 3.00e-04 | last 200 steps: 21.2s | total: 442s
#   step  4400 | loss 4.5249 | avg 4.5603 | ppl 95.61 | lr 3.00e-04 | last 200 steps: 21.0s | total: 463s
#   step  4600 | loss 4.2624 | avg 4.5606 | ppl 95.64 | lr 3.00e-04 | last 200 steps: 21.0s | total: 484s
#   step  4800 | loss 4.5572 | avg 4.5602 | ppl 95.60 | lr 3.00e-04 | last 200 steps: 21.1s | total: 505s
#   step  5000 | loss 4.6612 | avg 4.5599 | ppl 95.58 | lr 3.00e-04 | last 200 steps: 21.2s | total: 527s
#   step  5200 | loss 4.4415 | avg 4.5595 | ppl 95.54 | lr 3.00e-04 | last 200 steps: 21.0s | total: 548s
#   step  5400 | loss 4.6653 | avg 4.5589 | ppl 95.48 | lr 3.00e-04 | last 200 steps: 21.0s | total: 569s
#   step  5600 | loss 4.5933 | avg 4.5580 | ppl 95.39 | lr 3.00e-04 | last 200 steps: 21.1s | total: 590s
#   step  5800 | loss 4.4592 | avg 4.5575 | ppl 95.34 | lr 3.00e-04 | last 200 steps: 21.1s | total: 611s
#   step  6000 | loss 4.3859 | avg 4.5570 | ppl 95.29 | lr 3.00e-04 | last 200 steps: 21.2s | total: 632s
#   step  6200 | loss 4.5728 | avg 4.5566 | ppl 95.26 | lr 3.00e-04 | last 200 steps: 21.3s | total: 653s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 92
#      90 scaler.unscale_(optimizer)
#      91 torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
# ---> 92 scaler.step(optimizer)
#      93 scaler.update()
#      95 if not math.isnan(loss.item()):
#
# File d:\Anaconda3\envs\jarvis\Lib\site-packages\torch\amp\grad_scaler.py:465, in GradScaler.step(self, optimizer, *args, **kwargs)
#     459     self.unscale_(optimizer)
#     461 assert (
#     462     len(optimizer_state["found_inf_per_device"]) > 0
#     463 ), "No inf checks were recorded for this optimizer."
# --> 465 retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     467 optimizer_state["stage"] = OptState.STEPPED
#     469 return retval
#
# File d:\Anaconda3\envs\jarvis\Lib\site-packages\torch\amp\grad_scaler.py:359, in GradScaler._maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs)
#     351 def _maybe_opt_step(
#     352     self,
#     353     optimizer: torch.optim.Optimizer,
#    (...)    356     **kwargs: Any,
#     357 ) -> Optional[float]:
#     358     retval: Optional[float] = None
# --> 359     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     360         retval = optimizer.step(*args, **kwargs)
#     361     return retval
#
# File d:\Anaconda3\envs\jarvis\Lib\site-packages\torch\amp\grad_scaler.py:359, in <genexpr>(.0)
#     351 def _maybe_opt_step(
#     352     self,
#     353     optimizer: torch.optim.Optimizer,
#    (...)    356     **kwargs: Any,
#     357 ) -> Optional[float]:
#     358     retval: Optional[float] = None
# --> 359     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     360         retval = optimizer.step(*args, **kwargs)
#     361     return retval
#
# KeyboardInterrupt:

# %%
# Out:
# Epoch checkpoint saved → checkpoints_v3\epoch_1.pt

# %%
# ── Inference ─────────────────────────────────────────────────────────────────
from tokenizers import Tokenizer

tok = Tokenizer.from_file("tokenizer/tokenizer.json")

# Special token IDs
BOS_ID       = 2
EOS_ID       = 3
USER_ID      = 5
ASSISTANT_ID = 6

SPECIAL_IDS = set()  # 0-49, all special tokens
MAX_SEQ = 2048
def generate(prompt, max_new_tokens=200, temperature=0.8, top_k=1, mode="text"):
    ids = tok.encode(prompt).ids

    if mode == "text":
        ids = [BOS_ID] + ids
    elif mode == "chat":
        ids = [BOS_ID, USER_ID] + ids + [ASSISTANT_ID]

    x = torch.tensor([ids], dtype=torch.long).to(device)

    with torch.no_grad():
        for _ in range(max_new_tokens):
            logits = model(x[:, -MAX_SEQ:])
            logits = logits[:, -1, :] / temperature
            top_vals, top_idx = torch.topk(logits, top_k)
            probs   = torch.softmax(top_vals, dim=-1)
            next_id = top_idx[0][torch.multinomial(probs, 1)]
            x = torch.cat([x, next_id.view(1, 1)], dim=1)
            if next_id.item() == EOS_ID:
                break

    # manually filter special token IDs before decoding
    clean_ids = [t for t in x[0].tolist() if t not in SPECIAL_IDS]
    return tok.decode(clean_ids)

# ── Text generation prompts ───────────────────────────────────────────────────

text_prompts = [
    "Tori's Health Step by Step coming soon",
    "The quick brown fox",
    "Once upon a time",
    "What should i do ? i love her.",
    "Tell me about a girl named lola and her pet elephant"
]

print("=" * 60)
print("TEXT GENERATION MODE")
print("=" * 60)
for prompt in text_prompts:
    print(f"\nPrompt : {prompt}")
    print(f"Output : {generate(prompt, mode='chat')}")
# Out:
# ============================================================
# TEXT GENERATION MODE
# ============================================================
#
# Prompt : Tori's Health Step by Step coming soon
# Output : Tori's Health Step by Step coming soonic, and the new York Times.
# The New York Times, the New York Times, the New York Times, and the New York Times.
# The New York Times, the New York Times, the New York Times, the New York Times, the New York Times, the New York Times, the New York Times, the New York Times, the New York Times, the New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times, New York Times
#
# Prompt : The quick brown fox
# Output : The quick brown foxure, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old, and the other two-year-old,
#
# Prompt : Once upon a time
# Output : Once upon a timeic, and the other two-year-old, and the other one-year-old, and the other.
# The first time I was a member of the Board of directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors, and the Board of Directors,
#
# Prompt : What should i do ? i love her.
# Output : What should i do ? i love her.ii, I am not a fan of the same name.
# I am not a fan of the same name.
# I am not a fan of the same name.
# I am not a fan of the same name.
# I am not a fan of the same name.
# I am not a fan of the same name.
# I am not a fan of the same name.
# I am not a fan of the same name.
# I am not a fan of the same name.
# I am not a fan of the same name.
# I am not a fan of the same name.
# I am not a fan of the same name.
# I am not a fan of the same name.
# I am not a fan of the same name.
# I am not a fan of the same name.
# I am not a fan name.
# I am not a fan of the same name.
# I am not a fan of the same name.
# I am not
#
# Prompt : Tell me about a girl named lola and her pet elephant
# Output : Tell me about a girl named lola and her pet elephantic.
# The first time she was a girl, and she was a girl. She was a girl.
# She was a girl. She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl.
# She was a girl
